# %%
import pandas as pd 
medicare = pd.read_csv("/netapp2/home/se197/RPDR/Josh Lin/3_EHR_V2/CMS/final_medicare.csv")

# %%
train_set = medicare[medicare.Hospital != 'BWH'] # MGH; n = 204014
validation_set = medicare[medicare.Hospital == 'BWH'] # BWH and Neither; n = 115726
import numpy as np

fifty_perc_EHR_cont = np.percentile(medicare['Cal_MPEC_R0'],50)
train_set_high = train_set[train_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
train_set_low= train_set[train_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

validation_set_high = validation_set[validation_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
validation_set_low = validation_set[validation_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

# %%
predictor_variable_claims = [
    'Co_CAD_RC0', 'Co_Embolism_RC0', 'Co_DVT_RC0', 'Co_PE_RC0', 'Co_AFib_RC0',
        'Co_Hypertension_RC0', 'Co_Hyperlipidemia_RC0', 'Co_Atherosclerosis_RC0',
        'Co_HF_RC0', 'Co_HemoStroke_RC0', 'Co_IscheStroke_RC0', 'Co_OthStroke_RC0',
        'Co_TIA_RC0', 'Co_COPD_RC0', 'Co_Asthma_RC0', 'Co_Pneumonia_RC0', 'Co_Alcoholabuse_RC0',
        'Co_Drugabuse_RC0', 'Co_Epilepsy_RC0', 'Co_Cancer_RC0', 'Co_MorbidObesity_RC0',
        'Co_Dementia_RC0', 'Co_Depression_RC0', 'Co_Bipolar_RC0', 'Co_Psychosis_RC0',
        'Co_Personalitydisorder_RC0', 'Co_Adjustmentdisorder_RC0', 'Co_Anxiety_RC0',
        'Co_Generalizedanxiety_RC0', 'Co_OldMI_RC0', 'Co_AcuteMI_RC0', 'Co_PUD_RC0',
        'Co_UpperGIbleed_RC0', 'Co_LowerGIbleed_RC0', 'Co_Urogenitalbleed_RC0',
        'Co_Othbleed_RC0', 'Co_PVD_RC0', 'Co_LiverDisease_RC0', 'Co_MRI_RC0',
        'Co_ESRD_RC0', 'Co_Obesity_RC0', 'Co_Sepsis_RC0', 'Co_Osteoarthritis_RC0',
        'Co_RA_RC0', 'Co_NeuroPain_RC0', 'Co_NeckPain_RC0', 'Co_OthArthritis_RC0',
        'Co_Osteoporosis_RC0', 'Co_Fibromyalgia_RC0', 'Co_Migraine_RC0', 'Co_Headache_RC0',
        'Co_OthPain_RC0', 'Co_GeneralizedPain_RC0', 'Co_PainDisorder_RC0',
        'Co_Falls_RC0', 'Co_CoagulationDisorder_RC0', 'Co_WhiteBloodCell_RC0', 'Co_Parkinson_RC0',
        'Co_Anemia_RC0', 'Co_UrinaryIncontinence_RC0', 'Co_DecubitusUlcer_RC0',
        'Co_Oxygen_RC0', 'Co_Mammography_RC0', 'Co_PapTest_RC0', 'Co_PSATest_RC0',
        'Co_Colonoscopy_RC0', 'Co_FecalOccultTest_RC0', 'Co_FluShot_RC0', 'Co_PneumococcalVaccine_RC0' , 'Co_RenalDysfunction_RC0', 'Co_Valvular_RC0', 'Co_Hosp_Prior30Days_RC0',
        'Co_RX_Antibiotic_RC0', 'Co_RX_Corticosteroid_RC0', 'Co_RX_Aspirin_RC0', 'Co_RX_Dipyridamole_RC0',
        'Co_RX_Clopidogrel_RC0', 'Co_RX_Prasugrel_RC0', 'Co_RX_Cilostazol_RC0', 'Co_RX_Ticlopidine_RC0',
        'Co_RX_Ticagrelor_RC0', 'Co_RX_OthAntiplatelet_RC0', 'Co_RX_NSAIDs_RC0',
        'Co_RX_Opioid_RC0', 'Co_RX_Antidepressant_RC0', 'Co_RX_AAntipsychotic_RC0', 'Co_RX_TAntipsychotic_RC0',
        'Co_RX_Anticonvulsant_RC0', 'Co_RX_PPI_RC0', 'Co_RX_H2Receptor_RC0', 'Co_RX_OthGastro_RC0',
        'Co_RX_ACE_RC0', 'Co_RX_ARB_RC0', 'Co_RX_BBlocker_RC0', 'Co_RX_CCB_RC0', 'Co_RX_Thiazide_RC0',
        'Co_RX_Loop_RC0', 'Co_RX_Potassium_RC0', 'Co_RX_Nitrates_RC0', 'Co_RX_Aliskiren_RC0',
        'Co_RX_OthAntihypertensive_RC0', 'Co_RX_Antiarrhythmic_RC0', 'Co_RX_OthAnticoagulant_RC0',
        'Co_RX_Insulin_RC0', 'Co_RX_Noninsulin_RC0', 'Co_RX_Digoxin_RC0', 'Co_RX_Statin_RC0',
        'Co_RX_Lipid_RC0', 'Co_RX_Lithium_RC0', 'Co_RX_Benzo_RC0', 'Co_RX_ZDrugs_RC0',
        'Co_RX_OthAnxiolytic_RC0', 'Co_RX_Barbiturate_RC0', 'Co_RX_Dementia_RC0', 'Co_RX_Hormone_RC0',
        'Co_RX_Osteoporosis_RC0', 'Co_N_Drugs_RC0', 'Co_N_Hosp_RC0', 'Co_Total_HospLOS_RC0',
        'Co_N_MDVisit_RC0', 'Co_RX_AnyAspirin_RC0', 'Co_RX_AspirinMono_RC0', 'Co_RX_ClopidogrelMono_RC0',
        'Co_RX_AspirinClopidogrel_RC0', 'Co_RX_DM_RC0', 'Co_RX_Antipsychotic_RC0'
]


co_train_gpop = train_set[predictor_variable_claims]
co_train_high = train_set_high[predictor_variable_claims]
co_train_low = train_set_low[predictor_variable_claims]

co_validation_gpop = validation_set[predictor_variable_claims]
co_validation_high = validation_set_high[predictor_variable_claims]
co_validation_low = validation_set_low[predictor_variable_claims]

# %%
out_train_comp_gpop = train_set['Out_comp_cardiovascular_RC1']
out_train_comp_high = train_set_high['Out_comp_cardiovascular_RC1']
out_train_comp_low = train_set_low['Out_comp_cardiovascular_RC1']

out_validation_comp_gpop = validation_set['Out_comp_cardiovascular_RC1']
out_validation_comp_high = validation_set_high['Out_comp_cardiovascular_RC1']
out_validation_comp_low = validation_set_low['Out_comp_cardiovascular_RC1']

# %% [markdown]
# # Template LR

# %%
def lr(X_train, y_train):
    from sklearn.linear_model import Lasso
    from sklearn.decomposition import PCA
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler 

    model = LogisticRegression()
    param_grid = [
        {'C' : np.logspace(-4, 4, 20)}
        ]
    clf = GridSearchCV(model, param_grid, cv = 5, verbose = True, n_jobs = -1)
    best_clf = clf.fit(X_train, y_train)
    return best_clf

# %%
def train_scores(X_train,y_train):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_train)
    actual = y_train
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.decision_function(X_train)))
    print(log_loss(actual,pred))
    
def test_scores(X_test,y_test):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_test)
    actual = y_test
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.decision_function(X_test)))
    print(log_loss(actual,pred))

# %% [markdown]
# # General Population

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_gpop_sm,out_train_comp_gpop_sm = sm.fit_resample(co_train_gpop,out_train_comp_gpop)

best_clf = lr(co_train_gpop_sm, out_train_comp_gpop_sm)

train_scores(co_train_gpop_sm, out_train_comp_gpop_sm)

print()

train_scores(co_train_gpop, out_train_comp_gpop)

print()

test_scores(co_validation_gpop, out_validation_comp_gpop)

comb = [] 
for i in range(len(predictor_variable_claims)):
    comb.append(predictor_variable_claims[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7408817280453258
# 0.7370879367645737
# 0.7408231202570166
# 0.8117606962077378
# 8.94972588098018
#
# 0.7509388287141926
# 0.4166606091444356
# 0.6726123186859654
# 0.8033753459243019
# 8.602439582489708
#
# 0.7126047068209015
# 0.405650649618478
# 0.650158981672647
# 0.7885488553574033
# 9.926482703994484
# ['Co_CAD_RC0[[0.09361721]]',
#  'Co_Embolism_RC0[[-0.04682446]]',
#  'Co_DVT_RC0[[-0.18041996]]',
#  'Co_PE_RC0[[0.03465272]]',
#  'Co_AFib_RC0[[0.09834976]]',
#  'Co_Hypertension_RC0[[-0.11186203]]',
#  'Co_Hyperlipidemia_RC0[[-0.22500921]]',
#  'Co_Atherosclerosis_RC0[[0.00357515]]',
#  'Co_HF_RC0[[0.43697428]]',
#  'Co_HemoStroke_RC0[[0.18167955]]',
#  'Co_IscheStroke_RC0[[0.35215574]]',
#  'Co_OthStroke_RC0[[-0.11110924]]',
#  'Co_TIA_RC0[[0.02863647]]',
#  'Co_COPD_RC0[[0.19531857]]',
#  'Co_Asthma_RC0[[-0.15413047]]',
#  'Co_Pneumonia_RC0[[0.40739172]]',
#  'Co_Alcoholabuse_RC0[[0.00108186]]',
#  'Co_Drugabuse_RC0[[-0.06806608]]',
#  'Co_Epilepsy_RC0[[0.00650949]]',
#  'Co_Cancer_RC0[[0.35266396]]',
#  'Co_MorbidObesity_RC0[[-0.07482506]]',
#  'Co_Dementia_RC0[[0.4792083]]',
#  'Co_Depression_RC0[[-0.16558767]]',
#  'Co_Bipolar_RC0[[-0.11283303]]',
#  'Co_Psychosis_RC0[[0.04058215]]',
]',
#  'Co_RX_OthAntiplatelet_RC0[[0.03460988]]',
#  'Co_RX_NSAIDs_RC0[[-0.18427069]]',
#  'Co_RX_Opioid_RC0[[0.02006051]]',
#  'Co_RX_Antidepressant_RC0[[0.09023655]]',
#  'Co_RX_AAntipsychotic_RC0[[-0.04498376]]',
#  'Co_RX_TAntipsychotic_RC0[[0.06769219]]',
#  'Co_RX_Anticonvulsant_RC0[[0.03503433]]',
#  'Co_RX_PPI_RC0[[-0.02494484]]',
#  'Co_RX_H2Receptor_RC0[[0.02813395]]',
#  'Co_RX_OthGastro_RC0[[-0.19539939]]',
#  'Co_RX_ACE_RC0[[-0.11560413]]',
#  'Co_RX_ARB_RC0[[-0.2068359]]',
#  'Co_RX_BBlocker_RC0[[0.13668098]]',
#  'Co_RX_CCB_RC0[[0.02671463]]',
#  'Co_RX_Thiazide_RC0[[0.02238749]]',
#  'Co_RX_Loop_RC0[[0.27853327]]',
#  'Co_RX_Potassium_RC0[[-0.00194389]]',
#  'Co_RX_Nitrates_RC0[[0.15032654]]',
#  'Co_RX_Aliskiren_RC0[[0.0041416]]',
#  'Co_RX_OthAntihypertensive_RC0[[-0.13572569]]',
#  'Co_RX_Antiarrhythmic_RC0[[-0.19810793]]',
#  'Co_RX_OthAnticoagulant_RC0[[-0.02795638]]',
#  'Co_RX_Insulin_RC0[[0.12741264]]',
#  'Co_RX_Noninsulin_RC0[[-0.08321765]]',
#  'Co_RX_Digoxin_RC0[[0.00998665]]',
#  'Co_RX_Statin_RC0[[-0.20672981]]',
#  'Co_RX_Lipid_RC0[[-0.18222345]]',
#  'Co_RX_Lithium_RC0[[-0.02241469]]',
#  'Co_RX_Benzo_RC0[[0.08007823]]',
#  'Co_RX_ZDrugs_RC0[[-0.05730267]]',
#  'Co_RX_OthAnxiolytic_RC0[[0.0381654]]',
#  'Co_RX_Barbiturate_RC0[[-0.00046115]]',
#  'Co_RX_Dementia_RC0[[0.15169991]]',
#  'Co_RX_Hormone_RC0[[-0.21797637]]',
#  'Co_RX_Osteoporosis_RC0[[-0.05853605]]',
#  'Co_N_Drugs_RC0[[0.00082764]]',
#  'Co_N_Hosp_RC0[[0.02973347]]',
#  'Co_Total_HospLOS_RC0[[0.00088214]]',
#  'Co_N_MDVisit_RC0[[0.00226484]]',
#  'Co_RX_AnyAspirin_RC0[[-0.06551574]]',
#  'Co_RX_AspirinMono_RC0[[-0.05792738]]',
#  'Co_RX_ClopidogrelMono_RC0[[0.00564005]]',
#  'Co_RX_AspirinClopidogrel_RC0[[-0.02612509]]',
#  'Co_RX_DM_RC0[[0.05798555]]',
#  'Co_RX_Antipsychotic_RC0[[0.04482859]]']

# %% [markdown]
# # High Continuity

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_high_sm,out_train_comp_high_sm = sm.fit_resample(co_train_high, out_train_comp_high)

best_clf = lr(co_train_high_sm, out_train_comp_high_sm)

train_scores(co_train_high_sm, out_train_comp_high_sm)

print()

train_scores(co_train_high, out_train_comp_high)

print()

test_scores(co_validation_high, out_validation_comp_high)

comb = [] 
for i in range(len(predictor_variable_claims)):
    comb.append(predictor_variable_claims[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.
#  'Co_Fibromyalgia_RC0[[-0.49023825]]',
#  'Co_Migraine_RC0[[-0.11633667]]',
#  'Co_Headache_RC0[[-0.09752494]]',
#  'Co_OthPain_RC0[[0.27608099]]',
#  'Co_GeneralizedPain_RC0[[0.09074874]]',
#  'Co_PainDisorder_RC0[[-0.03682764]]',
#  'Co_Falls_RC0[[0.22015441]]',
#  'Co_CoagulationDisorder_RC0[[-0.07889029]]',
#  'Co_WhiteBloodCell_RC0[[0.42065973]]',
#  'Co_Parkinson_RC0[[0.22933029]]',
#  'Co_Anemia_RC0[[0.35478152]]',
#  'Co_UrinaryIncontinence_RC0[[0.24047449]]',
#  'Co_DecubitusUlcer_RC0[[0.29308569]]',
#  'Co_Oxygen_RC0[[0.25902373]]',
#  'Co_Mammography_RC0[[-0.91588562]]',
#  'Co_PapTest_RC0[[-0.50281992]]',
#  'Co_PSATest_RC0[[-0.56586562]]',
#  'Co_Colonoscopy_RC0[[-0.39520384]]',
#  'Co_FecalOccultTest_RC0[[-0.12119993]]',
#  'Co_FluShot_RC0[[-0.10784587]]',
#  'Co_PneumococcalVaccine_RC0[[-0.2513605]]',
#  'Co_RenalDysfunction_RC0[[0.28742501]]',
#  'Co_Valvular_RC0[[-0.0322324]]',
#  'Co_Hosp_Prior30Days_RC0[[0.91797664]]',
#  'Co_RX_Antibiotic_RC0[[-0.2580557]]',
#  'Co_RX_Corticosteroid_RC0[[0.28068566]]',
#  'Co_RX_Aspirin_RC0[[-0.04977722]]',
#  'Co_RX_Dipyridamole_RC0[[0.07238695]]',
#  'Co_RX_Clopidogrel_RC0[[0.04398198]]',
#  'Co_RX_Prasugrel_RC0[[-0.0251571]]',
#  'Co_RX_Cilostazol_RC0[[0.03583147]]',
#  'Co_RX_Ticlopidine_RC0[[-0.00925651]]',
#  'Co_RX_Ticagrelor_RC0[[-0.03664795]]',
#  'Co_RX_OthAntiplatelet_RC0[[0.02657496]]',
#  'Co_RX_NSAIDs_RC0[[-0.2037072]]',
#  'Co_RX_Opioid_RC0[[-0.10872331]]',
#  'Co_RX_Antidepressant_RC0[[0.13255372]]',
#  'Co_RX_AAntipsychotic_RC0[[-0.00678002]]',
#  'Co_RX_TAntipsychotic_RC0[[0.026781]]',
#  'Co_RX_Anticonvulsant_RC0[[0.01582978]]',
#  'Co_RX_PPI_RC0[[0.18745978]]',
#  'Co_RX_H2Receptor_RC0[[0.02233932]]',
#  'Co_RX_OthGastro_RC0[[-0.33352333]]',
#  'Co_RX_ACE_RC0[[-0.15567319]]',
#  'Co_RX_ARB_RC0[[-0.23847683]]',
#  'Co_RX_BBlocker_RC0[[0.17599028]]',
#  'Co_RX_CCB_RC0[[-0.09155662]]',
#  'Co_RX_Thiazide_RC0[[0.00244983]]',
#  'Co_RX_Loop_RC0[[0.24533067]]',
#  'Co_RX_Potassium_RC0[[0.10715406]]',
#  'Co_RX_Nitrates_RC0[[0.25571462]]',
#  'Co_RX_Aliskiren_RC0[[0.05951359]]',
#  'Co_RX_OthAntihypertensive_RC0[[-0.09064746]]',
#  'Co_RX_Antiarrhythmic_RC0[[-0.09122195]]',
#  'Co_RX_OthAnticoagulant_RC0[[-0.01952697]]',
#  'Co_RX_Insulin_RC0[[0.03560109]]',
#  'Co_RX_Noninsulin_RC0[[-0.032493]]',
#  'Co_RX_Digoxin_RC0[[0.09302534]]',
#  'Co_RX_Statin_RC0[[-0.2176271]]',
#  'Co_RX_Lipid_RC0[[-0.29440927]]',
#  'Co_RX_Lithium_RC0[[-0.05873895]]',
#  'Co_RX_Benzo_RC0[[0.09409817]]',
#  'Co_RX_ZDrugs_RC0[[-0.12268707]]',
#  'Co_RX_OthAnxiolytic_RC0[[0.14934919]]',
#  'Co_RX_Barbiturate_RC0[[-0.00257095]]',
#  'Co_RX_Dementia_RC0[[0.39740325]]',
#  'Co_RX_Hormone_RC0[[-0.31194555]]',
#  'Co_RX_Osteoporosis_RC0[[0.06288879]]',
#  'Co_N_Drugs_RC0[[0.00323002]]',
#  'Co_N_Hosp_RC0[[-0.01110658]]',
#  'Co_Total_HospLOS_RC0[[-0.00139477]]',
#  'Co_N_MDVisit_RC0[[0.01163093]]',
#  'Co_RX_AnyAspirin_RC0[[-0.05876959]]',
#  'Co_RX_AspirinMono_RC0[[-0.10702472]]',
#  'Co_RX_ClopidogrelMono_RC0[[-0.05577533]]',
#  'Co_RX_AspirinClopidogrel_RC0[[0.01096386]]',
#  'Co_RX_DM_RC0[[0.11179418]]',
#  'Co_RX_Antipsychotic_RC0[[0.03337142]]']

# %% [markdown]
# # Low Continuity

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_low_sm,out_train_comp_low_sm = sm.fit_resample(co_train_low,out_train_comp_low)

best_clf = lr(co_train_low_sm, out_train_comp_low_sm)

train_scores(co_train_low_sm, out_train_comp_low_sm)

print()

train_scores(co_train_low, out_train_comp_low)

print()

test_scores(co_validation_low, out_validation_comp_low)

comb = [] 
for i in range(len(predictor_variable_claims)):
    comb.append(predictor_variable_claims[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7381262947901481
# 0.735385331059079
# 0.7380960478839942
# 0.80844960848695
# 9.044897903477192
#
# 0.7422527010415992
# 0.46307277628032345
# 0.6819562102264305
# 0.7991253289757735
# 8.902445897502773
#
# 0.7126359992364956
# 0.45204731574158324
# 0.660450689677295
# 0.7699749288674713
# 9.925388770218722
# ['Co_CAD_RC0[[0.16566174]]',
#  'Co_Embolism_RC0[[-0.07947104]]',
#  'Co_DVT_RC0[[-0.17171737]]',
#  'Co_PE_RC0[[-0.02896689]]',
#  'Co_AFib_RC0[[0.12010437]]',
#  'Co_Hypertension_RC0[[-0.17404327]]',
#  'Co_Hyperlipidemia_RC0[[-0.13459763]]',
#  'Co_Atherosclerosis_RC0[[0.00120398]]',
#  'Co_HF_RC0[[0.35513097]]',
#  'Co_HemoStroke_RC0[[0.42182055]]',
#  'Co_IscheStroke_RC0[[0.45133984]]',
#  'Co_OthStroke_RC0[[-0.1628216]]',
#  'Co_TIA_RC0[[-0.05109855]]',
#  'Co_COPD_RC0[[0.23411215]]',
#  'Co_Asthma_RC0[[-0.11589558]]',
#  'Co_Pneumonia_RC0[[0.42986101]]',
#  'Co_Alcoholabuse_RC0[[-0.17479382]]',
#  'Co_Drugabuse_RC0[[-0.07073638]]',
#  'Co_Epilepsy_RC0[[-0.07572045]]',
#  'Co_Cancer_RC0[[0.24695796]]',
#  'Co_MorbidObesity_RC0[[-0.07540338]]',
#  'Co_Dementia_RC0[[0.48862055]]',
#  'Co_Depression_RC0[[-0.1801081]]',
#  'Co_Bipolar_RC0[[-0.15711835]]',
#  'Co_Psychosis_RC0[[0.07799391]]',
#  'Co_Personalitydisorder_RC0[[0.029744]]',
#  'Co_Adjustmentdisorder_RC0[[-0.10206385]]',
#  'Co_Anxiety_RC0[[0.05409642]]',
#  'Co_Generalizedanxiety_RC0[[-0.2633939]]',
#  'Co_OldMI_RC0[[-0.10553085]]',
#  'Co_AcuteMI_RC0[[0.27279742]]',
#  'Co_PUD_RC0[[0.06684911]]',
#  'Co_UpperGIbleed_RC0[[0.16498009]]',
#  'Co_LowerGIbleed_RC0[[0.18178322]]',
#  'Co_Urogenitalbleed_RC0[[-0.08504608]]',
#  'Co_Othbleed_RC0[[-0.0738404]]',
#  'Co_PVD_RC0[[0.21739429]]',
#  'Co_LiverDisease_RC0[[0.31997862]]',
#  'Co_MRI_RC0[[-0.20851159]]',
#  'Co_ESRD_RC0[[0.24885376]]',
#  'Co_Obesity_RC0[[-0.34639496]]',
#  'Co_Sepsis_RC0[[0.09245547]]',
#  'Co_Osteoarthritis_RC0[[-0.10355294]]',
#  'Co_RA_RC0[[-0.09001754]]',
#  'Co_NeuroPain_RC0[[-0.07712354]]',
#  'Co_NeckPain_RC0[[-0.12875719]]',
#  'Co_OthArthritis_RC0[[0.094088]]',
#  'Co_Osteoporosis_RC0[[0.08890693]]',
#  'Co_Fibromyalgia_RC0[[-0.03905793]]',
#  'Co_Migraine_RC0[[-0.13804433]]',
#  'Co_Headache_RC0[[0.0390995]]',
#  'Co_OthPain_RC0[[-0.10060804]]',
#  'Co_GeneralizedPain_RC0[[0.06944079]]',
#  'Co_PainDisorder_RC0[[-0.01846828]]',
#  'Co_Falls_RC0[[0.09694273]]',
#  'Co_CoagulationDisorder_RC0[[-0.00316382]]',
#  'Co_WhiteBloodCell_RC0[[0.12994431]]',
#  'Co_Parkinson_RC0[[0.04151815]]',
#  'Co_Anemia_RC0[[0.16870203]]',
#  'Co_UrinaryIncontinence_RC0[[0.17761539]]',
#  'Co_DecubitusUlcer_RC0[[0.26386592]]',
#  'Co_Oxygen_RC0[[0.19470857]]',
#  'Co_Mammography_RC0[[-0.56350363]]',
#  'Co_PapTest_RC0[[-0.1558656]]',
#  'Co_PSATest_RC0[[-0.3864433]]',
#  'Co_Colonoscopy_RC0[[-0.39608113]]',
#  'Co_FecalOccultTest_RC0[[-0.23068736]]',
#  'Co_FluShot_RC0[[-0.02935866]]',
#  'Co_PneumococcalVaccine_RC0[[-0.07321981]]',
#  'Co_RenalDysfunction_RC0[[0.39108763]]',
#  'Co_Valvular_RC0[[-0.03040373]]',
#  'Co_Hosp_Prior30Days_RC0[[0.98898119]]',
#  'Co_RX_Antibiotic_RC0[[-0.05965762]]',
#  'Co_RX_Corticosteroid_RC0[[0.09226014]]',
#  'Co_RX_Aspirin_RC0[[-0.01274628]]',
#  'Co_RX_Dipyridamole_RC0[[0.15968565]]',
#  'Co_RX_Clopidogrel_RC0[[0.00328405]]',
#  'Co_RX_Prasugrel_RC0[[-0.0075857]]',
#  'Co_RX_Cilostazol_RC0[[0.08538293]]',
#  'Co_RX_Ticlopidine_RC0[[0.00467501]]',
#  'Co_RX_Ticagrelor_RC0[[0.01348453]]',
#  'Co_RX_OthAntiplatelet_RC0[[0.09005794]]',
#  'Co_RX_NSAIDs_RC0[[-0.14484199]]',
#  'Co_RX_Opioid_RC0[[0.14062717]]',
#  'Co_RX_Antidepressant_RC0[[0.11253527]]',
#  'Co_RX_AAntipsychotic_RC0[[-0.1129883]]',
#  'Co_RX_TAntipsychotic_RC0[[0.17714604]]',
#  'Co_RX_Anticonvulsant_RC0[[0.11702489]]',
#  'Co_RX_PPI_RC0[[-0.12552964]]',
#  'Co_RX_H2Receptor_RC0[[0.01231173]]',
#  'Co_RX_OthGastro_RC0[[-0.20854417]]',
#  'Co_RX_ACE_RC0[[-0.01974356]]',
#  'Co_RX_ARB_RC0[[-0.13524591]]',
#  'Co_RX_BBlocker_RC0[[0.16293588]]',
#  'Co_RX_CCB_RC0[[0.068604]]',
#  'Co_RX_Thiazide_RC0[[0.1254642]]',
#  'Co_RX_Loop_RC0[[0.3678419]]',
#  'Co_RX_Potassium_RC0[[0.06612377]]',
#  'Co_RX_Nitrates_RC0[[0.02329362]]',
#  'Co_RX_Aliskiren_RC0[[-0.02929261]]',
#  'Co_RX_OthAntihypertensive_RC0[[-0.19565523]]',
#  'Co_RX_Antiarrhythmic_RC0[[-0.33032232]]',
#  'Co_RX_OthAnticoagulant_RC0[[0.00494301]]',
#  'Co_RX_Insulin_RC0[[0.20351858]]',
#  'Co_RX_Noninsulin_RC0[[-0.18202129]]',
#  'Co_RX_Digoxin_RC0[[-0.00598168]]',
#  'Co_RX_Statin_RC0[[-0.25942715]]',
#  'Co_RX_Lipid_RC0[[-0.08520431]]',
#  'Co_RX_Lithium_RC0[[-0.00612842]]',
#  'Co_RX_Benzo_RC0[[0.12323741]]',
#  'Co_RX_ZDrugs_RC0[[0.088153]]',
#  'Co_RX_OthAnxiolytic_RC0[[-0.19887578]]',
#  'Co_RX_Barbiturate_RC0[[0.]]',
#  'Co_RX_Dementia_RC0[[0.17048626]]',
#  'Co_RX_Hormone_RC0[[-0.21082323]]',
#  'Co_RX_Osteoporosis_RC0[[-0.12712974]]',
#  'Co_N_Drugs_RC0[[-0.00425422]]',
#  'Co_N_Hosp_RC0[[0.0055673]]',
#  'Co_Total_HospLOS_RC0[[0.0024632]]',
#  'Co_N_MDVisit_RC0[[-0.0053123]]',
#  'Co_RX_AnyAspirin_RC0[[-0.03306316]]',
#  'Co_RX_AspirinMono_RC0[[-0.02980539]]',
#  'Co_RX_ClopidogrelMono_RC0[[0.02371022]]',
#  'Co_RX_AspirinClopidogrel_RC0[[-0.02420637]]',
#  'Co_RX_DM_RC0[[0.16159959]]',
#  'Co_RX_Antipsychotic_RC0[[0.09923615]]']
