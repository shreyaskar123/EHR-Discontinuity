# %%
import pandas as pd
medicare = pd.read_csv("/netapp2/home/se197/RPDR/Josh Lin/3_EHR_V2/CMS/Data/final_medicare.csv")

# %%
train_set = medicare[medicare.Hospital != 'BWH'] # MGH; n = 204014
validation_set = medicare[medicare.Hospital == 'BWH'] # BWH and Neither; n = 115726
import numpy as np

fifty_perc_EHR_cont = np.percentile(medicare['Cal_MPEC_R0'],50)
train_set_high = train_set[train_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
train_set_low= train_set[train_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

validation_set_high = validation_set[validation_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
validation_set_low = validation_set[validation_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

# %%
predictor_variable = [
        'Co_CAD_R0', 'Co_Embolism_R0', 'Co_DVT_R0', 'Co_PE_R0', 'Co_AFib_R0',
        'Co_Hypertension_R0', 'Co_Hyperlipidemia_R0', 'Co_Atherosclerosis_R0',
        'Co_HF_R0', 'Co_HemoStroke_R0', 'Co_IscheStroke_R0', 'Co_OthStroke_R0',
        'Co_TIA_R0', 'Co_COPD_R0', 'Co_Asthma_R0', 'Co_Pneumonia_R0', 'Co_Alcoholabuse_R0',
        'Co_Drugabuse_R0', 'Co_Epilepsy_R0', 'Co_Cancer_R0', 'Co_MorbidObesity_R0',
        'Co_Dementia_R0', 'Co_Depression_R0', 'Co_Bipolar_R0', 'Co_Psychosis_R0',
        'Co_Personalitydisorder_R0', 'Co_Adjustmentdisorder_R0', 'Co_Anxiety_R0',
        'Co_Generalizedanxiety_R0', 'Co_OldMI_R0', 'Co_AcuteMI_R0', 'Co_PUD_R0',
        'Co_UpperGIbleed_R0', 'Co_LowerGIbleed_R0', 'Co_Urogenitalbleed_R0',
        'Co_Othbleed_R0', 'Co_PVD_R0', 'Co_LiverDisease_R0', 'Co_MRI_R0',
        'Co_ESRD_R0', 'Co_Obesity_R0', 'Co_Sepsis_R0', 'Co_Osteoarthritis_R0',
        'Co_RA_R0', 'Co_NeuroPain_R0', 'Co_NeckPain_R0', 'Co_OthArthritis_R0',
        'Co_Osteoporosis_R0', 'Co_Fibromyalgia_R0', 'Co_Migraine_R0', 'Co_Headache_R0',
        'Co_OthPain_R0', 'Co_GeneralizedPain_R0', 'Co_PainDisorder_R0',
        'Co_Falls_R0', 'Co_CoagulationDisorder_R0', 'Co_WhiteBloodCell_R0', 'Co_Parkinson_R0',
        'Co_Anemia_R0', 'Co_UrinaryIncontinence_R0', 'Co_DecubitusUlcer_R0',
        'Co_Oxygen_R0', 'Co_Mammography_R0', 'Co_PapTest_R0', 'Co_PSATest_R0',
        'Co_Colonoscopy_R0', 'Co_FecalOccultTest_R0', 'Co_FluShot_R0', 'Co_PneumococcalVaccine_R0', 'Co_RenalDysfunction_R0', 'Co_Valvular_R0', 'Co_Hosp_Prior30Days_R0',
        'Co_RX_Antibiotic_R0', 'Co_RX_Corticosteroid_R0', 'Co_RX_Aspirin_R0', 'Co_RX_Dipyridamole_R0',
        'Co_RX_Clopidogrel_R0', 'Co_RX_Prasugrel_R0', 'Co_RX_Cilostazol_R0', 'Co_RX_Ticlopidine_R0',
        'Co_RX_Ticagrelor_R0', 'Co_RX_OthAntiplatelet_R0', 'Co_RX_NSAIDs_R0',
        'Co_RX_Opioid_R0', 'Co_RX_Antidepressant_R0', 'Co_RX_AAntipsychotic_R0', 'Co_RX_TAntipsychotic_R0',
        'Co_RX_Anticonvulsant_R0', 'Co_RX_PPI_R0', 'Co_RX_H2Receptor_R0', 'Co_RX_OthGastro_R0',
        'Co_RX_ACE_R0', 'Co_RX_ARB_R0', 'Co_RX_BBlocker_R0', 'Co_RX_CCB_R0', 'Co_RX_Thiazide_R0',
        'Co_RX_Loop_R0', 'Co_RX_Potassium_R0', 'Co_RX_Nitrates_R0', 'Co_RX_Aliskiren_R0',
        'Co_RX_OthAntihypertensive_R0', 'Co_RX_Antiarrhythmic_R0', 'Co_RX_OthAnticoagulant_R0',
        'Co_RX_Insulin_R0', 'Co_RX_Noninsulin_R0', 'Co_RX_Digoxin_R0', 'Co_RX_Statin_R0',
        'Co_RX_Lipid_R0', 'Co_RX_Lithium_R0', 'Co_RX_Benzo_R0', 'Co_RX_ZDrugs_R0',
        'Co_RX_OthAnxiolytic_R0', 'Co_RX_Dementia_R0', 'Co_RX_Hormone_R0',
        'Co_RX_Osteoporosis_R0', 'Co_N_Drugs_R0', 'Co_N_Hosp_R0', 'Co_Total_HospLOS_R0',
        'Co_N_MDVisit_R0', 'Co_RX_AnyAspirin_R0', 'Co_RX_AspirinMono_R0', 'Co_RX_ClopidogrelMono_R0',
        'Co_RX_AspirinClopidogrel_R0', 'Co_RX_DM_R0', 'Co_RX_Antipsychotic_R0'
]

co_train_gpop = train_set[predictor_variable]
co_train_high = train_set_high[predictor_variable]
co_train_low = train_set_low[predictor_variable]

co_validation_gpop = validation_set[predictor_variable]
co_validation_high = validation_set_high[predictor_variable]
co_validation_low = validation_set_low[predictor_variable]

# %%
out_train_death_gpop = train_set['ehr_death']
out_train_death_high = train_set_high['ehr_death']
out_train_death_low = train_set_low['ehr_death']

out_validation_death_gpop = validation_set['ehr_death']
out_validation_death_high = validation_set_high['ehr_death']
out_validation_death_low = validation_set_low['ehr_death']

# %%
def lr(X_train, y_train):
    from sklearn.linear_model import Lasso
    from sklearn.decomposition import PCA
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler 

    model = LogisticRegression()
    param_grid = [
        {'C' : np.logspace(-4, 4, 20)}
        ]
    clf = GridSearchCV(model, param_grid, cv = 5, verbose = True, n_jobs = -1)
    best_clf = clf.fit(X_train, y_train)
    return best_clf

# %%
def scores(X_train,y_train):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_train)
    actual = y_train
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.predict_proba(X_train)[:,1]))
    print(log_loss(actual,best_clf.predict_proba(X_train)[:,1]))

# %%
def cross_val(X,y):
    from sklearn.model_selection import KFold
    from sklearn.model_selection import cross_validate
    from sklearn.metrics import log_loss
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import fbeta_score
    import sklearn
    import numpy as np
    cv = KFold(n_splits=5, random_state=1, shuffle=True)
    log_loss = [] 
    auc = [] 
    accuracy = [] 
    f1 = [] 
    f2 = [] 
    for train_index, test_index in cv.split(X):
        X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        model = lr(X_train, y_train)
        prob = model.predict_proba(X_test)[:,1] # prob is a vector of probabilities 
        print(prob)
        pred = np.round(prob) # pred is the rounded predictions 
        
        log_loss.append(sklearn.metrics.log_loss(y_test, prob))
        auc.append(sklearn.metrics.roc_auc_score(y_test, prob))
        accuracy.append(sklearn.metrics.accuracy_score(y_test, pred))
        f1.append(sklearn.metrics.f1_score(y_test, pred, average = 'macro'))
        f2.append(fbeta_score(y_test,pred, average = 'macro', beta = 2))
    print(np.mean(accuracy))
    print(np.mean(f1))
    print(np.mean(f2))
    print(np.mean(auc))
    print(np.mean(log_loss))

# %% [markdown]
# # General Population

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_gpop_sm,out_train_death_gpop_sm = sm.fit_resample(co_train_gpop,out_train_death_gpop)

best_clf = lr(co_train_gpop_sm, out_train_death_gpop_sm)

scores(co_train_gpop_sm, out_train_death_gpop_sm)

print()

scores(co_train_gpop, out_train_death_gpop)

print()

scores(co_validation_gpop, out_validation_death_gpop)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7517415446744069
# 0.746241959340924
# 0.7516101497695287
# 0.8322785442012088
# 0.5089293050346955
#
# 0.7694671177182583
# 0.32778280542986427
# 0.6469217978767886
# 0.8208670182643601
# 0.5273185445239118
#
# 0.7281112883925009
# 0.3169234623575097
# 0.6200771551583267
# 0.7880742354931562
# 0.5908318680067534
# ['Co_CAD_R0[[0.04664563]]',
#  'Co_Embolism_R0[[0.14885889]]',
#  'Co_DVT_R0[[-0.10028692]]',
#  'Co_PE_R0[[0.18076673]]',
#  'Co_AFib_R0[[0.31608717]]',
#  'Co_Hypertension_R0[[-0.11144262]]',
#  'Co_Hyperlipidemia_R0[[-0.59232719]]',
#  'Co_Atherosclerosis_R0[[0.12007089]]',
#  'Co_HF_R0[[0.62246732]]',
#  'Co_HemoStroke_R0[[0.45077223]]',
#  'Co_IscheStroke_R0[[0.14968934]]',
#  'Co_OthStroke_R0[[-0.24565081]]',
#  'Co_TIA_R0[[-0.16980507]]',
#  'Co_COPD_R0[[0.69585698]]',
#  'Co_Asthma_R0[[-0.96948917]]',
#  'Co_Pneumonia_R0[[0.42149587]]',
#  'Co_Alcoholabuse_R0[[-0.45333917]]',
#  'Co_Drugabuse_R0[[-0.35451037]]',
#  'Co_Epilepsy_R0[[-0.0198945]]',
#  'Co_Cancer_R0[[0.63452982]]',
#  'Co_MorbidObesity_R0[[-0.31879275]]',
#  'Co_Dementia_R0[[1.11678405]]',
#  'Co_Depression_R0[[-0.24192623]]',
#  'Co_Bipolar_R0[[-0.18281383]]',
#  'Co_Psychosis_R0[[-0.57222065]]',
#  'Co_Personalitydisorder_R0[[-0.00165045]]',
#  'Co_Adjustmentdisorder_R0[[-0.05039268]]',
#  'Co_Anxiety_R0[[-0.38165495]]',
#  'Co_Generalizedanxiety_R0[[-0.2367677]]',
#  'Co_OldMI_R0[[-0.19413698]]',
#  'Co_AcuteMI_R0[[-0.03925732]]',
#  'Co_PUD_R0[[-0.33139834]]',
#  'Co_UpperGIbleed_R0[[0.02393927]]',
#  'Co_LowerGIbleed_R0[[-0.00119304]]',
#  'Co_Urogenitalbleed_R0[[-0.1818467]]',
#  'Co_Othbleed_R0[[-0.38840829]]',
#  'Co_PVD_R0[[0.13330632]]',
#  'Co_LiverDisease_R0[[0.23831557]]',
#  'Co_MRI_R0[[-0.09227299]]',
#  'Co_ESRD_R0[[0.48055656]]',
#  'Co_Obesity_R0[[-0.931559]]',
#  'Co_Sepsis_R0[[0.27758714]]',
#  'Co_Osteoarthritis_R0[[-0.40198052]]',
#  'Co_RA_R0[[-0.19425146]]',
#  'Co_NeuroPain_R0[[-0.0690727]]',
#  'Co_NeckPain_R0[[-0.25600905]]',
#  'Co_OthArthritis_R0[[-0.16972457]]',
#  'Co_Osteoporosis_R0[[-0.30225147]]',
#  'Co_Fibromyalgia_R0[[-0.43884473]]',
#  'Co_Migraine_R0[[-0.28634213]]',
#  'Co_Headache_R0[[-0.2643293]]',
#  'Co_OthPain_R0[[0.08592662]]',
#  'Co_GeneralizedPain_R0[[0.05000522]]',
#  'Co_PainDisorder_R0[[-0.01912519]]',
#  'Co_Falls_R0[[0.43199993]]',
#  'Co_CoagulationDisorder_R0[[-0.20254988]]',
#  'Co_WhiteBloodCell_R0[[0.30324913]]',
#  'Co_Parkinson_R0[[-0.01488928]]',
#  'Co_Anemia_R0[[0.27664823]]',
#  'Co_UrinaryIncontinence_R0[[-0.0419274]]',
#  'Co_DecubitusUlcer_R0[[0.44325616]]',
#  'Co_Oxygen_R0[[0.23735429]]',
#  'Co_Mammography_R0[[-1.08942463]]',
#  'Co_PapTest_R0[[-0.54162656]]',
#  'Co_PSATest_R0[[-0.53741688]]',
#  'Co_Colonoscopy_R0[[-0.54541969]]',
#  'Co_FecalOccultTest_R0[[-0.04296616]]',
#  'Co_FluShot_R0[[-0.27525792]]',
#  'Co_PneumococcalVaccine_R0[[-0.58982002]]',
#  'Co_RenalDysfunction_R0[[0.48814584]]',
#  'Co_Valvular_R0[[-0.00076079]]',
#  'Co_Hosp_Prior30Days_R0[[1.2697794]]',
#  'Co_RX_Antibiotic_R0[[-0.1878993]]',
#  'Co_RX_Corticosteroid_R0[[0.24887222]]',
#  'Co_RX_Aspirin_R0[[-0.05789072]]',
#  'Co_RX_Dipyridamole_R0[[0.08172127]]',
#  'Co_RX_Clopidogrel_R0[[-0.0894855]]',
#  'Co_RX_Prasugrel_R0[[-0.06245215]]',
#  'Co_RX_Cilostazol_R0[[0.06521412]]',
#  'Co_RX_Ticlopidine_R0[[-0.01336245]]',
#  'Co_RX_Ticagrelor_R0[[-0.05387694]]',
#  'Co_RX_OthAntiplatelet_R0[[0.05185167]]',
#  'Co_RX_NSAIDs_R0[[-0.06200392]]',
#  'Co_RX_Opioid_R0[[0.11940515]]',
#  'Co_RX_Antidepressant_R0[[0.24642459]]',
#  'Co_RX_AAntipsychotic_R0[[0.23684989]]',
#  'Co_RX_TAntipsychotic_R0[[-0.24277437]]',
#  'Co_RX_Anticonvulsant_R0[[0.08332228]]',
#  'Co_RX_PPI_R0[[0.28897946]]',
#  'Co_RX_H2Receptor_R0[[0.04192883]]',
#  'Co_RX_OthGastro_R0[[-0.49443788]]',
#  'Co_RX_ACE_R0[[-0.14336707]]',
#  'Co_RX_ARB_R0[[-0.32520216]]',
#  'Co_RX_BBlocker_R0[[0.00100105]]',
#  'Co_RX_CCB_R0[[-0.1391424]]',
#  'Co_RX_Thiazide_R0[[-0.20137561]]',
#  'Co_RX_Loop_R0[[0.39447628]]',
#  'Co_RX_Potassium_R0[[0.24490314]]',
#  'Co_RX_Nitrates_R0[[0.00550801]]',
#  'Co_RX_Aliskiren_R0[[0.00516778]]',
#  'Co_RX_OthAntihypertensive_R0[[-0.16380894]]',
#  'Co_RX_Antiarrhythmic_R0[[-0.14273982]]',
#  'Co_RX_OthAnticoagulant_R0[[0.04353557]]',
#  'Co_RX_Insulin_R0[[0.11336983]]',
#  'Co_RX_Noninsulin_R0[[-0.14328265]]',
#  'Co_RX_Digoxin_R0[[0.29591488]]',
#  'Co_RX_Statin_R0[[-0.36317823]]',
#  'Co_RX_Lipid_R0[[-0.48576484]]',
#  'Co_RX_Lithium_R0[[-0.07376754]]',
#  'Co_RX_Benzo_R0[[0.12683034]]',
#  'Co_RX_ZDrugs_R0[[0.07168101]]',
#  'Co_RX_OthAnxiolytic_R0[[-0.02901204]]',
#  'Co_RX_Dementia_R0[[0.26867582]]',
#  'Co_RX_Hormone_R0[[-0.4292088]]',
#  'Co_RX_Osteoporosis_R0[[0.17089806]]',
#  'Co_N_Drugs_R0[[0.0052093]]',
#  'Co_N_Hosp_R0[[-0.01428653]]',
#  'Co_Total_HospLOS_R0[[1.87045112e-05]]',
#  'Co_N_MDVisit_R0[[0.02896747]]',
#  'Co_RX_AnyAspirin_R0[[-0.06094285]]',
#  'Co_RX_AspirinMono_R0[[-0.05198257]]',
#  'Co_RX_ClopidogrelMono_R0[[-0.05322177]]',
#  'Co_RX_AspirinClopidogrel_R0[[-0.02675376]]',
#  'Co_RX_DM_R0[[-0.07497294]]',
#  'Co_RX_Antipsychotic_R0[[0.13200481]]']

# %% [markdown]
# # High Continuity

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_high_sm,out_train_death_high_sm = sm.fit_resample(co_train_high,out_train_death_high)

best_clf = lr(co_train_high_sm, out_train_death_high_sm)

scores(co_train_high_sm, out_train_death_high_sm)

print()

scores(co_train_high, out_train_death_high)

print()

scores(co_validation_high, out_validation_death_high)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7883213991508776
# 0.791394760670684
# 0.7882619515733829
# 0.8561199702404387
# 0.47609731034547115
#
# 0.773204485802911
# 0.28399246704331454
# 0.6321479349479815
# 0.8430488960577713
# 0.5059633823284494
#
# 0.7521403215702652
# 0.25486503452605147
# 0.6007387767204706
# 0.7973969694331178
# 0.5293000574121814
# ['Co_CAD_R0[[-0.2136165]]',
#  'Co_Embolism_R0[[-0.04464614]]',
#  'Co_DVT_R0[[-0.07407405]]',
#  'Co_PE_R0[[0.12657404]]',
#  'Co_AFib_R0[[0.28460603]]',
#  'Co_Hypertension_R0[[-0.01996086]]',
#  'Co_Hyperlipidemia_R0[[-0.59162003]]',
#  'Co_Atherosclerosis_R0[[0.18369273]]',
#  'Co_HF_R0[[0.79573718]]',
#  'Co_HemoStroke_R0[[-0.23381358]]',
#  'Co_IscheStroke_R0[[-0.09289817]]',
#  'Co_OthStroke_R0[[-0.30562528]]',
#  'Co_TIA_R0[[0.21657677]]',
#  'Co_COPD_R0[[0.60945255]]',
#  'Co_Asthma_R0[[-0.79737819]]',
#  'Co_Pneumonia_R0[[0.42279442]]',
#  'Co_Alcoholabuse_R0[[-0.22303447]]',
#  'Co_Drugabuse_R0[[-0.35280526]]',
#  'Co_Epilepsy_R0[[-0.29010105]]',
#  'Co_Cancer_R0[[0.78579299]]',
#  'Co_MorbidObesity_R0[[-0.45800947]]',
#  'Co_Dementia_R0[[1.02082224]]',
#  'Co_Depression_R0[[-0.25749006]]',
#  'Co_Bipolar_R0[[-0.27454922]]',
#  'Co_Psychosis_R0[[-0.4366817]]',
#  'Co_Personalitydisorder_R0[[0.01731781]]',
#  'Co_Adjustmentdisorder_R0[[-0.01576891]]',
#  'Co_Anxiety_R0[[-0.23731207]]',
#  'Co_Generalizedanxiety_R0[[-0.16217063]]',
#  'Co_OldMI_R0[[0.40869975]]',
#  'Co_AcuteMI_R0[[-0.08644007]]',
#  'Co_PUD_R0[[-0.158025]]',
#  'Co_UpperGIbleed_R0[[0.1205642]]',
#  'Co_LowerGIbleed_R0[[-0.00080049]]',
#  'Co_Urogenitalbleed_R0[[0.01130278]]',
#  'Co_Othbleed_R0[[-0.32760373]]',
#  'Co_PVD_R0[[0.21250045]]',
#  'Co_LiverDisease_R0[[0.12597248]]',
#  'Co_MRI_R0[[-0.10579737]]',
#  'Co_ESRD_R0[[0.40301748]]',
#  'Co_Obesity_R0[[-0.96570287]]',
#  'Co_Sepsis_R0[[-0.06306767]]',
#  'Co_Osteoarthritis_R0[[-0.44331767]]',
#  'Co_RA_R0[[-0.40173644]]',
#  'Co_NeuroPain_R0[[-0.14423527]]',
#  'Co_NeckPain_R0[[-0.16317052]]',
#  'Co_OthArthritis_R0[[-0.24815373]]',
#  'Co_Osteoporosis_R0[[-0.37845277]]',
#  'Co_Fibromyalgia_R0[[-0.65333026]]',
#  'Co_Migraine_R0[[-0.41400646]]',
#  'Co_Headache_R0[[-0.07750418]]',
#  'Co_OthPain_R0[[0.20138287]]',
#  'Co_GeneralizedPain_R0[[0.06995857]]',
#  'Co_PainDisorder_R0[[-0.02949122]]',
#  'Co_Falls_R0[[0.50261199]]',
#  'Co_CoagulationDisorder_R0[[-0.24198829]]',
#  'Co_WhiteBloodCell_R0[[0.42408761]]',
#  'Co_Parkinson_R0[[0.3439965]]',
#  'Co_Anemia_R0[[0.51674456]]',
#  'Co_UrinaryIncontinence_R0[[0.12711615]]',
#  'Co_DecubitusUlcer_R0[[0.50612512]]',
#  'Co_Oxygen_R0[[0.35711232]]',
#  'Co_Mammography_R0[[-1.14411537]]',
#  'Co_PapTest_R0[[-0.76917469]]',
#  'Co_PSATest_R0[[-0.50191092]]',
#  'Co_Colonoscopy_R0[[-0.63477967]]',
#  'Co_FecalOccultTest_R0[[-0.1185175]]',
#  'Co_FluShot_R0[[-0.19242233]]',
#  'Co_PneumococcalVaccine_R0[[-0.57382861]]',
#  'Co_RenalDysfunction_R0[[0.5923152]]',
#  'Co_Valvular_R0[[0.03097013]]',
#  'Co_Hosp_Prior30Days_R0[[0.92634056]]',
#  'Co_RX_Antibiotic_R0[[-0.12631778]]',
#  'Co_RX_Corticosteroid_R0[[0.21606824]]',
#  'Co_RX_Aspirin_R0[[-0.10242466]]',
#  'Co_RX_Dipyridamole_R0[[-0.03491055]]',
#  'Co_RX_Clopidogrel_R0[[-0.02032106]]',
#  'Co_RX_Prasugrel_R0[[-0.05190477]]',
#  'Co_RX_Cilostazol_R0[[0.16240719]]',
#  'Co_RX_Ticlopidine_R0[[-0.01651674]]',
#  'Co_RX_Ticagrelor_R0[[-0.10979363]]',
#  'Co_RX_OthAntiplatelet_R0[[0.14589045]]',
#  'Co_RX_NSAIDs_R0[[-0.04139304]]',
#  'Co_RX_Opioid_R0[[0.08875605]]',
#  'Co_RX_Antidepressant_R0[[0.44060635]]',
#  'Co_RX_AAntipsychotic_R0[[0.22365386]]',
#  'Co_RX_TAntipsychotic_R0[[-0.20493617]]',
#  'Co_RX_Anticonvulsant_R0[[0.22630852]]',
#  'Co_RX_PPI_R0[[0.22575944]]',
#  'Co_RX_H2Receptor_R0[[-0.11361939]]',
#  'Co_RX_OthGastro_R0[[-0.55494719]]',
#  'Co_RX_ACE_R0[[-0.25103153]]',
#  'Co_RX_ARB_R0[[-0.28331408]]',
#  'Co_RX_BBlocker_R0[[0.01700653]]',
#  'Co_RX_CCB_R0[[-0.06495871]]',
#  'Co_RX_Thiazide_R0[[-0.02744925]]',
#  'Co_RX_Loop_R0[[0.43900711]]',
#  'Co_RX_Potassium_R0[[0.24431904]]',
#  'Co_RX_Nitrates_R0[[0.11100627]]',
#  'Co_RX_Aliskiren_R0[[0.04425832]]',
#  'Co_RX_OthAntihypertensive_R0[[-0.02806715]]',
#  'Co_RX_Antiarrhythmic_R0[[0.00115849]]',
#  'Co_RX_OthAnticoagulant_R0[[-0.04130489]]',
#  'Co_RX_Insulin_R0[[0.03771503]]',
#  'Co_RX_Noninsulin_R0[[-0.13501086]]',
#  'Co_RX_Digoxin_R0[[0.40295404]]',
#  'Co_RX_Statin_R0[[-0.14499241]]',
#  'Co_RX_Lipid_R0[[-0.60566631]]',
#  'Co_RX_Lithium_R0[[-0.10620497]]',
#  'Co_RX_Benzo_R0[[0.07255583]]',
#  'Co_RX_ZDrugs_R0[[-0.03014932]]',
#  'Co_RX_OthAnxiolytic_R0[[0.28138661]]',
#  'Co_RX_Dementia_R0[[0.33155908]]',
#  'Co_RX_Hormone_R0[[-0.69308345]]',
#  'Co_RX_Osteoporosis_R0[[0.33487874]]',
#  'Co_N_Drugs_R0[[0.00045306]]',
#  'Co_N_Hosp_R0[[-0.06200322]]',
#  'Co_Total_HospLOS_R0[[0.00857588]]',
#  'Co_N_MDVisit_R0[[0.02843296]]',
#  'Co_RX_AnyAspirin_R0[[-0.11542531]]',
#  'Co_RX_AspirinMono_R0[[0.04332832]]',
#  'Co_RX_ClopidogrelMono_R0[[0.07757782]]',
#  'Co_RX_AspirinClopidogrel_R0[[-0.09073307]]',
#  'Co_RX_DM_R0[[0.0665282]]',
#  'Co_RX_Antipsychotic_R0[[0.14217018]]']

# %% [markdown]
# # Low Continuity

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_low_sm,out_train_death_low_sm = sm.fit_resample(co_train_low,out_train_death_low)

best_clf = lr(co_train_low_sm, out_train_death_low_sm)

scores(co_train_low_sm, out_train_death_low_sm)

print()

scores(co_train_low, out_train_death_low)

print()

scores(co_validation_low, out_validation_death_low)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7485287785273432
# 0.7393632847366856
# 0.7481821618341922
# 0.8270390849321461
# 0.5142761221167984
#
# 0.775829721161933
# 0.38224282403280446
# 0.6701260282339374
# 0.8120127048619884
# 0.5283606433256661
#
# 0.7236113762168352
# 0.35673034207019105
# 0.6297893609214511
# 0.7576487745981016
# 0.6078485089238544
# ['Co_CAD_R0[[0.2157129]]',
#  'Co_Embolism_R0[[0.38600636]]',
#  'Co_DVT_R0[[-0.09540709]]',
#  'Co_PE_R0[[0.30439672]]',
#  'Co_AFib_R0[[0.3215227]]',
#  'Co_Hypertension_R0[[-0.01660259]]',
#  'Co_Hyperlipidemia_R0[[-0.46543261]]',
#  'Co_Atherosclerosis_R0[[0.02882561]]',
#  'Co_HF_R0[[0.73891707]]',
#  'Co_HemoStroke_R0[[1.03214555]]',
#  'Co_IscheStroke_R0[[0.4448976]]',
#  'Co_OthStroke_R0[[0.08430235]]',
#  'Co_TIA_R0[[-1.12720248]]',
#  'Co_COPD_R0[[0.6978746]]',
#  'Co_Asthma_R0[[-1.08614169]]',
#  'Co_Pneumonia_R0[[0.38594918]]',
#  'Co_Alcoholabuse_R0[[-1.29012696]]',
#  'Co_Drugabuse_R0[[-0.5720966]]',
#  'Co_Epilepsy_R0[[0.1780321]]',
#  'Co_Cancer_R0[[0.69980211]]',
#  'Co_MorbidObesity_R0[[0.17810404]]',
#  'Co_Dementia_R0[[1.23064694]]',
#  'Co_Depression_R0[[-0.2304156]]',
#  'Co_Bipolar_R0[[-0.3899963]]',
#  'Co_Psychosis_R0[[-0.93635174]]',
#  'Co_Personalitydisorder_R0[[0.11940784]]',
#  'Co_Adjustmentdisorder_R0[[-0.28076416]]',
#  'Co_Anxiety_R0[[-0.44680943]]',
#  'Co_Generalizedanxiety_R0[[-0.55413434]]',
#  'Co_OldMI_R0[[-0.50555916]]',
#  'Co_AcuteMI_R0[[-0.06411668]]',
#  'Co_PUD_R0[[-0.62199152]]',
#  'Co_UpperGIbleed_R0[[-0.25954811]]',
#  'Co_LowerGIbleed_R0[[0.27698494]]',
#  'Co_Urogenitalbleed_R0[[-1.05056209]]',
#  'Co_Othbleed_R0[[-0.36993575]]',
#  'Co_PVD_R0[[0.22682187]]',
#  'Co_LiverDisease_R0[[0.58280317]]',
#  'Co_MRI_R0[[-0.21650546]]',
#  'Co_ESRD_R0[[0.83428872]]',
#  'Co_Obesity_R0[[-0.73258371]]',
#  'Co_Sepsis_R0[[0.95308781]]',
#  'Co_Osteoarthritis_R0[[-0.15866914]]',
#  'Co_RA_R0[[0.13818031]]',
#  'Co_NeuroPain_R0[[-0.09721492]]',
#  'Co_NeckPain_R0[[-0.23370147]]',
#  'Co_OthArthritis_R0[[-0.02774958]]',
#  'Co_Osteoporosis_R0[[-0.62621594]]',
#  'Co_Fibromyalgia_R0[[-0.21634437]]',
#  'Co_Migraine_R0[[-0.3819611]]',
#  'Co_Headache_R0[[-0.79858475]]',
#  'Co_OthPain_R0[[-0.53052625]]',
#  'Co_GeneralizedPain_R0[[0.04152914]]',
#  'Co_PainDisorder_R0[[-0.0233652]]',
#  'Co_Falls_R0[[0.35285873]]',
#  'Co_CoagulationDisorder_R0[[-0.20469657]]',
#  'Co_WhiteBloodCell_R0[[0.10496634]]',
#  'Co_Parkinson_R0[[-0.12498874]]',
#  'Co_Anemia_R0[[0.11484122]]',
#  'Co_UrinaryIncontinence_R0[[-0.75982391]]',
#  'Co_DecubitusUlcer_R0[[0.81088859]]',
#  'Co_Oxygen_R0[[0.04855698]]',
#  'Co_Mammography_R0[[-0.67393742]]',
#  'Co_PapTest_R0[[-0.46243218]]',
#  'Co_PSATest_R0[[-0.69196994]]',
#  'Co_Colonoscopy_R0[[-0.51563365]]',
#  'Co_FecalOccultTest_R0[[0.2218436]]',
#  'Co_FluShot_R0[[-1.08053507]]',
#  'Co_PneumococcalVaccine_R0[[-0.60130166]]',
#  'Co_RenalDysfunction_R0[[0.4550574]]',
#  'Co_Valvular_R0[[0.15184901]]',
#  'Co_Hosp_Prior30Days_R0[[1.29382245]]',
#  'Co_RX_Antibiotic_R0[[-0.09196941]]',
#  'Co_RX_Corticosteroid_R0[[0.21275813]]',
#  'Co_RX_Aspirin_R0[[0.01702927]]',
#  'Co_RX_Dipyridamole_R0[[0.32206682]]',
#  'Co_RX_Clopidogrel_R0[[-0.32834077]]',
#  'Co_RX_Prasugrel_R0[[-0.17544529]]',
#  'Co_RX_Cilostazol_R0[[0.02184913]]',
#  'Co_RX_Ticlopidine_R0[[-0.03880342]]',
#  'Co_RX_Ticagrelor_R0[[-0.10051519]]',
#  'Co_RX_OthAntiplatelet_R0[[-0.01695429]]',
#  'Co_RX_NSAIDs_R0[[-0.23946395]]',
#  'Co_RX_Opioid_R0[[0.29954444]]',
#  'Co_RX_Antidepressant_R0[[-0.05643871]]',
#  'Co_RX_AAntipsychotic_R0[[0.37968987]]',
#  'Co_RX_TAntipsychotic_R0[[-0.59986389]]',
#  'Co_RX_Anticonvulsant_R0[[0.1396975]]',
#  'Co_RX_PPI_R0[[0.43932486]]',
#  'Co_RX_H2Receptor_R0[[0.01194559]]',
#  'Co_RX_OthGastro_R0[[-0.73681731]]',
#  'Co_RX_ACE_R0[[-0.02610606]]',
#  'Co_RX_ARB_R0[[-0.47486479]]',
#  'Co_RX_BBlocker_R0[[-0.02817149]]',
#  'Co_RX_CCB_R0[[-0.13158209]]',
#  'Co_RX_Thiazide_R0[[-0.50874968]]',
#  'Co_RX_Loop_R0[[0.43137623]]',
#  'Co_RX_Potassium_R0[[0.17744762]]',
#  'Co_RX_Nitrates_R0[[-0.11957035]]',
#  'Co_RX_Aliskiren_R0[[-0.04729497]]',
#  'Co_RX_OthAntihypertensive_R0[[-0.37250215]]',
#  'Co_RX_Antiarrhythmic_R0[[-0.19449336]]',
#  'Co_RX_OthAnticoagulant_R0[[0.30499225]]',
#  'Co_RX_Insulin_R0[[0.43260074]]',
#  'Co_RX_Noninsulin_R0[[-0.02847257]]',
#  'Co_RX_Digoxin_R0[[0.20485435]]',
#  'Co_RX_Statin_R0[[-0.44250907]]',
#  'Co_RX_Lipid_R0[[-0.31086359]]',
#  'Co_RX_Lithium_R0[[-0.1178776]]',
#  'Co_RX_Benzo_R0[[0.05393527]]',
#  'Co_RX_ZDrugs_R0[[0.25531652]]',
#  'Co_RX_OthAnxiolytic_R0[[-0.52371951]]',
#  'Co_RX_Dementia_R0[[0.26476154]]',
#  'Co_RX_Hormone_R0[[-0.11441472]]',
#  'Co_RX_Osteoporosis_R0[[-0.12205106]]',
#  'Co_N_Drugs_R0[[0.00958859]]',
#  'Co_N_Hosp_R0[[-0.60225161]]',
#  'Co_Total_HospLOS_R0[[-0.00478857]]',
#  'Co_N_MDVisit_R0[[-0.34116302]]',
#  'Co_RX_AnyAspirin_R0[[0.01702927]]',
#  'Co_RX_AspirinMono_R0[[-0.1060739]]',
#  'Co_RX_ClopidogrelMono_R0[[-0.61720961]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.33039894]]',
#  'Co_RX_DM_R0[[-0.43565265]]',
#  'Co_RX_Antipsychotic_R0[[0.20582956]]']
