# %%
import pandas as pd 
medicare = pd.read_csv("/netapp2/home/se197/RPDR/Josh Lin/3_EHR_V2/CMS/final_medicare.csv")

# %%
train_set = medicare[medicare.Hospital != 'BWH'] # MGH; n = 204014
validation_set = medicare[medicare.Hospital == 'BWH'] # BWH and Neither; n = 115726
import numpy as np

fifty_perc_EHR_cont = np.percentile(medicare['Cal_MPEC_R0'],50)
train_set_high = train_set[train_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
train_set_low= train_set[train_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

validation_set_high = validation_set[validation_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
validation_set_low = validation_set[validation_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

# %%
predictor_variable_claims = [
    'Co_CAD_RC0', 'Co_Embolism_RC0', 'Co_DVT_RC0', 'Co_PE_RC0', 'Co_AFib_RC0',
        'Co_Hypertension_RC0', 'Co_Hyperlipidemia_RC0', 'Co_Atherosclerosis_RC0',
        'Co_HF_RC0', 'Co_HemoStroke_RC0', 'Co_IscheStroke_RC0', 'Co_OthStroke_RC0',
        'Co_TIA_RC0', 'Co_COPD_RC0', 'Co_Asthma_RC0', 'Co_Pneumonia_RC0', 'Co_Alcoholabuse_RC0',
        'Co_Drugabuse_RC0', 'Co_Epilepsy_RC0', 'Co_Cancer_RC0', 'Co_MorbidObesity_RC0',
        'Co_Dementia_RC0', 'Co_Depression_RC0', 'Co_Bipolar_RC0', 'Co_Psychosis_RC0',
        'Co_Personalitydisorder_RC0', 'Co_Adjustmentdisorder_RC0', 'Co_Anxiety_RC0',
        'Co_Generalizedanxiety_RC0', 'Co_OldMI_RC0', 'Co_AcuteMI_RC0', 'Co_PUD_RC0',
        'Co_UpperGIbleed_RC0', 'Co_LowerGIbleed_RC0', 'Co_Urogenitalbleed_RC0',
        'Co_Othbleed_RC0', 'Co_PVD_RC0', 'Co_LiverDisease_RC0', 'Co_MRI_RC0',
        'Co_ESRD_RC0', 'Co_Obesity_RC0', 'Co_Sepsis_RC0', 'Co_Osteoarthritis_RC0',
        'Co_RA_RC0', 'Co_NeuroPain_RC0', 'Co_NeckPain_RC0', 'Co_OthArthritis_RC0',
        'Co_Osteoporosis_RC0', 'Co_Fibromyalgia_RC0', 'Co_Migraine_RC0', 'Co_Headache_RC0',
        'Co_OthPain_RC0', 'Co_GeneralizedPain_RC0', 'Co_PainDisorder_RC0',
        'Co_Falls_RC0', 'Co_CoagulationDisorder_RC0', 'Co_WhiteBloodCell_RC0', 'Co_Parkinson_RC0',
        'Co_Anemia_RC0', 'Co_UrinaryIncontinence_RC0', 'Co_DecubitusUlcer_RC0',
        'Co_Oxygen_RC0', 'Co_Mammography_RC0', 'Co_PapTest_RC0', 'Co_PSATest_RC0',
        'Co_Colonoscopy_RC0', 'Co_FecalOccultTest_RC0', 'Co_FluShot_RC0', 'Co_PneumococcalVaccine_RC0' , 'Co_RenalDysfunction_RC0', 'Co_Valvular_RC0', 'Co_Hosp_Prior30Days_RC0',
        'Co_RX_Antibiotic_RC0', 'Co_RX_Corticosteroid_RC0', 'Co_RX_Aspirin_RC0', 'Co_RX_Dipyridamole_RC0',
        'Co_RX_Clopidogrel_RC0', 'Co_RX_Prasugrel_RC0', 'Co_RX_Cilostazol_RC0', 'Co_RX_Ticlopidine_RC0',
        'Co_RX_Ticagrelor_RC0', 'Co_RX_OthAntiplatelet_RC0', 'Co_RX_NSAIDs_RC0',
        'Co_RX_Opioid_RC0', 'Co_RX_Antidepressant_RC0', 'Co_RX_AAntipsychotic_RC0', 'Co_RX_TAntipsychotic_RC0',
        'Co_RX_Anticonvulsant_RC0', 'Co_RX_PPI_RC0', 'Co_RX_H2Receptor_RC0', 'Co_RX_OthGastro_RC0',
        'Co_RX_ACE_RC0', 'Co_RX_ARB_RC0', 'Co_RX_BBlocker_RC0', 'Co_RX_CCB_RC0', 'Co_RX_Thiazide_RC0',
        'Co_RX_Loop_RC0', 'Co_RX_Potassium_RC0', 'Co_RX_Nitrates_RC0', 'Co_RX_Aliskiren_RC0',
        'Co_RX_OthAntihypertensive_RC0', 'Co_RX_Antiarrhythmic_RC0', 'Co_RX_OthAnticoagulant_RC0',
        'Co_RX_Insulin_RC0', 'Co_RX_Noninsulin_RC0', 'Co_RX_Digoxin_RC0', 'Co_RX_Statin_RC0',
        'Co_RX_Lipid_RC0', 'Co_RX_Lithium_RC0', 'Co_RX_Benzo_RC0', 'Co_RX_ZDrugs_RC0',
        'Co_RX_OthAnxiolytic_RC0', 'Co_RX_Barbiturate_RC0', 'Co_RX_Dementia_RC0', 'Co_RX_Hormone_RC0',
        'Co_RX_Osteoporosis_RC0', 'Co_N_Drugs_RC0', 'Co_N_Hosp_RC0', 'Co_Total_HospLOS_RC0',
        'Co_N_MDVisit_RC0', 'Co_RX_AnyAspirin_RC0', 'Co_RX_AspirinMono_RC0', 'Co_RX_ClopidogrelMono_RC0',
        'Co_RX_AspirinClopidogrel_RC0', 'Co_RX_DM_RC0', 'Co_RX_Antipsychotic_RC0'
]


co_train_gpop = train_set[predictor_variable_claims]
co_train_high = train_set_high[predictor_variable_claims]
co_train_low = train_set_low[predictor_variable_claims]

co_validation_gpop = validation_set[predictor_variable_claims]
co_validation_high = validation_set_high[predictor_variable_claims]
co_validation_low = validation_set_low[predictor_variable_claims]

# %%
out_train_death_gpop = train_set['ehr_claims_death']
out_train_death_high = train_set_high['ehr_claims_death']
out_train_death_low = train_set_low['ehr_claims_death']

out_validation_death_gpop = validation_set['ehr_claims_death']
out_validation_death_high = validation_set_high['ehr_claims_death']
out_validation_death_low = validation_set_low['ehr_claims_death']

# %% [markdown]
# # Template LR

# %%
def lr(X_train, y_train):
    from sklearn.linear_model import Lasso
    from sklearn.decomposition import PCA
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler 

    model = LogisticRegression()
    param_grid = [
        {'C' : np.logspace(-4, 4, 20)}
        ]
    clf = GridSearchCV(model, param_grid, cv = 5, verbose = True, n_jobs = -1)
    best_clf = clf.fit(X_train, y_train)
    return best_clf

# %%
def train_scores(X_train,y_train):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_train)
    actual = y_train
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.decision_function(X_train)))
    print(log_loss(actual,pred))
    
def test_scores(X_test,y_test):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_test)
    actual = y_test
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.decision_function(X_test)))
    print(log_loss(actual,pred))

# %% [markdown]
# # General Population

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_gpop_sm,out_train_death_gpop_sm = sm.fit_resample(co_train_gpop,out_train_death_gpop)

best_clf = lr(co_train_gpop_sm, out_train_death_gpop_sm)

train_scores(co_train_gpop_sm, out_train_death_gpop_sm)

print()

train_scores(co_train_gpop, out_train_death_gpop)

print()

test_scores(co_validation_gpop, out_validation_death_gpop)

comb = [] 
for i in range(len(predictor_variable_claims)):
    comb.append(predictor_variable_claims[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7823146721451806
# 0.7825789572681724
# 0.7823142660704393
# 0.8564936297238926
# 7.518672379518242
#
# 0.7790571366500109
# 0.39148645183349007
# 0.6822616392599816
# 0.8462242575918789
# 7.631254802201682
#
# 0.7470083765456721
# 0.3908763505402161
# 0.6690719797664134
# 0.8335496571682424
# 8.738205582622973
# ['Co_CAD_RC0[[0.00962605]]',
#  'Co_Embolism_RC0[[-0.02058273]]',
#  'Co_DVT_RC0[[-0.14602008]]',
#  'Co_PE_RC0[[0.08720625]]',
#  'Co_AFib_RC0[[0.09294956]]',
#  'Co_Hypertension_RC0[[-0.27822573]]',
#  'Co_Hyperlipidemia_RC0[[-0.21912368]]',
#  'Co_Atherosclerosis_RC0[[-0.01980653]]',
#  'Co_HF_RC0[[0.55581054]]',
#  'Co_HemoStroke_RC0[[0.3750815]]',
#  'Co_IscheStroke_RC0[[0.19843488]]',
#  'Co_OthStroke_RC0[[-0.13474079]]',
#  'Co_TIA_RC0[[-0.19276062]]',
#  'Co_COPD_RC0[[0.23343233]]',
#  'Co_Asthma_RC0[[-0.41500652]]',
#  'Co_Pneumonia_RC0[[0.5040175]]',
#  'Co_Alcoholabuse_RC0[[-0.21353762]]',
#  'Co_Drugabuse_RC0[[-0.15205425]]',
#  'Co_Epilepsy_RC0[[-0.04758002]]',
#  'Co_Cancer_RC0[[0.62275066]]',
#  'Co_MorbidObesity_RC0[[-0.18716283]]',
#  'Co_Dementia_RC0[[0.80916737]]',
#  'Co_Depression_RC0[[-0.22386919]]',
#  'Co_Bipolar_RC0[[-0.16746537]]',
#  'Co_Psychosis_RC0[[-0.04084855]]',
#  'Co_Personalitydisorder_RC0[[0.01081192]]',
#  'Co_Adjustmentdisorder_RC0[[-0.08091129]]',
#  'Co_Anxiety_RC0[[-0.00290036]]',
]',
#  'Co_RX_OthAntiplatelet_RC0[[0.06908206]]',
#  'Co_RX_NSAIDs_RC0[[-0.14185702]]',
#  'Co_RX_Opioid_RC0[[0.18528693]]',
#  'Co_RX_Antidepressant_RC0[[0.21165892]]',
#  'Co_RX_AAntipsychotic_RC0[[0.01515513]]',
#  'Co_RX_TAntipsychotic_RC0[[0.1150531]]',
#  'Co_RX_Anticonvulsant_RC0[[0.06459891]]',
#  'Co_RX_PPI_RC0[[0.06027648]]',
#  'Co_RX_H2Receptor_RC0[[0.1211483]]',
#  'Co_RX_OthGastro_RC0[[-0.22962292]]',
#  'Co_RX_ACE_RC0[[-0.15643635]]',
#  'Co_RX_ARB_RC0[[-0.36244481]]',
#  'Co_RX_BBlocker_RC0[[0.19434141]]',
#  'Co_RX_CCB_RC0[[0.0343035]]',
#  'Co_RX_Thiazide_RC0[[-0.01973889]]',
#  'Co_RX_Loop_RC0[[0.55117557]]',
#  'Co_RX_Potassium_RC0[[0.05869982]]',
#  'Co_RX_Nitrates_RC0[[0.05533271]]',
#  'Co_RX_Aliskiren_RC0[[-0.01416995]]',
#  'Co_RX_OthAntihypertensive_RC0[[-0.28460041]]',
#  'Co_RX_Antiarrhythmic_RC0[[-0.20934496]]',
#  'Co_RX_OthAnticoagulant_RC0[[0.02405992]]',
#  'Co_RX_Insulin_RC0[[0.07501322]]',
#  'Co_RX_Noninsulin_RC0[[-0.15358064]]',
#  'Co_RX_Digoxin_RC0[[0.19885043]]',
#  'Co_RX_Statin_RC0[[-0.30767641]]',
#  'Co_RX_Lipid_RC0[[-0.35241734]]',
#  'Co_RX_Lithium_RC0[[-0.06283603]]',
#  'Co_RX_Benzo_RC0[[0.1225435]]',
#  'Co_RX_ZDrugs_RC0[[-0.08366334]]',
#  'Co_RX_OthAnxiolytic_RC0[[0.16258878]]',
#  'Co_RX_Barbiturate_RC0[[-0.00013503]]',
#  'Co_RX_Dementia_RC0[[0.33097535]]',
#  'Co_RX_Hormone_RC0[[-0.41344619]]',
#  'Co_RX_Osteoporosis_RC0[[-0.00368805]]',
#  'Co_N_Drugs_RC0[[0.00100066]]',
#  'Co_N_Hosp_RC0[[-0.01925241]]',
#  'Co_Total_HospLOS_RC0[[0.00134245]]',
#  'Co_N_MDVisit_RC0[[0.01127701]]',
#  'Co_RX_AnyAspirin_RC0[[-0.10987988]]',
#  'Co_RX_AspirinMono_RC0[[-0.04278203]]',
#  'Co_RX_ClopidogrelMono_RC0[[-0.03703304]]',
#  'Co_RX_AspirinClopidogrel_RC0[[-0.06370743]]',
#  'Co_RX_DM_RC0[[0.09760962]]',
#  'Co_RX_Antipsychotic_RC0[[0.15490278]]']

# %% [markdown]
# # High Continuity

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_high_sm,out_train_death_high_sm = sm.fit_resample(co_train_high, out_train_death_high)

best_clf = lr(co_train_high_sm, out_train_death_high_sm)

train_scores(co_train_high_sm, out_train_death_high_sm)

print()

train_scores(co_train_high, out_train_death_high)

print()

test_scores(co_validation_high, out_validation_death_high)

comb = [] 
for i in range(len(predictor_variable_claims)):
    comb.append(predictor_variable_claims[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.
#  'Co_OthPain_RC0[[0.24287178]]',
#  'Co_GeneralizedPain_RC0[[0.11743381]]',
#  'Co_PainDisorder_RC0[[-0.02452051]]',
#  'Co_Falls_RC0[[0.39014322]]',
#  'Co_CoagulationDisorder_RC0[[-0.02863383]]',
#  'Co_WhiteBloodCell_RC0[[0.29024649]]',
#  'Co_Parkinson_RC0[[0.14055552]]',
#  'Co_Anemia_RC0[[0.49860113]]',
#  'Co_UrinaryIncontinence_RC0[[0.04485784]]',
#  'Co_DecubitusUlcer_RC0[[0.36130297]]',
#  'Co_Oxygen_RC0[[0.31482355]]',
#  'Co_Mammography_RC0[[-0.96625331]]',
#  'Co_PapTest_RC0[[-0.47304413]]',
#  'Co_PSATest_RC0[[-0.52088609]]',
#  'Co_Colonoscopy_RC0[[-0.52400636]]',
#  'Co_FecalOccultTest_RC0[[-0.02191664]]',
#  'Co_FluShot_RC0[[-0.27911697]]',
#  'Co_PneumococcalVaccine_RC0[[-0.31761253]]',
#  'Co_RenalDysfunction_RC0[[0.28840197]]',
#  'Co_Valvular_RC0[[-0.03327152]]',
#  'Co_Hosp_Prior30Days_RC0[[0.78629547]]',
#  'Co_RX_Antibiotic_RC0[[-0.38036667]]',
#  'Co_RX_Corticosteroid_RC0[[0.39012589]]',
#  'Co_RX_Aspirin_RC0[[-0.08254135]]',
#  'Co_RX_Dipyridamole_RC0[[-0.04900002]]',
#  'Co_RX_Clopidogrel_RC0[[0.02437916]]',
#  'Co_RX_Prasugrel_RC0[[-0.02248637]]',
#  'Co_RX_Cilostazol_RC0[[0.0984012]]',
#  'Co_RX_Ticlopidine_RC0[[0.00988277]]',
#  'Co_RX_Ticagrelor_RC0[[-0.06270738]]',
#  'Co_RX_OthAntiplatelet_RC0[[0.10828397]]',
#  'Co_RX_NSAIDs_RC0[[-0.12081342]]',
#  'Co_RX_Opioid_RC0[[0.02586373]]',
#  'Co_RX_Antidepressant_RC0[[0.24873015]]',
#  'Co_RX_AAntipsychotic_RC0[[0.11074292]]',
#  'Co_RX_TAntipsychotic_RC0[[0.0625538]]',
#  'Co_RX_Anticonvulsant_RC0[[0.06682364]]',
#  'Co_RX_PPI_RC0[[0.10723093]]',
#  'Co_RX_H2Receptor_RC0[[0.11880954]]',
#  'Co_RX_OthGastro_RC0[[-0.30148335]]',
#  'Co_RX_ACE_RC0[[-0.3144396]]',
#  'Co_RX_ARB_RC0[[-0.4623285]]',
#  'Co_RX_BBlocker_RC0[[0.21923442]]',
#  'Co_RX_CCB_RC0[[-0.06350056]]',
#  'Co_RX_Thiazide_RC0[[0.00734669]]',
#  'Co_RX_Loop_RC0[[0.43540383]]',
#  'Co_RX_Potassium_RC0[[0.04762604]]',
#  'Co_RX_Nitrates_RC0[[0.11525463]]',
#  'Co_RX_Aliskiren_RC0[[0.00201463]]',
#  'Co_RX_OthAntihypertensive_RC0[[0.01581531]]',
#  'Co_RX_Antiarrhythmic_RC0[[0.03773384]]',
#  'Co_RX_OthAnticoagulant_RC0[[-0.00273323]]',
#  'Co_RX_Insulin_RC0[[-0.01471325]]',
#  'Co_RX_Noninsulin_RC0[[-0.18043512]]',
#  'Co_RX_Digoxin_RC0[[0.21893487]]',
#  'Co_RX_Statin_RC0[[-0.19910813]]',
#  'Co_RX_Lipid_RC0[[-0.41788221]]',
#  'Co_RX_Lithium_RC0[[-0.07235031]]',
#  'Co_RX_Benzo_RC0[[0.11614779]]',
#  'Co_RX_ZDrugs_RC0[[-0.11791383]]',
#  'Co_RX_OthAnxiolytic_RC0[[0.20319922]]',
#  'Co_RX_Barbiturate_RC0[[-0.00064406]]',
#  'Co_RX_Dementia_RC0[[0.35601384]]',
#  'Co_RX_Hormone_RC0[[-0.46170423]]',
#  'Co_RX_Osteoporosis_RC0[[0.2041442]]',
#  'Co_N_Drugs_RC0[[0.00290525]]',
#  'Co_N_Hosp_RC0[[-0.04899838]]',
#  'Co_Total_HospLOS_RC0[[0.00544603]]',
#  'Co_N_MDVisit_RC0[[0.02225897]]',
#  'Co_RX_AnyAspirin_RC0[[-0.08142551]]',
#  'Co_RX_AspirinMono_RC0[[-0.02210457]]',
#  'Co_RX_ClopidogrelMono_RC0[[-0.125588]]',
#  'Co_RX_AspirinClopidogrel_RC0[[-0.04636216]]',
#  'Co_RX_DM_RC0[[0.04770377]]',
#  'Co_RX_Antipsychotic_RC0[[0.17395206]]']

# %% [markdown]
# # Low Continuity

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_low_sm,out_train_death_low_sm = sm.fit_resample(co_train_low,out_train_death_low)

best_clf = lr(co_train_low_sm, out_train_death_low_sm)

train_scores(co_train_low_sm, out_train_death_low_sm)

print()

train_scores(co_train_low, out_train_death_low)

print()

test_scores(co_validation_low, out_validation_death_low)

comb = [] 
for i in range(len(predictor_variable_claims)):
    comb.append(predictor_variable_claims[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7788525193085694
# 0.7803951645301486
# 0.7788389302360478
# 0.8536947726357544
# 7.6382546088203895
#
# 0.7698777253024519
# 0.44168890284099827
# 0.6957297787119086
# 0.8413826164212612
# 7.9483022570955395
#
# 0.7441305592670356
# 0.43640950178684046
# 0.6781363379721603
# 0.8125143554803129
# 8.837593680551565
# ['Co_CAD_RC0[[0.05349063]]',
#  'Co_Embolism_RC0[[0.10628089]]',
#  'Co_DVT_RC0[[-0.15588901]]',
#  'Co_PE_RC0[[0.05318343]]',
#  'Co_AFib_RC0[[0.13749864]]',
#  'Co_Hypertension_RC0[[-0.38150004]]',
#  'Co_Hyperlipidemia_RC0[[-0.19998624]]',
#  'Co_Atherosclerosis_RC0[[0.00825536]]',
#  'Co_HF_RC0[[0.50598345]]',
#  'Co_HemoStroke_RC0[[0.66657584]]',
#  'Co_IscheStroke_RC0[[0.35537951]]',
#  'Co_OthStroke_RC0[[-0.17831155]]',
#  'Co_TIA_RC0[[-0.30303577]]',
#  'Co_COPD_RC0[[0.27376913]]',
#  'Co_Asthma_RC0[[-0.25798179]]',
#  'Co_Pneumonia_RC0[[0.52195515]]',
#  'Co_Alcoholabuse_RC0[[-0.37592493]]',
#  'Co_Drugabuse_RC0[[-0.11230186]]',
#  'Co_Epilepsy_RC0[[-0.07263205]]',
#  'Co_Cancer_RC0[[0.43068028]]',
#  'Co_MorbidObesity_RC0[[-0.12566446]]',
#  'Co_Dementia_RC0[[0.79213583]]',
#  'Co_Depression_RC0[[-0.16321488]]',
#  'Co_Bipolar_RC0[[-0.2045149]]',
#  'Co_Psychosis_RC0[[0.00997774]]',
#  'Co_Personalitydisorder_RC0[[0.02168755]]',
#  'Co_Adjustmentdisorder_RC0[[-0.10943987]]',
#  'Co_Anxiety_RC0[[0.14321729]]',
#  'Co_Generalizedanxiety_RC0[[-0.24505292]]',
#  'Co_OldMI_RC0[[-0.09450679]]',
#  'Co_AcuteMI_RC0[[0.1650747]]',
#  'Co_PUD_RC0[[0.05765644]]',
#  'Co_UpperGIbleed_RC0[[0.07263608]]',
#  'Co_LowerGIbleed_RC0[[0.27145704]]',
#  'Co_Urogenitalbleed_RC0[[0.06357959]]',
#  'Co_Othbleed_RC0[[0.02558023]]',
#  'Co_PVD_RC0[[0.28559723]]',
#  'Co_LiverDisease_RC0[[0.51660394]]',
#  'Co_MRI_RC0[[-0.21390298]]',
#  'Co_ESRD_RC0[[0.17695823]]',
#  'Co_Obesity_RC0[[-0.47233626]]',
#  'Co_Sepsis_RC0[[0.11566801]]',
#  'Co_Osteoarthritis_RC0[[-0.27350207]]',
#  'Co_RA_RC0[[-0.09580283]]',
#  'Co_NeuroPain_RC0[[-0.14229663]]',
#  'Co_NeckPain_RC0[[-0.0254224]]',
#  'Co_OthArthritis_RC0[[0.00560073]]',
#  'Co_Osteoporosis_RC0[[-0.02183761]]',
#  'Co_Fibromyalgia_RC0[[-0.21553972]]',
#  'Co_Migraine_RC0[[-0.16460739]]',
#  'Co_Headache_RC0[[-0.09663388]]',
#  'Co_OthPain_RC0[[-0.06268923]]',
#  'Co_GeneralizedPain_RC0[[0.02090063]]',
#  'Co_PainDisorder_RC0[[-0.00025579]]',
#  'Co_Falls_RC0[[0.1914949]]',
#  'Co_CoagulationDisorder_RC0[[0.04128846]]',
#  'Co_WhiteBloodCell_RC0[[0.17541337]]',
#  'Co_Parkinson_RC0[[0.04711614]]',
#  'Co_Anemia_RC0[[0.30197107]]',
#  'Co_UrinaryIncontinence_RC0[[0.19581247]]',
#  'Co_DecubitusUlcer_RC0[[0.36643621]]',
#  'Co_Oxygen_RC0[[0.33592266]]',
#  'Co_Mammography_RC0[[-0.69220215]]',
#  'Co_PapTest_RC0[[-0.35069262]]',
#  'Co_PSATest_RC0[[-0.38000387]]',
#  'Co_Colonoscopy_RC0[[-0.4647525]]',
#  'Co_FecalOccultTest_RC0[[-0.29239315]]',
#  'Co_FluShot_RC0[[-0.03601333]]',
#  'Co_PneumococcalVaccine_RC0[[-0.04448813]]',
#  'Co_RenalDysfunction_RC0[[0.5070635]]',
#  'Co_Valvular_RC0[[0.01934511]]',
#  'Co_Hosp_Prior30Days_RC0[[1.30447216]]',
#  'Co_RX_Antibiotic_RC0[[-0.10718037]]',
#  'Co_RX_Corticosteroid_RC0[[0.17639579]]',
#  'Co_RX_Aspirin_RC0[[-0.04375111]]',
#  'Co_RX_Dipyridamole_RC0[[0.06992681]]',
#  'Co_RX_Clopidogrel_RC0[[-0.01008669]]',
#  'Co_RX_Prasugrel_RC0[[-0.02619247]]',
#  'Co_RX_Cilostazol_RC0[[0.06757032]]',
#  'Co_RX_Ticlopidine_RC0[[0.00857737]]',
#  'Co_RX_Ticagrelor_RC0[[-0.00847638]]',
#  'Co_RX_OthAntiplatelet_RC0[[0.07614769]]',
#  'Co_RX_NSAIDs_RC0[[-0.11969423]]',
#  'Co_RX_Opioid_RC0[[0.27460561]]',
#  'Co_RX_Antidepressant_RC0[[0.20063796]]',
#  'Co_RX_AAntipsychotic_RC0[[0.00221364]]',
#  'Co_RX_TAntipsychotic_RC0[[0.10053308]]',
#  'Co_RX_Anticonvulsant_RC0[[0.1587627]]',
#  'Co_RX_PPI_RC0[[-0.06154805]]',
#  'Co_RX_H2Receptor_RC0[[0.07838468]]',
#  'Co_RX_OthGastro_RC0[[-0.18359395]]',
#  'Co_RX_ACE_RC0[[0.03143243]]',
#  'Co_RX_ARB_RC0[[-0.15536017]]',
#  'Co_RX_BBlocker_RC0[[0.24324216]]',
#  'Co_RX_CCB_RC0[[0.08845516]]',
#  'Co_RX_Thiazide_RC0[[0.07480658]]',
#  'Co_RX_Loop_RC0[[0.62176075]]',
#  'Co_RX_Potassium_RC0[[0.17985392]]',
#  'Co_RX_Nitrates_RC0[[-0.04094313]]',
#  'Co_RX_Aliskiren_RC0[[-0.03928719]]',
#  'Co_RX_OthAntihypertensive_RC0[[-0.46498491]]',
#  'Co_RX_Antiarrhythmic_RC0[[-0.36402387]]',
#  'Co_RX_OthAnticoagulant_RC0[[0.02391375]]',
#  'Co_RX_Insulin_RC0[[0.23748384]]',
#  'Co_RX_Noninsulin_RC0[[-0.18489289]]',
#  'Co_RX_Digoxin_RC0[[0.23921199]]',
#  'Co_RX_Statin_RC0[[-0.42802131]]',
#  'Co_RX_Lipid_RC0[[-0.22525173]]',
#  'Co_RX_Lithium_RC0[[-0.02019894]]',
#  'Co_RX_Benzo_RC0[[0.07648037]]',
#  'Co_RX_ZDrugs_RC0[[0.02500722]]',
#  'Co_RX_OthAnxiolytic_RC0[[-0.15283037]]',
#  'Co_RX_Barbiturate_RC0[[0.]]',
#  'Co_RX_Dementia_RC0[[0.3070458]]',
#  'Co_RX_Hormone_RC0[[-0.28535767]]',
#  'Co_RX_Osteoporosis_RC0[[-0.06719424]]',
#  'Co_N_Drugs_RC0[[-0.0070663]]',
#  'Co_N_Hosp_RC0[[-0.01296296]]',
#  'Co_Total_HospLOS_RC0[[0.00045882]]',
#  'Co_N_MDVisit_RC0[[-0.01028641]]',
#  'Co_RX_AnyAspirin_RC0[[-0.06558982]]',
#  'Co_RX_AspirinMono_RC0[[-0.01699745]]',
#  'Co_RX_ClopidogrelMono_RC0[[0.037841]]',
#  'Co_RX_AspirinClopidogrel_RC0[[-0.04460067]]',
#  'Co_RX_DM_RC0[[0.15956793]]',
#  'Co_RX_Antipsychotic_RC0[[0.1407125]]']
