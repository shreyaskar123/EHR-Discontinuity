# %%
import pyreadstat
medicare,meta = pyreadstat.read_sas7bdat("/netapp2/home/se197/RPDR/Josh Lin/3_EHR_V2/CMS/Data/cohort.sas7bdat")

# %%
train_set = medicare[medicare.Hospital != 'BWH'] # MGH; n = 204014
validation_set = medicare[medicare.Hospital == 'BWH'] # BWH and Neither; n = 115726
import numpy as np

fifty_perc_EHR_cont = np.percentile(medicare['Cal_MPEC_R0'],50)
train_set_high = train_set[train_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
train_set_low= train_set[train_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

validation_set_high = validation_set[validation_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
validation_set_low = validation_set[validation_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

# %%
predictor_variable_claims = [
    'Co_CAD_RC0', 'Co_Embolism_RC0', 'Co_DVT_RC0', 'Co_PE_RC0', 'Co_AFib_RC0',
        'Co_Hypertension_RC0', 'Co_Hyperlipidemia_RC0', 'Co_Atherosclerosis_RC0',
        'Co_HF_RC0', 'Co_HemoStroke_RC0', 'Co_IscheStroke_RC0', 'Co_OthStroke_RC0',
        'Co_TIA_RC0', 'Co_COPD_RC0', 'Co_Asthma_RC0', 'Co_Pneumonia_RC0', 'Co_Alcoholabuse_RC0',
        'Co_Drugabuse_RC0', 'Co_Epilepsy_RC0', 'Co_Cancer_RC0', 'Co_MorbidObesity_RC0',
        'Co_Dementia_RC0', 'Co_Depression_RC0', 'Co_Bipolar_RC0', 'Co_Psychosis_RC0',
        'Co_Personalitydisorder_RC0', 'Co_Adjustmentdisorder_RC0', 'Co_Anxiety_RC0',
        'Co_Generalizedanxiety_RC0', 'Co_OldMI_RC0', 'Co_AcuteMI_RC0', 'Co_PUD_RC0',
        'Co_UpperGIbleed_RC0', 'Co_LowerGIbleed_RC0', 'Co_Urogenitalbleed_RC0',
        'Co_Othbleed_RC0', 'Co_PVD_RC0', 'Co_LiverDisease_RC0', 'Co_MRI_RC0',
        'Co_ESRD_RC0', 'Co_Obesity_RC0', 'Co_Sepsis_RC0', 'Co_Osteoarthritis_RC0',
        'Co_RA_RC0', 'Co_NeuroPain_RC0', 'Co_NeckPain_RC0', 'Co_OthArthritis_RC0',
        'Co_Osteoporosis_RC0', 'Co_Fibromyalgia_RC0', 'Co_Migraine_RC0', 'Co_Headache_RC0',
        'Co_OthPain_RC0', 'Co_GeneralizedPain_RC0', 'Co_PainDisorder_RC0',
        'Co_Falls_RC0', 'Co_CoagulationDisorder_RC0', 'Co_WhiteBloodCell_RC0', 'Co_Parkinson_RC0',
        'Co_Anemia_RC0', 'Co_UrinaryIncontinence_RC0', 'Co_DecubitusUlcer_RC0',
        'Co_Oxygen_RC0', 'Co_Mammography_RC0', 'Co_PapTest_RC0', 'Co_PSATest_RC0',
        'Co_Colonoscopy_RC0', 'Co_FecalOccultTest_RC0', 'Co_FluShot_RC0', 'Co_PneumococcalVaccine_RC0' , 'Co_RenalDysfunction_RC0', 'Co_Valvular_RC0', 'Co_Hosp_Prior30Days_RC0',
        'Co_RX_Antibiotic_RC0', 'Co_RX_Corticosteroid_RC0', 'Co_RX_Aspirin_RC0', 'Co_RX_Dipyridamole_RC0',
        'Co_RX_Clopidogrel_RC0', 'Co_RX_Prasugrel_RC0', 'Co_RX_Cilostazol_RC0', 'Co_RX_Ticlopidine_RC0',
        'Co_RX_Ticagrelor_RC0', 'Co_RX_OthAntiplatelet_RC0', 'Co_RX_NSAIDs_RC0',
        'Co_RX_Opioid_RC0', 'Co_RX_Antidepressant_RC0', 'Co_RX_AAntipsychotic_RC0', 'Co_RX_TAntipsychotic_RC0',
        'Co_RX_Anticonvulsant_RC0', 'Co_RX_PPI_RC0', 'Co_RX_H2Receptor_RC0', 'Co_RX_OthGastro_RC0',
        'Co_RX_ACE_RC0', 'Co_RX_ARB_RC0', 'Co_RX_BBlocker_RC0', 'Co_RX_CCB_RC0', 'Co_RX_Thiazide_RC0',
        'Co_RX_Loop_RC0', 'Co_RX_Potassium_RC0', 'Co_RX_Nitrates_RC0', 'Co_RX_Aliskiren_RC0',
        'Co_RX_OthAntihypertensive_RC0', 'Co_RX_Antiarrhythmic_RC0', 'Co_RX_OthAnticoagulant_RC0',
        'Co_RX_Insulin_RC0', 'Co_RX_Noninsulin_RC0', 'Co_RX_Digoxin_RC0', 'Co_RX_Statin_RC0',
        'Co_RX_Lipid_RC0', 'Co_RX_Lithium_RC0', 'Co_RX_Benzo_RC0', 'Co_RX_ZDrugs_RC0',
        'Co_RX_OthAnxiolytic_RC0', 'Co_RX_Barbiturate_RC0', 'Co_RX_Dementia_RC0', 'Co_RX_Hormone_RC0',
        'Co_RX_Osteoporosis_RC0', 'Co_N_Drugs_RC0', 'Co_N_Hosp_RC0', 'Co_Total_HospLOS_RC0',
        'Co_N_MDVisit_RC0', 'Co_RX_AnyAspirin_RC0', 'Co_RX_AspirinMono_RC0', 'Co_RX_ClopidogrelMono_RC0',
        'Co_RX_AspirinClopidogrel_RC0', 'Co_RX_DM_RC0', 'Co_RX_Antipsychotic_RC0'
]


co_train_gpop = train_set[predictor_variable_claims]
co_train_high = train_set_high[predictor_variable_claims]
co_train_low = train_set_low[predictor_variable_claims]

co_validation_gpop = validation_set[predictor_variable_claims]
co_validation_high = validation_set_high[predictor_variable_claims]
co_validation_low = validation_set_low[predictor_variable_claims]

# %%
out_train_hemorrhage_gpop = train_set['Out_Hemorrhage_RC1']
out_train_hemorrhage_high = train_set_high['Out_Hemorrhage_RC1']
out_train_hemorrhage_low = train_set_low['Out_Hemorrhage_RC1']

out_validation_hemorrhage_gpop = validation_set['Out_Hemorrhage_RC1']
out_validation_hemorrhage_high = validation_set_high['Out_Hemorrhage_RC1']
out_validation_hemorrhage_low = validation_set_low['Out_Hemorrhage_RC1']

# %% [markdown]
# # Template LR

# %%
def lr(X_train, y_train):
    from sklearn.linear_model import Lasso
    from sklearn.decomposition import PCA
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler 

    model = LogisticRegression()
    param_grid = [
        {'C' : np.logspace(-4, 4, 20)}
        ]
    clf = GridSearchCV(model, param_grid, cv = 5, verbose = True, n_jobs = -1)
    best_clf = clf.fit(X_train, y_train)
    return best_clf

# %%
def train_scores(X_train,y_train):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_train)
    actual = y_train
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.decision_function(X_train)))
    print(log_loss(actual,pred))
    
def test_scores(X_test,y_test):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_test)
    actual = y_test
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.decision_function(X_test)))
    print(log_loss(actual,pred))

# %% [markdown]
# # General Population

# %%
best_clf = lr(co_train_gpop, out_train_hemorrhage_gpop)

train_scores(co_train_gpop, out_train_hemorrhage_gpop)

print()

test_scores(co_validation_gpop, out_validation_hemorrhage_gpop)

comb = [] 
for i in range(len(predictor_variable_claims)):
    comb.append(predictor_variable_claims[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9461948689795798
# 0.005075682044774767
# 0.4958868423807129
# 0.7361344867550276
# 1.858363608695437
#
# 0.9314415083905087
# 0.006511394941147007
# 0.49469651156131916
# 0.7261685831502179
# 2.3679266535016463
# ['Co_CAD_RC0[[0.08923877]]',
#  'Co_Embolism_RC0[[0.01754832]]',
#  'Co_DVT_RC0[[0.00810143]]',
#  'Co_PE_RC0[[0.04336631]]',
#  'Co_AFib_RC0[[0.19044758]]',
#  'Co_Hypertension_RC0[[0.13273492]]',
#  'Co_Hyperlipidemia_RC0[[-0.05810461]]',
#  'Co_Atherosclerosis_RC0[[0.09307252]]',
#  'Co_HF_RC0[[0.09369982]]',
#  'Co_HemoStroke_RC0[[-8.11859117e-05]]',
#  'Co_IscheStroke_RC0[[0.04777093]]',
#  'Co_OthStroke_RC0[[0.01991487]]',
#  'Co_TIA_RC0[[0.00987805]]',
#  'Co_COPD_RC0[[0.11618078]]',
#  'Co_Asthma_RC0[[0.06417064]]',
#  'Co_Pneumonia_RC0[[0.01986059]]',
#  'Co_Alcoholabuse_RC0[[0.06542793]]',
#  'Co_Drugabuse_RC0[[0.00727018]]',
#  'Co_Epilepsy_RC0[[0.01367183]]',
#  'Co_Cancer_RC0[[0.07799843]]',
#  'Co_MorbidObesity_RC0[[0.01759022]]',
#  'Co_Dementia_RC0[[0.06293216]]',
#  'Co_Depression_RC0[[0.00023724]]',
#  'Co_Bipolar_RC0[[-0.00610539]]',
#  'Co_Psychosis_RC0[[0.04037896]]',
#  'Co_Personalitydisorder_RC0[[-0.00809485]]',
#  'Co_Adjustmentdisorder_RC0[[-0.01299573]]',
#  'Co_Anxiety_RC0[[0.00094485]]',
#  'Co_Generalizedanxiety_RC0[[0.01118106]]',
#  'Co_OldMI_RC0[[0.00318899]]',
#  'Co_AcuteMI_RC0[[0.01533487]]',
#  'Co_PUD_RC0[[0.0328949]]',
#  'Co_UpperGIbleed_RC0[[0.06983166]]',
#  'Co_LowerGIbleed_RC0[[0.17686182]]',
#  'Co_Urogenitalbleed_RC0[[0.05860079]]',
#  'Co_Othbleed_RC0[[0.13680486]]',
]',
#  'Co_RX_Antiarrhythmic_RC0[[-0.00431973]]',
#  'Co_RX_OthAnticoagulant_RC0[[-0.00526196]]',
#  'Co_RX_Insulin_RC0[[0.01347631]]',
#  'Co_RX_Noninsulin_RC0[[0.00453375]]',
#  'Co_RX_Digoxin_RC0[[0.00641531]]',
#  'Co_RX_Statin_RC0[[-0.01845338]]',
#  'Co_RX_Lipid_RC0[[-0.01226482]]',
#  'Co_RX_Lithium_RC0[[-0.00151055]]',
#  'Co_RX_Benzo_RC0[[-0.00857476]]',
#  'Co_RX_ZDrugs_RC0[[-0.05362725]]',
#  'Co_RX_OthAnxiolytic_RC0[[-0.0131042]]',
#  'Co_RX_Barbiturate_RC0[[0.00012795]]',
#  'Co_RX_Dementia_RC0[[0.01634265]]',
#  'Co_RX_Hormone_RC0[[-0.06831639]]',
#  'Co_RX_Osteoporosis_RC0[[-0.04521371]]',
#  'Co_N_Drugs_RC0[[-0.00140845]]',
#  'Co_N_Hosp_RC0[[0.07538382]]',
#  'Co_Total_HospLOS_RC0[[0.00366304]]',
#  'Co_N_MDVisit_RC0[[0.01429202]]',
#  'Co_RX_AnyAspirin_RC0[[0.00359]]',
#  'Co_RX_AspirinMono_RC0[[-0.01221829]]',
#  'Co_RX_ClopidogrelMono_RC0[[0.02245617]]',
#  'Co_RX_AspirinClopidogrel_RC0[[0.01724763]]',
#  'Co_RX_DM_RC0[[0.0267906]]',
#  'Co_RX_Antipsychotic_RC0[[-0.00775672]]']

# %% [markdown]
# # High Continuity

# %%
best_clf = lr(co_train_high, out_train_hemorrhage_high)

train_scores(co_train_high, out_train_hemorrhage_high)

print()

test_scores(co_validation_high, out_validation_hemorrhage_high)

comb = [] 
for i in range(len(predictor_variable_claims)):
    comb.append(predictor_variable_claims[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9533156951438081
# 0.011247238401285397
# 0.4985974990946247
# 0.7585207473421411
# 1.612419024384873
#
# 0.9359947163719087
# 0.009538950715421303
# 0.4960890831741011
# 0.7375374142793024
# 2.2106646252720026
# ['Co_CAD_RC0[[0.08542777]]',
#  'Co_Embolism_RC0[[0.0445949]]',
#  'Co_DVT_RC0[[0.04619904]]',
#  'Co_PE_RC0[[0.06055766]]',
#  'Co_AFib_RC0[[0.29383891]]',
#  'Co_Hypertension_RC0[[0.09942692]]',
#  'Co_Hyperlipidemia_RC0[[-0.12918729]]',
#  'Co_Atherosclerosis_RC0[[0.11056518]]',
#  'Co_HF_RC0[[0.11066962]]',
#  'Co_HemoStroke_RC0[[0.01210532]]',
#  'Co_IscheStroke_RC0[[0.03901561]]',
#  'Co_OthStroke_RC0[[0.02731598]]',
#  'Co_TIA_RC0[[-0.03032815]]',
#  'Co_COPD_RC0[[0.15420753]]',
#  'Co_Asthma_RC0[[0.05657408]]',
#  'Co_Pneumonia_RC0[[-0.05208414]]',
#  'Co_Alcoholabuse_RC0[[0.15573655]]',
#  'Co_Drugabuse_RC0[[-0.00203311]]',
#  'Co_Epilepsy_RC0[[0.00299374]]',
#  'Co_Cancer_RC0[[0.09779209]]',
#  'Co_MorbidObesity_RC0[[-0.01106324]]',
#  'Co_Dementia_RC0[[0.06161575]]',
#  'Co_Depression_RC0[[-0.05117566]]',
#  'Co_Bipolar_RC0[[-0.02100988]]',
#  'Co_Psychosis_RC0[[0.07449933]]',
]',
#  'Co_RX_AAntipsychotic_RC0[[-0.01920376]]',
#  'Co_RX_TAntipsychotic_RC0[[0.01333099]]',
#  'Co_RX_Anticonvulsant_RC0[[0.08951087]]',
#  'Co_RX_PPI_RC0[[0.03459027]]',
#  'Co_RX_H2Receptor_RC0[[-0.01139119]]',
#  'Co_RX_OthGastro_RC0[[0.01284331]]',
#  'Co_RX_ACE_RC0[[0.0546636]]',
#  'Co_RX_ARB_RC0[[0.02671705]]',
#  'Co_RX_BBlocker_RC0[[0.05468669]]',
#  'Co_RX_CCB_RC0[[0.07724416]]',
#  'Co_RX_Thiazide_RC0[[0.02463385]]',
#  'Co_RX_Loop_RC0[[0.16463752]]',
#  'Co_RX_Potassium_RC0[[0.10613628]]',
#  'Co_RX_Nitrates_RC0[[-0.01607971]]',
#  'Co_RX_Aliskiren_RC0[[-0.01522518]]',
#  'Co_RX_OthAntihypertensive_RC0[[0.01683083]]',
#  'Co_RX_Antiarrhythmic_RC0[[-0.01302019]]',
#  'Co_RX_OthAnticoagulant_RC0[[-0.01943134]]',
#  'Co_RX_Insulin_RC0[[0.00133976]]',
#  'Co_RX_Noninsulin_RC0[[0.01963835]]',
#  'Co_RX_Digoxin_RC0[[-0.00979977]]',
#  'Co_RX_Statin_RC0[[-0.0029682]]',
#  'Co_RX_Lipid_RC0[[-0.01324529]]',
#  'Co_RX_Lithium_RC0[[-0.0048749]]',
#  'Co_RX_Benzo_RC0[[-0.05983452]]',
#  'Co_RX_ZDrugs_RC0[[-0.10104915]]',
#  'Co_RX_OthAnxiolytic_RC0[[-0.04910325]]',
#  'Co_RX_Barbiturate_RC0[[0.00079023]]',
#  'Co_RX_Dementia_RC0[[0.07574219]]',
#  'Co_RX_Hormone_RC0[[-0.16642479]]',
#  'Co_RX_Osteoporosis_RC0[[-0.09369454]]',
#  'Co_N_Drugs_RC0[[0.00012205]]',
#  'Co_N_Hosp_RC0[[0.03747095]]',
#  'Co_Total_HospLOS_RC0[[0.00106284]]',
#  'Co_N_MDVisit_RC0[[0.01300757]]',
#  'Co_RX_AnyAspirin_RC0[[0.00893759]]',
#  'Co_RX_AspirinMono_RC0[[-0.0258216]]',
#  'Co_RX_ClopidogrelMono_RC0[[0.01740133]]',
#  'Co_RX_AspirinClopidogrel_RC0[[0.05226605]]',
#  'Co_RX_DM_RC0[[0.02690244]]',
#  'Co_RX_Antipsychotic_RC0[[0.03181544]]']

# %% [markdown]
# # Low Continuity

# %%
best_clf = lr(co_train_low, out_train_hemorrhage_low)

train_scores(co_train_low, out_train_hemorrhage_low)

print()

test_scores(co_validation_low, out_validation_hemorrhage_low)

comb = [] 
for i in range(len(predictor_variable_claims)):
    comb.append(predictor_variable_claims[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 0.9387485922423676
# 0.007235652030915968
# 0.4957473237832538
# 0.7162095506769646
# 2.115548895457701
#
# 0.9246075938727911
# 0.004439511653718091
# 0.4932704283709289
# 0.7056018246468698
# 2.6039617091235954
# ['Co_CAD_RC0[[0.0823832]]',
#  'Co_Embolism_RC0[[0.00901849]]',
#  'Co_DVT_RC0[[-0.00063229]]',
#  'Co_PE_RC0[[0.032656]]',
#  'Co_AFib_RC0[[0.13180075]]',
#  'Co_Hypertension_RC0[[0.09294752]]',
#  'Co_Hyperlipidemia_RC0[[-0.02838337]]',
#  'Co_Atherosclerosis_RC0[[0.08261391]]',
#  'Co_HF_RC0[[0.07160415]]',
#  'Co_HemoStroke_RC0[[-0.00086322]]',
#  'Co_IscheStroke_RC0[[0.04632658]]',
#  'Co_OthStroke_RC0[[0.01596652]]',
#  'Co_TIA_RC0[[0.01988077]]',
#  'Co_COPD_RC0[[0.08326105]]',
#  'Co_Asthma_RC0[[0.04820316]]',
#  'Co_Pneumonia_RC0[[0.0353952]]',
#  'Co_Alcoholabuse_RC0[[0.03109203]]',
#  'Co_Drugabuse_RC0[[0.0061072]]',
#  'Co_Epilepsy_RC0[[0.01203659]]',
#  'Co_Cancer_RC0[[0.06363541]]',
#  'Co_MorbidObesity_RC0[[0.02109739]]',
#  'Co_Dementia_RC0[[0.04220929]]',
#  'Co_Depression_RC0[[0.01335027]]',
#  'Co_Bipolar_RC0[[-0.005396]]',
#  'Co_Psychosis_RC0[[0.01828931]]',
#  'Co_Personalitydisorder_RC0[[-0.00922539]]',
#  'Co_Adjustmentdisorder_RC0[[-0.00467344]]',
#  'Co_Anxiety_RC0[[-0.01195189]]',
#  'Co_Generalizedanxiety_RC0[[-0.00214235]]',
#  'Co_OldMI_RC0[[0.00771562]]',
#  'Co_AcuteMI_RC0[[0.02102907]]',
#  'Co_PUD_RC0[[0.01748217]]',
#  'Co_UpperGIbleed_RC0[[0.04501198]]',
#  'Co_LowerGIbleed_RC0[[0.12670012]]',
#  'Co_Urogenitalbleed_RC0[[0.03073609]]',
#  'Co_Othbleed_RC0[[0.12354554]]',
#  'Co_PVD_RC0[[0.06286143]]',
#  'Co_LiverDisease_RC0[[0.07859156]]',
#  'Co_MRI_RC0[[0.04894058]]',
#  'Co_ESRD_RC0[[0.01919409]]',
#  'Co_Obesity_RC0[[0.02506878]]',
#  'Co_Sepsis_RC0[[-0.00934969]]',
#  'Co_Osteoarthritis_RC0[[0.04734581]]',
#  'Co_RA_RC0[[0.00430564]]',
#  'Co_NeuroPain_RC0[[0.03438796]]',
#  'Co_NeckPain_RC0[[0.01646929]]',
#  'Co_OthArthritis_RC0[[0.02650249]]',
#  'Co_Osteoporosis_RC0[[0.03860427]]',
#  'Co_Fibromyalgia_RC0[[-0.01663686]]',
#  'Co_Migraine_RC0[[-0.01903709]]',
#  'Co_Headache_RC0[[-0.00269771]]',
#  'Co_OthPain_RC0[[0.04160664]]',
#  'Co_GeneralizedPain_RC0[[0.0214973]]',
#  'Co_PainDisorder_RC0[[0.00128782]]',
#  'Co_Falls_RC0[[0.06802429]]',
#  'Co_CoagulationDisorder_RC0[[0.0686573]]',
#  'Co_WhiteBloodCell_RC0[[0.04173207]]',
#  'Co_Parkinson_RC0[[0.01200521]]',
#  'Co_Anemia_RC0[[0.22216195]]',
#  'Co_UrinaryIncontinence_RC0[[0.01902217]]',
#  'Co_DecubitusUlcer_RC0[[0.00777047]]',
#  'Co_Oxygen_RC0[[0.02584061]]',
#  'Co_Mammography_RC0[[-0.10398726]]',
#  'Co_PapTest_RC0[[-0.06241668]]',
#  'Co_PSATest_RC0[[-0.03983018]]',
#  'Co_Colonoscopy_RC0[[-0.00897326]]',
#  'Co_FecalOccultTest_RC0[[-0.01859028]]',
#  'Co_FluShot_RC0[[0.03293963]]',
#  'Co_PneumococcalVaccine_RC0[[0.12669937]]',
#  'Co_RenalDysfunction_RC0[[0.14863421]]',
#  'Co_Valvular_RC0[[0.07882545]]',
#  'Co_Hosp_Prior30Days_RC0[[0.16943636]]',
#  'Co_RX_Antibiotic_RC0[[-0.01903932]]',
#  'Co_RX_Corticosteroid_RC0[[0.00042632]]',
#  'Co_RX_Aspirin_RC0[[0.01551148]]',
#  'Co_RX_Dipyridamole_RC0[[0.00241776]]',
#  'Co_RX_Clopidogrel_RC0[[0.02140163]]',
#  'Co_RX_Prasugrel_RC0[[0.00185882]]',
#  'Co_RX_Cilostazol_RC0[[0.00572747]]',
#  'Co_RX_Ticlopidine_RC0[[0.00033646]]',
#  'Co_RX_Ticagrelor_RC0[[0.00431518]]',
#  'Co_RX_OthAntiplatelet_RC0[[0.00606393]]',
#  'Co_RX_NSAIDs_RC0[[-0.02571854]]',
#  'Co_RX_Opioid_RC0[[0.0413848]]',
#  'Co_RX_Antidepressant_RC0[[0.01395594]]',
#  'Co_RX_AAntipsychotic_RC0[[-0.02766897]]',
#  'Co_RX_TAntipsychotic_RC0[[-0.00635755]]',
#  'Co_RX_Anticonvulsant_RC0[[0.00171978]]',
#  'Co_RX_PPI_RC0[[0.01923992]]',
#  'Co_RX_H2Receptor_RC0[[0.00049393]]',
#  'Co_RX_OthGastro_RC0[[0.0126341]]',
#  'Co_RX_ACE_RC0[[0.01451744]]',
#  'Co_RX_ARB_RC0[[-0.00916481]]',
#  'Co_RX_BBlocker_RC0[[0.07125755]]',
#  'Co_RX_CCB_RC0[[0.03106479]]',
#  'Co_RX_Thiazide_RC0[[-0.03784345]]',
#  'Co_RX_Loop_RC0[[0.09304181]]',
#  'Co_RX_Potassium_RC0[[-0.00965448]]',
#  'Co_RX_Nitrates_RC0[[0.00753052]]',
#  'Co_RX_Aliskiren_RC0[[-0.00176604]]',
#  'Co_RX_OthAntihypertensive_RC0[[0.01268404]]',
#  'Co_RX_Antiarrhythmic_RC0[[-0.00322488]]',
#  'Co_RX_OthAnticoagulant_RC0[[-0.00115286]]',
#  'Co_RX_Insulin_RC0[[0.00871361]]',
#  'Co_RX_Noninsulin_RC0[[-0.0021714]]',
#  'Co_RX_Digoxin_RC0[[0.00518229]]',
#  'Co_RX_Statin_RC0[[-0.0207258]]',
#  'Co_RX_Lipid_RC0[[-0.00976467]]',
#  'Co_RX_Lithium_RC0[[-0.00135539]]',
#  'Co_RX_Benzo_RC0[[0.02085754]]',
#  'Co_RX_ZDrugs_RC0[[-0.03612309]]',
#  'Co_RX_OthAnxiolytic_RC0[[-0.00277063]]',
#  'Co_RX_Barbiturate_RC0[[-5.98473661e-05]]',
#  'Co_RX_Dementia_RC0[[-0.00666137]]',
#  'Co_RX_Hormone_RC0[[-0.03826465]]',
#  'Co_RX_Osteoporosis_RC0[[-0.03061584]]',
#  'Co_N_Drugs_RC0[[0.00803166]]',
#  'Co_N_Hosp_RC0[[0.08174937]]',
#  'Co_Total_HospLOS_RC0[[0.00477886]]',
#  'Co_N_MDVisit_RC0[[0.01315484]]',
#  'Co_RX_AnyAspirin_RC0[[0.01636814]]',
#  'Co_RX_AspirinMono_RC0[[0.00860869]]',
#  'Co_RX_ClopidogrelMono_RC0[[0.01879011]]',
#  'Co_RX_AspirinClopidogrel_RC0[[0.00668464]]',
#  'Co_RX_DM_RC0[[0.01592577]]',
#  'Co_RX_Antipsychotic_RC0[[-0.02686889]]']
