# %%
import pyreadstat
medicare,meta = pyreadstat.read_sas7bdat("/netapp2/home/se197/RPDR/Josh Lin/3_EHR_V2/CMS/Data/cohort.sas7bdat")

# %%
train_set = medicare[medicare.Hospital != 'BWH'] # MGH; n = 204014
validation_set = medicare[medicare.Hospital == 'BWH'] # BWH and Neither; n = 115726
import numpy as np

fifty_perc_EHR_cont = np.percentile(medicare['Cal_MPEC_RC0'],50)
train_set_high = train_set[train_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
train_set_low= train_set[train_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

validation_set_high = validation_set[validation_set.Cal_MPEC_RC0 >= fifty_perc_EHR_cont]
validation_set_low = validation_set[validation_set.Cal_MPEC_RC0 < fifty_perc_EHR_cont]

# %%
predictor_variable_claims = [
    'Co_CAD_RC0', 'Co_Embolism_RC0', 'Co_DVT_RC0', 'Co_PE_RC0', 'Co_AFib_RC0',
        'Co_Hypertension_RC0', 'Co_Hyperlipidemia_RC0', 'Co_Atherosclerosis_RC0',
        'Co_HF_RC0', 'Co_HemoStroke_RC0', 'Co_IscheStroke_RC0', 'Co_OthStroke_RC0',
        'Co_TIA_RC0', 'Co_COPD_RC0', 'Co_Asthma_RC0', 'Co_Pneumonia_RC0', 'Co_Alcoholabuse_RC0',
        'Co_Drugabuse_RC0', 'Co_Epilepsy_RC0', 'Co_Cancer_RC0', 'Co_MorbidObesity_RC0',
        'Co_Dementia_RC0', 'Co_Depression_RC0', 'Co_Bipolar_RC0', 'Co_Psychosis_RC0',
        'Co_Personalitydisorder_RC0', 'Co_Adjustmentdisorder_RC0', 'Co_Anxiety_RC0',
        'Co_Generalizedanxiety_RC0', 'Co_OldMI_RC0', 'Co_AcuteMI_RC0', 'Co_PUD_RC0',
        'Co_UpperGIbleed_RC0', 'Co_LowerGIbleed_RC0', 'Co_Urogenitalbleed_RC0',
        'Co_Othbleed_RC0', 'Co_PVD_RC0', 'Co_LiverDisease_RC0', 'Co_MRI_RC0',
        'Co_ESRD_RC0', 'Co_Obesity_RC0', 'Co_Sepsis_RC0', 'Co_Osteoarthritis_RC0',
        'Co_RA_RC0', 'Co_NeuroPain_RC0', 'Co_NeckPain_RC0', 'Co_OthArthritis_RC0',
        'Co_Osteoporosis_RC0', 'Co_Fibromyalgia_RC0', 'Co_Migraine_RC0', 'Co_Headache_RC0',
        'Co_OthPain_RC0', 'Co_GeneralizedPain_RC0', 'Co_PainDisorder_RC0',
        'Co_Falls_RC0', 'Co_CoagulationDisorder_RC0', 'Co_WhiteBloodCell_RC0', 'Co_Parkinson_RC0',
        'Co_Anemia_RC0', 'Co_UrinaryIncontinence_RC0', 'Co_DecubitusUlcer_RC0',
        'Co_Oxygen_RC0', 'Co_Mammography_RC0', 'Co_PapTest_RC0', 'Co_PSATest_RC0',
        'Co_Colonoscopy_RC0', 'Co_FecalOccultTest_RC0', 'Co_FluShot_RC0', 'Co_PneumococcalVaccine_RC0' , 'Co_RenalDysfunction_RC0', 'Co_Valvular_RC0', 'Co_Hosp_Prior30Days_RC0',
        'Co_RX_Antibiotic_RC0', 'Co_RX_Corticosteroid_RC0', 'Co_RX_Aspirin_RC0', 'Co_RX_Dipyridamole_RC0',
        'Co_RX_Clopidogrel_RC0', 'Co_RX_Prasugrel_RC0', 'Co_RX_Cilostazol_RC0', 'Co_RX_Ticlopidine_RC0',
        'Co_RX_Ticagrelor_RC0', 'Co_RX_OthAntiplatelet_RC0', 'Co_RX_NSAIDs_RC0',
        'Co_RX_Opioid_RC0', 'Co_RX_Antidepressant_RC0', 'Co_RX_AAntipsychotic_RC0', 'Co_RX_TAntipsychotic_RC0',
        'Co_RX_Anticonvulsant_RC0', 'Co_RX_PPI_RC0', 'Co_RX_H2Receptor_RC0', 'Co_RX_OthGastro_RC0',
        'Co_RX_ACE_RC0', 'Co_RX_ARB_RC0', 'Co_RX_BBlocker_RC0', 'Co_RX_CCB_RC0', 'Co_RX_Thiazide_RC0',
        'Co_RX_Loop_RC0', 'Co_RX_Potassium_RC0', 'Co_RX_Nitrates_RC0', 'Co_RX_Aliskiren_RC0',
        'Co_RX_OthAntihypertensive_RC0', 'Co_RX_Antiarrhythmic_RC0', 'Co_RX_OthAnticoagulant_RC0',
        'Co_RX_Insulin_RC0', 'Co_RX_Noninsulin_RC0', 'Co_RX_Digoxin_RC0', 'Co_RX_Statin_RC0',
        'Co_RX_Lipid_RC0', 'Co_RX_Lithium_RC0', 'Co_RX_Benzo_RC0', 'Co_RX_ZDrugs_RC0',
        'Co_RX_OthAnxiolytic_RC0', 'Co_RX_Barbiturate_RC0', 'Co_RX_Dementia_RC0', 'Co_RX_Hormone_RC0',
        'Co_RX_Osteoporosis_RC0', 'Co_N_Drugs_RC0', 'Co_N_Hosp_RC0', 'Co_Total_HospLOS_RC0',
        'Co_N_MDVisit_RC0', 'Co_RX_AnyAspirin_RC0', 'Co_RX_AspirinMono_RC0', 'Co_RX_ClopidogrelMono_RC0',
        'Co_RX_AspirinClopidogrel_RC0', 'Co_RX_DM_RC0', 'Co_RX_Antipsychotic_RC0'
]


co_train_gpop = train_set[predictor_variable]
co_train_high = train_set_high[predictor_variable]
co_train_low = train_set_low[predictor_variable]

co_validation_gpop = validation_set[predictor_variable]
co_validation_high = validation_set_high[predictor_variable]
co_validation_low = validation_set_low[predictor_variable]

# %%
out_train_hemorrhage_gpop = train_set['Out_Hemorrhage_RC1']
out_train_hemorrhage_high = train_set_high['Out_Hemorrhage_RC1']
out_train_hemorrhage_low = train_set_low['Out_Hemorrhage_RC1']

out_validation_hemorrhage_gpop = validation_set['Out_Hemorrhage_RC1']
out_validation_hemorrhage_high = validation_set_high['Out_Hemorrhage_RC1']
out_validation_hemorrhage_low = validation_set_low['Out_Hemorrhage_RC1']

# %% [markdown]
# # Template LR

# %%
def lr(X_train, y_train):
    from sklearn.linear_model import Lasso
    from sklearn.decomposition import PCA
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler 

    model = LogisticRegression()
    param_grid = [
        {'C' : np.logspace(-4, 4, 20)}
        ]
    clf = GridSearchCV(model, param_grid, cv = 5, verbose = True, n_jobs = -1)
    best_clf = clf.fit(X_train, y_train)
    return best_clf

# %%
def train_scores(X_train,y_train):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_train)
    actual = y_train
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.decision_function(X_train)))
    print(log_loss(actual,pred))
    
def test_scores(X_test,y_test):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_test)
    actual = y_test
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.decision_function(X_test)))
    print(log_loss(actual,pred))

# %% [markdown]
# # General Population

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_gpop_sm,out_train_hemorrhage_gpop_sm = sm.fit_resample(co_train_gpop,out_train_hemorrhage_gpop)

best_clf = lr(co_train_gpop_sm, out_train_hemorrhage_gpop_sm)

train_scores(co_train_gpop_sm, out_train_hemorrhage_gpop_sm)

print()

test_scores(co_validation_gpop, out_validation_hemorrhage_gpop)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6342124232556984
# 0.5787316145949628
# 0.6290201574164773
# 0.6964148906412316
# 12.633948909345644
#
# 0.6796571211309472
# 0.05664410402565016
# 0.42404202595431756
# 0.625818292568733
# 11.064497956613916
# ['Co_CAD_R0[[0.68657197]]',
#  'Co_Embolism_R0[[0.20637754]]',
#  'Co_DVT_R0[[-0.04336604]]',
#  'Co_PE_R0[[0.10822335]]',
#  'Co_AFib_R0[[0.22576014]]',
#  'Co_Hypertension_R0[[0.23790696]]',
#  'Co_Hyperlipidemia_R0[[-0.41828915]]',
#  'Co_Atherosclerosis_R0[[0.0203639]]',
#  'Co_HF_R0[[0.13307755]]',
#  'Co_HemoStroke_R0[[-0.23136807]]',
#  'Co_IscheStroke_R0[[-0.1086877]]',
#  'Co_OthStroke_R0[[-0.05054004]]',
#  'Co_TIA_R0[[-0.08621743]]',
#  'Co_COPD_R0[[0.10856921]]',
#  'Co_Asthma_R0[[0.05428653]]',
#  'Co_Pneumonia_R0[[0.00398419]]',
#  'Co_Alcoholabuse_R0[[-0.02831117]]',
#  'Co_Drugabuse_R0[[0.06474745]]',
#  'Co_Epilepsy_R0[[0.00726261]]',
#  'Co_Cancer_R0[[0.38202111]]',
#  'Co_MorbidObesity_R0[[0.35588364]]',
#  'Co_Dementia_R0[[0.08027547]]',
#  'Co_Depression_R0[[-0.15239845]]',
#  'Co_Bipolar_R0[[-0.13523415]]',
#  'Co_Psychosis_R0[[0.01626717]]',
#  'Co_Personalitydisorder_R0[[-0.14379125]]',
#  'Co_Adjustmentdisorder_R0[[-0.1436214]]',
#  'Co_Anxiety_R0[[-0.02387127]]',
#  'Co_Generalizedanxiety_R0[[0.15847682]]',
#  'Co_OldMI_R0[[-0.34567222]]',
#  'Co_AcuteMI_R0[[-0.19075883]]',
#  'Co_PUD_R0[[-0.29912123]]',
#  'Co_UpperGIbleed_R0[[0.1181905]]',
#  'Co_LowerGIbleed_R0[[1.12806547]]',
#  'Co_Urogenitalbleed_R0[[0.40281954]]',
#  'Co_Othbleed_R0[[-0.24265638]]',
#  'Co_PVD_R0[[0.95666527]]',
#  'Co_LiverDisease_R0[[0.48401934]]',
#  'Co_MRI_R0[[0.32838189]]',
#  'Co_ESRD_R0[[0.31914542]]',
#  'Co_Obesity_R0[[-0.06051553]]',
#  'Co_Sepsis_R0[[-0.44304987]]',
#  'Co_Osteoarthritis_R0[[0.31277455]]',
#  'Co_RA_R0[[0.09579714]]',
#  'Co_NeuroPain_R0[[0.07378931]]',
#  'Co_NeckPain_R0[[-0.00213521]]',
#  'Co_OthArthritis_R0[[-0.11598204]]',
#  'Co_Osteoporosis_R0[[0.04956628]]',
#  'Co_Fibromyalgia_R0[[-0.28032403]]',
#  'Co_Migraine_R0[[-0.14698539]]',
#  'Co_Headache_R0[[-0.10079757]]',
#  'Co_OthPain_R0[[-0.14325827]]',
#  'Co_GeneralizedPain_R0[[-0.11450993]]',
#  'Co_PainDisorder_R0[[0.00572909]]',
#  'Co_Falls_R0[[0.39141651]]',
#  'Co_CoagulationDisorder_R0[[-0.38960227]]',
#  'Co_WhiteBloodCell_R0[[0.1773922]]',
#  'Co_Parkinson_R0[[-0.26317151]]',
#  'Co_Anemia_R0[[0.69957292]]',
#  'Co_UrinaryIncontinence_R0[[-0.08345256]]',
#  'Co_DecubitusUlcer_R0[[0.17300527]]',
#  'Co_Oxygen_R0[[0.0115439]]',
#  'Co_Mammography_R0[[-0.80427144]]',
#  'Co_PapTest_R0[[-0.81668268]]',
#  'Co_PSATest_R0[[-0.67598656]]',
#  'Co_Colonoscopy_R0[[-0.19086952]]',
#  'Co_FecalOccultTest_R0[[-0.08657254]]',
#  'Co_FluShot_R0[[-0.0389011]]',
#  'Co_PneumococcalVaccine_R0[[0.06563374]]',
#  'Co_RenalDysfunction_R0[[0.1834231]]',
#  'Co_Valvular_R0[[0.41439516]]',
#  'Co_Hosp_Prior30Days_R0[[0.70106701]]',
#  'Co_RX_Antibiotic_R0[[-0.3115317]]',
#  'Co_RX_Corticosteroid_R0[[-0.03837728]]',
#  'Co_RX_Aspirin_R0[[0.0008238]]',
#  'Co_RX_Dipyridamole_R0[[-0.14377263]]',
#  'Co_RX_Clopidogrel_R0[[-0.11409291]]',
#  'Co_RX_Prasugrel_R0[[0.03116461]]',
#  'Co_RX_Cilostazol_R0[[-0.1589988]]',
#  'Co_RX_Ticlopidine_R0[[-0.01779941]]',
#  'Co_RX_Ticagrelor_R0[[0.09501978]]',
#  'Co_RX_OthAntiplatelet_R0[[-0.17679821]]',
#  'Co_RX_NSAIDs_R0[[-0.10375268]]',
#  'Co_RX_Opioid_R0[[0.09115313]]',
#  'Co_RX_Antidepressant_R0[[-0.03625835]]',
#  'Co_RX_AAntipsychotic_R0[[-0.04589965]]',
#  'Co_RX_TAntipsychotic_R0[[-0.20949129]]',
#  'Co_RX_Anticonvulsant_R0[[0.12817584]]',
#  'Co_RX_PPI_R0[[-0.03674987]]',
#  'Co_RX_H2Receptor_R0[[-0.33832227]]',
#  'Co_RX_OthGastro_R0[[-0.23258167]]',
#  'Co_RX_ACE_R0[[-0.37227364]]',
#  'Co_RX_ARB_R0[[-0.28692525]]',
#  'Co_RX_BBlocker_R0[[0.15200489]]',
#  'Co_RX_CCB_R0[[-0.08239262]]',
#  'Co_RX_Thiazide_R0[[-0.1948402]]',
#  'Co_RX_Loop_R0[[0.14478267]]',
#  'Co_RX_Potassium_R0[[-0.19523425]]',
#  'Co_RX_Nitrates_R0[[-0.14093131]]',
#  'Co_RX_Aliskiren_R0[[0.04807871]]',
#  'Co_RX_OthAntihypertensive_R0[[0.01077922]]',
#  'Co_RX_Antiarrhythmic_R0[[-0.16991927]]',
#  'Co_RX_OthAnticoagulant_R0[[-0.22367872]]',
#  'Co_RX_Insulin_R0[[-0.05768432]]',
#  'Co_RX_Noninsulin_R0[[-0.1262733]]',
#  'Co_RX_Digoxin_R0[[-0.18329894]]',
#  'Co_RX_Statin_R0[[0.04375108]]',
#  'Co_RX_Lipid_R0[[0.02779581]]',
#  'Co_RX_Lithium_R0[[-0.08575984]]',
#  'Co_RX_Benzo_R0[[-0.29526541]]',
#  'Co_RX_ZDrugs_R0[[-0.29182874]]',
#  'Co_RX_OthAnxiolytic_R0[[-0.16103248]]',
#  'Co_RX_Barbiturate_R0[[-0.00852583]]',
#  'Co_RX_Dementia_R0[[-0.40926432]]',
#  'Co_RX_Hormone_R0[[-0.49263165]]',
#  'Co_RX_Osteoporosis_R0[[-0.26684838]]',
#  'Co_N_Drugs_R0[[0.01945221]]',
#  'Co_N_Hosp_R0[[-0.11965434]]',
#  'Co_Total_HospLOS_R0[[0.00074131]]',
#  'Co_N_MDVisit_R0[[0.03750339]]',
#  'Co_RX_AnyAspirin_R0[[-0.02287861]]',
#  'Co_RX_AspirinMono_R0[[0.05615122]]',
#  'Co_RX_ClopidogrelMono_R0[[-0.15451287]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.05363543]]',
#  'Co_RX_DM_R0[[-0.07746073]]',
#  'Co_RX_Antipsychotic_R0[[-0.06045155]]']

# %% [markdown]
# # High Continuity

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_high_sm,out_train_hemorrhage_high_sm = sm.fit_resample(co_train_high,out_train_hemorrhage_high)

best_clf = lr(co_train_high_sm, out_train_hemorrhage_high_sm)

train_scores(co_train_high_sm, out_train_hemorrhage_high_sm)

print()

test_scores(co_validation_high, out_validation_hemorrhage_high)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6940160009231302
# 0.6572119553800826
# 0.6906788532335774
# 0.7617302092620999
# 10.568392331449083
#
# 0.800557716298525
# 0.0831252951892585
# 0.4986762518749962
# 0.6270231481990928
# 6.888640718338179
# ['Co_CAD_R0[[0.40947226]]',
#  'Co_Embolism_R0[[0.15327397]]',
#  'Co_DVT_R0[[0.13919434]]',
#  'Co_PE_R0[[0.10378251]]',
#  'Co_AFib_R0[[0.19343763]]',
#  'Co_Hypertension_R0[[0.21960018]]',
#  'Co_Hyperlipidemia_R0[[-0.25822129]]',
#  'Co_Atherosclerosis_R0[[0.05561293]]',
#  'Co_HF_R0[[0.23223502]]',
#  'Co_HemoStroke_R0[[-0.05871107]]',
#  'Co_IscheStroke_R0[[-0.0034619]]',
#  'Co_OthStroke_R0[[-0.00927381]]',
#  'Co_TIA_R0[[-0.13029676]]',
#  'Co_COPD_R0[[0.18337444]]',
#  'Co_Asthma_R0[[0.07045069]]',
#  'Co_Pneumonia_R0[[0.02258208]]',
#  'Co_Alcoholabuse_R0[[0.2573279]]',
#  'Co_Drugabuse_R0[[0.03233325]]',
#  'Co_Epilepsy_R0[[-0.22396985]]',
#  'Co_Cancer_R0[[0.27111066]]',
#  'Co_MorbidObesity_R0[[0.10536104]]',
#  'Co_Dementia_R0[[0.28552462]]',
#  'Co_Depression_R0[[-0.24166752]]',
#  'Co_Bipolar_R0[[-0.00992976]]',
#  'Co_Psychosis_R0[[0.0924012]]',
#  'Co_Personalitydisorder_R0[[-0.11257334]]',
#  'Co_Adjustmentdisorder_R0[[-0.11386729]]',
#  'Co_Anxiety_R0[[-0.04843246]]',
#  'Co_Generalizedanxiety_R0[[0.12302404]]',
#  'Co_OldMI_R0[[-0.16277409]]',
#  'Co_AcuteMI_R0[[-0.02177126]]',
#  'Co_PUD_R0[[-0.10335659]]',
#  'Co_UpperGIbleed_R0[[-0.01631578]]',
#  'Co_LowerGIbleed_R0[[0.73229386]]',
#  'Co_Urogenitalbleed_R0[[0.39763825]]',
#  'Co_Othbleed_R0[[-0.12155605]]',
#  'Co_PVD_R0[[1.00444668]]',
#  'Co_LiverDisease_R0[[0.47417483]]',
#  'Co_MRI_R0[[0.36446174]]',
#  'Co_ESRD_R0[[0.1984999]]',
#  'Co_Obesity_R0[[-0.02371275]]',
#  'Co_Sepsis_R0[[-0.2485048]]',
#  'Co_Osteoarthritis_R0[[0.2629753]]',
#  'Co_RA_R0[[0.18989175]]',
#  'Co_NeuroPain_R0[[0.28221635]]',
#  'Co_NeckPain_R0[[-0.05489526]]',
#  'Co_OthArthritis_R0[[-0.08153505]]',
#  'Co_Osteoporosis_R0[[0.09857542]]',
#  'Co_Fibromyalgia_R0[[-0.20452242]]',
#  'Co_Migraine_R0[[-0.08034517]]',
#  'Co_Headache_R0[[0.02633899]]',
#  'Co_OthPain_R0[[-0.01321644]]',
#  'Co_GeneralizedPain_R0[[0.06040656]]',
#  'Co_PainDisorder_R0[[-0.00089429]]',
#  'Co_Falls_R0[[0.19512358]]',
#  'Co_CoagulationDisorder_R0[[-0.33694373]]',
#  'Co_WhiteBloodCell_R0[[0.18604813]]',
#  'Co_Parkinson_R0[[0.04510532]]',
#  'Co_Anemia_R0[[0.71871653]]',
#  'Co_UrinaryIncontinence_R0[[-0.0029822]]',
#  'Co_DecubitusUlcer_R0[[0.28033475]]',
#  'Co_Oxygen_R0[[-0.10255238]]',
#  'Co_Mammography_R0[[-0.59306608]]',
#  'Co_PapTest_R0[[-0.59561754]]',
#  'Co_PSATest_R0[[-0.47780091]]',
#  'Co_Colonoscopy_R0[[-0.00351745]]',
#  'Co_FecalOccultTest_R0[[-0.17997392]]',
#  'Co_FluShot_R0[[-0.00671691]]',
#  'Co_PneumococcalVaccine_R0[[0.08491861]]',
#  'Co_RenalDysfunction_R0[[0.21472009]]',
#  'Co_Valvular_R0[[0.36395136]]',
#  'Co_Hosp_Prior30Days_R0[[0.7651981]]',
#  'Co_RX_Antibiotic_R0[[-0.20516817]]',
#  'Co_RX_Corticosteroid_R0[[0.10481682]]',
#  'Co_RX_Aspirin_R0[[0.01488027]]',
#  'Co_RX_Dipyridamole_R0[[-0.05095338]]',
#  'Co_RX_Clopidogrel_R0[[-0.047705]]',
#  'Co_RX_Prasugrel_R0[[-0.0635154]]',
#  'Co_RX_Cilostazol_R0[[-0.17753541]]',
#  'Co_RX_Ticlopidine_R0[[-0.01560522]]',
#  'Co_RX_Ticagrelor_R0[[0.10572679]]',
#  'Co_RX_OthAntiplatelet_R0[[-0.19314063]]',
#  'Co_RX_NSAIDs_R0[[-0.07602674]]',
#  'Co_RX_Opioid_R0[[0.02438197]]',
#  'Co_RX_Antidepressant_R0[[0.10649011]]',
#  'Co_RX_AAntipsychotic_R0[[-0.03862593]]',
#  'Co_RX_TAntipsychotic_R0[[-0.13022691]]',
#  'Co_RX_Anticonvulsant_R0[[0.0192733]]',
#  'Co_RX_PPI_R0[[0.00711845]]',
#  'Co_RX_H2Receptor_R0[[-0.26732373]]',
#  'Co_RX_OthGastro_R0[[-0.12310077]]',
#  'Co_RX_ACE_R0[[-0.29725284]]',
#  'Co_RX_ARB_R0[[-0.27589281]]',
#  'Co_RX_BBlocker_R0[[0.27544502]]',
#  'Co_RX_CCB_R0[[0.12674266]]',
#  'Co_RX_Thiazide_R0[[-0.09188932]]',
#  'Co_RX_Loop_R0[[0.15510314]]',
#  'Co_RX_Potassium_R0[[-0.00515672]]',
#  'Co_RX_Nitrates_R0[[-0.22457819]]',
#  'Co_RX_Aliskiren_R0[[0.04379687]]',
#  'Co_RX_OthAntihypertensive_R0[[-0.01995463]]',
#  'Co_RX_Antiarrhythmic_R0[[0.00389723]]',
#  'Co_RX_OthAnticoagulant_R0[[-0.15804953]]',
#  'Co_RX_Insulin_R0[[-0.06945013]]',
#  'Co_RX_Noninsulin_R0[[-0.05261984]]',
#  'Co_RX_Digoxin_R0[[-0.29116587]]',
#  'Co_RX_Statin_R0[[-0.01474964]]',
#  'Co_RX_Lipid_R0[[-0.13075925]]',
#  'Co_RX_Lithium_R0[[-0.01911332]]',
#  'Co_RX_Benzo_R0[[-0.23285284]]',
#  'Co_RX_ZDrugs_R0[[-0.05353389]]',
#  'Co_RX_OthAnxiolytic_R0[[-0.20586921]]',
#  'Co_RX_Barbiturate_R0[[-0.00639094]]',
#  'Co_RX_Dementia_R0[[-0.24969286]]',
#  'Co_RX_Hormone_R0[[-0.36988676]]',
#  'Co_RX_Osteoporosis_R0[[-0.17426371]]',
#  'Co_N_Drugs_R0[[0.01229524]]',
#  'Co_N_Hosp_R0[[-0.01570444]]',
#  'Co_Total_HospLOS_R0[[-0.00956937]]',
#  'Co_N_MDVisit_R0[[0.04840852]]',
#  'Co_RX_AnyAspirin_R0[[-0.00509635]]',
#  'Co_RX_AspirinMono_R0[[0.02244604]]',
#  'Co_RX_ClopidogrelMono_R0[[-0.15864715]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.11888421]]',
#  'Co_RX_DM_R0[[-0.09317781]]',
#  'Co_RX_Antipsychotic_R0[[0.0038654]]']

# %% [markdown]
# # Low Continuity

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_low_sm,out_train_hemorrhage_low_sm = sm.fit_resample(co_train_low,out_train_hemorrhage_low)

best_clf = lr(co_train_low_sm, out_train_hemorrhage_low_sm)

train_scores(co_train_low_sm, out_train_hemorrhage_low_sm)

print()

test_scores(co_validation_low, out_validation_hemorrhage_low)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6146602031679378
# 0.545432470496819
# 0.6076377694347053
# 0.6498951135712061
# 13.309258250406666
#
# 0.6109138282448362
# 0.04654755161938108
# 0.38265269420744413
# 0.5834934286288109
# 13.43886417228638
# ['Co_CAD_R0[[1.17523342]]',
#  'Co_Embolism_R0[[0.35629084]]',
#  'Co_DVT_R0[[-0.66712874]]',
#  'Co_PE_R0[[0.32055831]]',
#  'Co_AFib_R0[[0.44967314]]',
#  'Co_Hypertension_R0[[0.52714913]]',
#  'Co_Hyperlipidemia_R0[[-0.58186735]]',
#  'Co_Atherosclerosis_R0[[-0.08141625]]',
#  'Co_HF_R0[[0.07520921]]',
#  'Co_HemoStroke_R0[[-0.60644021]]',
#  'Co_IscheStroke_R0[[0.052414]]',
#  'Co_OthStroke_R0[[-0.51316396]]',
#  'Co_TIA_R0[[0.42395672]]',
#  'Co_COPD_R0[[-0.09162829]]',
#  'Co_Asthma_R0[[-0.01866337]]',
#  'Co_Pneumonia_R0[[-0.26801196]]',
#  'Co_Alcoholabuse_R0[[-1.35872699]]',
#  'Co_Drugabuse_R0[[0.45269786]]',
#  'Co_Epilepsy_R0[[0.95656602]]',
#  'Co_Cancer_R0[[0.59989808]]',
#  'Co_MorbidObesity_R0[[2.69156983]]',
#  'Co_Dementia_R0[[-0.52541036]]',
#  'Co_Depression_R0[[-0.16743837]]',
#  'Co_Bipolar_R0[[-0.96945856]]',
#  'Co_Psychosis_R0[[0.15393536]]',
#  'Co_Personalitydisorder_R0[[-0.39664314]]',
#  'Co_Adjustmentdisorder_R0[[-0.4409769]]',
#  'Co_Anxiety_R0[[-0.02820714]]',
#  'Co_Generalizedanxiety_R0[[-1.17858813]]',
#  'Co_OldMI_R0[[-0.82509897]]',
#  'Co_AcuteMI_R0[[-1.03736368]]',
#  'Co_PUD_R0[[-1.00655552]]',
#  'Co_UpperGIbleed_R0[[1.43865274]]',
#  'Co_LowerGIbleed_R0[[1.52491955]]',
#  'Co_Urogenitalbleed_R0[[-0.0330905]]',
#  'Co_Othbleed_R0[[0.02277031]]',
#  'Co_PVD_R0[[0.94348819]]',
#  'Co_LiverDisease_R0[[0.62613069]]',
#  'Co_MRI_R0[[0.14815205]]',
#  'Co_ESRD_R0[[1.04759887]]',
#  'Co_Obesity_R0[[-0.92595621]]',
#  'Co_Sepsis_R0[[-1.00078458]]',
#  'Co_Osteoarthritis_R0[[0.57185838]]',
#  'Co_RA_R0[[-1.2351266]]',
#  'Co_NeuroPain_R0[[-0.55113838]]',
#  'Co_NeckPain_R0[[0.13904715]]',
#  'Co_OthArthritis_R0[[-0.06239678]]',
#  'Co_Osteoporosis_R0[[-1.36064727]]',
#  'Co_Fibromyalgia_R0[[-1.47122754]]',
#  'Co_Migraine_R0[[-0.04826995]]',
#  'Co_Headache_R0[[-1.04734548]]',
#  'Co_OthPain_R0[[-1.82067419]]',
#  'Co_GeneralizedPain_R0[[-1.6874618]]',
#  'Co_PainDisorder_R0[[-0.03508283]]',
#  'Co_Falls_R0[[0.46230608]]',
#  'Co_CoagulationDisorder_R0[[-0.25108415]]',
#  'Co_WhiteBloodCell_R0[[-0.0411343]]',
#  'Co_Parkinson_R0[[-2.90353701]]',
#  'Co_Anemia_R0[[0.53222509]]',
#  'Co_UrinaryIncontinence_R0[[-1.14914474]]',
#  'Co_DecubitusUlcer_R0[[-0.61124727]]',
#  'Co_Oxygen_R0[[0.06995984]]',
#  'Co_Mammography_R0[[-4.07974933]]',
#  'Co_PapTest_R0[[-2.06686262]]',
#  'Co_PSATest_R0[[-1.02601531]]',
#  'Co_Colonoscopy_R0[[-0.13117576]]',
#  'Co_FecalOccultTest_R0[[-0.22692468]]',
#  'Co_FluShot_R0[[-0.92860837]]',
#  'Co_PneumococcalVaccine_R0[[-1.26495519]]',
#  'Co_RenalDysfunction_R0[[-0.26182004]]',
#  'Co_Valvular_R0[[0.84353757]]',
#  'Co_Hosp_Prior30Days_R0[[-0.03679043]]',
#  'Co_RX_Antibiotic_R0[[-0.60203292]]',
#  'Co_RX_Corticosteroid_R0[[-0.40762823]]',
#  'Co_RX_Aspirin_R0[[0.0605695]]',
#  'Co_RX_Dipyridamole_R0[[-0.82546284]]',
#  'Co_RX_Clopidogrel_R0[[-0.26093542]]',
#  'Co_RX_Prasugrel_R0[[0.86135143]]',
#  'Co_RX_Cilostazol_R0[[0.54376012]]',
#  'Co_RX_Ticlopidine_R0[[0.]]',
#  'Co_RX_Ticagrelor_R0[[-0.46957493]]',
#  'Co_RX_OthAntiplatelet_R0[[0.54376012]]',
#  'Co_RX_NSAIDs_R0[[-0.308282]]',
#  'Co_RX_Opioid_R0[[0.29175853]]',
#  'Co_RX_Antidepressant_R0[[-0.50921784]]',
#  'Co_RX_AAntipsychotic_R0[[-0.51605018]]',
#  'Co_RX_TAntipsychotic_R0[[0.3083925]]',
#  'Co_RX_Anticonvulsant_R0[[0.09497563]]',
#  'Co_RX_PPI_R0[[-0.32519801]]',
#  'Co_RX_H2Receptor_R0[[-0.62600429]]',
#  'Co_RX_OthGastro_R0[[0.23080416]]',
#  'Co_RX_ACE_R0[[-0.55714656]]',
#  'Co_RX_ARB_R0[[-0.42451729]]',
#  'Co_RX_BBlocker_R0[[-0.03033252]]',
#  'Co_RX_CCB_R0[[-0.47278236]]',
#  'Co_RX_Thiazide_R0[[-0.4396018]]',
#  'Co_RX_Loop_R0[[0.24778857]]',
#  'Co_RX_Potassium_R0[[-0.7068457]]',
#  'Co_RX_Nitrates_R0[[-0.16108429]]',
#  'Co_RX_Aliskiren_R0[[-0.11482013]]',
#  'Co_RX_OthAntihypertensive_R0[[-0.14338213]]',
#  'Co_RX_Antiarrhythmic_R0[[-0.83887198]]',
#  'Co_RX_OthAnticoagulant_R0[[-1.27266576]]',
#  'Co_RX_Insulin_R0[[-0.87282841]]',
#  'Co_RX_Noninsulin_R0[[-1.30569068]]',
#  'Co_RX_Digoxin_R0[[0.04035802]]',
#  'Co_RX_Statin_R0[[-0.17189902]]',
#  'Co_RX_Lipid_R0[[0.13400049]]',
#  'Co_RX_Lithium_R0[[-0.76583357]]',
#  'Co_RX_Benzo_R0[[-0.29968064]]',
#  'Co_RX_ZDrugs_R0[[-0.7631993]]',
#  'Co_RX_OthAnxiolytic_R0[[-0.55676438]]',
#  'Co_RX_Barbiturate_R0[[-0.00805426]]',
#  'Co_RX_Dementia_R0[[-1.47252579]]',
#  'Co_RX_Hormone_R0[[-1.14146984]]',
#  'Co_RX_Osteoporosis_R0[[-0.45091915]]',
#  'Co_N_Drugs_R0[[0.09463432]]',
#  'Co_N_Hosp_R0[[-0.03679043]]',
#  'Co_Total_HospLOS_R0[[0.05610976]]',
#  'Co_N_MDVisit_R0[[-0.10395934]]',
#  'Co_RX_AnyAspirin_R0[[0.0605695]]',
#  'Co_RX_AspirinMono_R0[[0.05567957]]',
#  'Co_RX_ClopidogrelMono_R0[[-0.03639468]]',
#  'Co_RX_AspirinClopidogrel_R0[[-0.14624556]]',
#  'Co_RX_DM_R0[[0.98834196]]',
#  'Co_RX_Antipsychotic_R0[[0.18609164]]']
