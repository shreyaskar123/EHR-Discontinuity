# %%
import pandas as pd 
medicare = pd.read_csv("/netapp2/home/se197/RPDR/Josh Lin/3_EHR_V2/CMS/final_medicare.csv")

# %%
train_set = medicare[medicare.Hospital != 'BWH'] # MGH; n = 204014
validation_set = medicare[medicare.Hospital == 'BWH'] # BWH and Neither; n = 115726
import numpy as np

fifty_perc_EHR_cont = np.percentile(medicare['Cal_MPEC_R0'],50)
train_set_high = train_set[train_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
train_set_low= train_set[train_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

validation_set_high = validation_set[validation_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
validation_set_low = validation_set[validation_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

# %%
predictor_variable_claims = [
    'Co_CAD_RC0', 'Co_Embolism_RC0', 'Co_DVT_RC0', 'Co_PE_RC0', 'Co_AFib_RC0',
        'Co_Hypertension_RC0', 'Co_Hyperlipidemia_RC0', 'Co_Atherosclerosis_RC0',
        'Co_HF_RC0', 'Co_HemoStroke_RC0', 'Co_IscheStroke_RC0', 'Co_OthStroke_RC0',
        'Co_TIA_RC0', 'Co_COPD_RC0', 'Co_Asthma_RC0', 'Co_Pneumonia_RC0', 'Co_Alcoholabuse_RC0',
        'Co_Drugabuse_RC0', 'Co_Epilepsy_RC0', 'Co_Cancer_RC0', 'Co_MorbidObesity_RC0',
        'Co_Dementia_RC0', 'Co_Depression_RC0', 'Co_Bipolar_RC0', 'Co_Psychosis_RC0',
        'Co_Personalitydisorder_RC0', 'Co_Adjustmentdisorder_RC0', 'Co_Anxiety_RC0',
        'Co_Generalizedanxiety_RC0', 'Co_OldMI_RC0', 'Co_AcuteMI_RC0', 'Co_PUD_RC0',
        'Co_UpperGIbleed_RC0', 'Co_LowerGIbleed_RC0', 'Co_Urogenitalbleed_RC0',
        'Co_Othbleed_RC0', 'Co_PVD_RC0', 'Co_LiverDisease_RC0', 'Co_MRI_RC0',
        'Co_ESRD_RC0', 'Co_Obesity_RC0', 'Co_Sepsis_RC0', 'Co_Osteoarthritis_RC0',
        'Co_RA_RC0', 'Co_NeuroPain_RC0', 'Co_NeckPain_RC0', 'Co_OthArthritis_RC0',
        'Co_Osteoporosis_RC0', 'Co_Fibromyalgia_RC0', 'Co_Migraine_RC0', 'Co_Headache_RC0',
        'Co_OthPain_RC0', 'Co_GeneralizedPain_RC0', 'Co_PainDisorder_RC0',
        'Co_Falls_RC0', 'Co_CoagulationDisorder_RC0', 'Co_WhiteBloodCell_RC0', 'Co_Parkinson_RC0',
        'Co_Anemia_RC0', 'Co_UrinaryIncontinence_RC0', 'Co_DecubitusUlcer_RC0',
        'Co_Oxygen_RC0', 'Co_Mammography_RC0', 'Co_PapTest_RC0', 'Co_PSATest_RC0',
        'Co_Colonoscopy_RC0', 'Co_FecalOccultTest_RC0', 'Co_FluShot_RC0', 'Co_PneumococcalVaccine_RC0' , 'Co_RenalDysfunction_RC0', 'Co_Valvular_RC0', 'Co_Hosp_Prior30Days_RC0',
        'Co_RX_Antibiotic_RC0', 'Co_RX_Corticosteroid_RC0', 'Co_RX_Aspirin_RC0', 'Co_RX_Dipyridamole_RC0',
        'Co_RX_Clopidogrel_RC0', 'Co_RX_Prasugrel_RC0', 'Co_RX_Cilostazol_RC0', 'Co_RX_Ticlopidine_RC0',
        'Co_RX_Ticagrelor_RC0', 'Co_RX_OthAntiplatelet_RC0', 'Co_RX_NSAIDs_RC0',
        'Co_RX_Opioid_RC0', 'Co_RX_Antidepressant_RC0', 'Co_RX_AAntipsychotic_RC0', 'Co_RX_TAntipsychotic_RC0',
        'Co_RX_Anticonvulsant_RC0', 'Co_RX_PPI_RC0', 'Co_RX_H2Receptor_RC0', 'Co_RX_OthGastro_RC0',
        'Co_RX_ACE_RC0', 'Co_RX_ARB_RC0', 'Co_RX_BBlocker_RC0', 'Co_RX_CCB_RC0', 'Co_RX_Thiazide_RC0',
        'Co_RX_Loop_RC0', 'Co_RX_Potassium_RC0', 'Co_RX_Nitrates_RC0', 'Co_RX_Aliskiren_RC0',
        'Co_RX_OthAntihypertensive_RC0', 'Co_RX_Antiarrhythmic_RC0', 'Co_RX_OthAnticoagulant_RC0',
        'Co_RX_Insulin_RC0', 'Co_RX_Noninsulin_RC0', 'Co_RX_Digoxin_RC0', 'Co_RX_Statin_RC0',
        'Co_RX_Lipid_RC0', 'Co_RX_Lithium_RC0', 'Co_RX_Benzo_RC0', 'Co_RX_ZDrugs_RC0',
        'Co_RX_OthAnxiolytic_RC0', 'Co_RX_Barbiturate_RC0', 'Co_RX_Dementia_RC0', 'Co_RX_Hormone_RC0',
        'Co_RX_Osteoporosis_RC0', 'Co_N_Drugs_RC0', 'Co_N_Hosp_RC0', 'Co_Total_HospLOS_RC0',
        'Co_N_MDVisit_RC0', 'Co_RX_AnyAspirin_RC0', 'Co_RX_AspirinMono_RC0', 'Co_RX_ClopidogrelMono_RC0',
        'Co_RX_AspirinClopidogrel_RC0', 'Co_RX_DM_RC0', 'Co_RX_Antipsychotic_RC0'
]


co_train_gpop = train_set[predictor_variable_claims]
co_train_high = train_set_high[predictor_variable_claims]
co_train_low = train_set_low[predictor_variable_claims]

co_validation_gpop = validation_set[predictor_variable_claims]
co_validation_high = validation_set_high[predictor_variable_claims]
co_validation_low = validation_set_low[predictor_variable_claims]

# %%
out_train_hemorrhage_gpop = train_set['Out_Hemorrhage_RC1']
out_train_hemorrhage_high = train_set_high['Out_Hemorrhage_RC1']
out_train_hemorrhage_low = train_set_low['Out_Hemorrhage_RC1']

out_validation_hemorrhage_gpop = validation_set['Out_Hemorrhage_RC1']
out_validation_hemorrhage_high = validation_set_high['Out_Hemorrhage_RC1']
out_validation_hemorrhage_low = validation_set_low['Out_Hemorrhage_RC1']

# %% [markdown]
# # Template LR

# %%
def lr(X_train, y_train):
    from sklearn.linear_model import Lasso
    from sklearn.decomposition import PCA
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler 

    model = LogisticRegression(penalty = 'l1', solver = 'liblinear')
    param_grid = [
        {'C' : np.logspace(-4, 4, 20)}
        ]
    clf = GridSearchCV(model, param_grid, cv = 5, verbose = True, n_jobs = -1)
    best_clf = clf.fit(X_train, y_train)
    return best_clf

# %%
def train_scores(X_train,y_train):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_train)
    actual = y_train
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.decision_function(X_train)))
    print(log_loss(actual,pred))
    
def test_scores(X_test,y_test):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_test)
    actual = y_test
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.decision_function(X_test)))
    print(log_loss(actual,pred))

# %% [markdown]
# # General Population

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_gpop_sm,out_train_hemorrhage_gpop_sm = sm.fit_resample(co_train_gpop,out_train_hemorrhage_gpop)

best_clf = lr(co_train_gpop_sm, out_train_hemorrhage_gpop_sm)

train_scores(co_train_gpop_sm, out_train_hemorrhage_gpop_sm)

print()

train_scores(co_train_gpop, out_train_hemorrhage_gpop)

print()

test_scores(co_validation_gpop, out_validation_hemorrhage_gpop)

comb = [] 
for i in range(len(predictor_variable_claims)):
    comb.append(predictor_variable_claims[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6739064449765606
# 0.661117341931866
# 0.6734902244761949
# 0.7341926337258203
# 11.262987664544381
#
# 0.7059060860929207
# 0.2575994985897838
# 0.575855289073967
# 0.7334243620368576
# 10.157856108631073
#
# 0.6653370562425209
# 0.2625796528235553
# 0.5581331387427605
# 0.7054302948453475
# 11.559089426142616
# ['Co_CAD_RC0[[0.10596376]]',
#  'Co_Embolism_RC0[[0.00896932]]',
#  'Co_DVT_RC0[[0.03239284]]',
#  'Co_PE_RC0[[0.03475864]]',
#  'Co_AFib_RC0[[0.22753676]]',
#  'Co_Hypertension_RC0[[0.08203045]]',
#  'Co_Hyperlipidemia_RC0[[-0.0522919]]',
#  'Co_Atherosclerosis_RC0[[0.08580757]]',
#  'Co_HF_RC0[[0.13330373]]',
#  'Co_HemoStroke_RC0[[-0.03623605]]',
#  'Co_IscheStroke_RC0[[-0.02226368]]',
#  'Co_OthStroke_RC0[[-0.0050988]]',
#  'Co_TIA_RC0[[-0.03679261]]',
#  'Co_COPD_RC0[[0.12116508]]',
#  'Co_Asthma_RC0[[0.04527643]]',
#  'Co_Pneumonia_RC0[[-0.05877968]]',
#  'Co_Alcoholabuse_RC0[[0.05035872]]',
#  'Co_Drugabuse_RC0[[0.01924578]]',
#  'Co_Epilepsy_RC0[[-0.02978648]]',
#  'Co_Cancer_RC0[[0.04560602]]',
#  'Co_MorbidObesity_RC0[[0.01781412]]',
#  'Co_Dementia_RC0[[0.0046645]]',
#  'Co_Depression_RC0[[-0.03184557]]',
#  'Co_Bipolar_RC0[[-0.00445272]]',
#  'Co_Psychosis_RC0[[0.0089807]]',
#  'Co_Personalitydisorder_RC0[[0.02632103]]',
#  'Co_Adjustmentdisorder_RC0[[-0.04017844]]',
#  'Co_Anxiety_RC0[[0.00315258]]',
#  'Co_Generalizedanxiety_RC0[[0.001015]]',
#  'Co_OldMI_RC0[[-0.06252116]]',
#  'Co_AcuteMI_RC0[[0.00770767]]',
#  'Co_PUD_RC0[[0.01589273]]',
#  'Co_UpperGIbleed_RC0[[0.10885974]]',
#  'Co_LowerGIbleed_RC0[[0.24800369]]',
#  'Co_Urogenitalbleed_RC0[[0.09553361]]',
#  'Co_Othbleed_RC0[[0.0502082]]',
#  'Co_PVD_RC0[[0.16615588]]',
#  'Co_LiverDisease_RC0[[0.04838414]]',
#  'Co_MRI_RC0[[0.07486234]]',
#  'Co_ESRD_RC0[[0.06453054]]',
#  'Co_Obesity_RC0[[-0.0541964]]',
#  'Co_Sepsis_RC0[[-0.01565153]]',
#  'Co_Osteoarthritis_RC0[[0.0494779]]',
#  'Co_RA_RC0[[0.01288223]]',
#  'Co_NeuroPain_RC0[[0.04856749]]',
#  'Co_NeckPain_RC0[[0.02306165]]',
#  'Co_OthArthritis_RC0[[0.04283976]]',
#  'Co_Osteoporosis_RC0[[0.08730748]]',
#  'Co_Fibromyalgia_RC0[[-0.07180186]]',
#  'Co_Migraine_RC0[[-0.02278673]]',
#  'Co_Headache_RC0[[-0.00755274]]',
#  'Co_OthPain_RC0[[0.12293625]]',
#  'Co_GeneralizedPain_RC0[[0.06551226]]',
#  'Co_PainDisorder_RC0[[0.00358518]]',
#  'Co_Falls_RC0[[0.11942535]]',
#  'Co_CoagulationDisorder_RC0[[0.03752247]]',
#  'Co_WhiteBloodCell_RC0[[0.05795127]]',
#  'Co_Parkinson_RC0[[0.07007333]]',
#  'Co_Anemia_RC0[[0.3027118]]',
#  'Co_UrinaryIncontinence_RC0[[0.06929055]]',
#  'Co_DecubitusUlcer_RC0[[-0.00390529]]',
#  'Co_Oxygen_RC0[[0.04007856]]',
#  'Co_Mammography_RC0[[-0.13513006]]',
#  'Co_PapTest_RC0[[-0.1442525]]',
#  'Co_PSATest_RC0[[-0.10585976]]',
#  'Co_Colonoscopy_RC0[[-0.01820777]]',
#  'Co_FecalOccultTest_RC0[[-0.09140027]]',
#  'Co_FluShot_RC0[[0.00633492]]',
#  'Co_PneumococcalVaccine_RC0[[0.19660506]]',
#  'Co_RenalDysfunction_RC0[[0.23179602]]',
#  'Co_Valvular_RC0[[0.11919573]]',
#  'Co_Hosp_Prior30Days_RC0[[0.26147762]]',
#  'Co_RX_Antibiotic_RC0[[0.02809171]]',
#  'Co_RX_Corticosteroid_RC0[[0.02829874]]',
#  'Co_RX_Aspirin_RC0[[0.00477512]]',
#  'Co_RX_Dipyridamole_RC0[[-0.01383632]]',
#  'Co_RX_Clopidogrel_RC0[[0.04163186]]',
#  'Co_RX_Prasugrel_RC0[[-0.00336178]]',
#  'Co_RX_Cilostazol_RC0[[-0.02189106]]',
#  'Co_RX_Ticlopidine_RC0[[-0.00590585]]',
#  'Co_RX_Ticagrelor_RC0[[0.01089338]]',
#  'Co_RX_OthAntiplatelet_RC0[[-0.0277969]]',
#  'Co_RX_NSAIDs_RC0[[-0.06827157]]',
#  'Co_RX_Opioid_RC0[[-0.01368143]]',
#  'Co_RX_Antidepressant_RC0[[0.09705038]]',
#  'Co_RX_AAntipsychotic_RC0[[-0.05343067]]',
#  'Co_RX_TAntipsychotic_RC0[[0.04320702]]',
#  'Co_RX_Anticonvulsant_RC0[[0.00773926]]',
#  'Co_RX_PPI_RC0[[-0.01188291]]',
#  'Co_RX_H2Receptor_RC0[[-0.09283264]]',
#  'Co_RX_OthGastro_RC0[[-0.03999273]]',
#  'Co_RX_ACE_RC0[[-0.09929175]]',
#  'Co_RX_ARB_RC0[[-0.07411245]]',
#  'Co_RX_BBlocker_RC0[[0.07495358]]',
#  'Co_RX_CCB_RC0[[0.01155808]]',
#  'Co_RX_Thiazide_RC0[[-0.04305267]]',
#  'Co_RX_Loop_RC0[[0.17941904]]',
#  'Co_RX_Potassium_RC0[[0.04886583]]',
#  'Co_RX_Nitrates_RC0[[-0.0175505]]',
#  'Co_RX_Aliskiren_RC0[[-0.01108945]]',
#  'Co_RX_OthAntihypertensive_RC0[[-0.04675103]]',
#  'Co_RX_Antiarrhythmic_RC0[[-0.06973654]]',
#  'Co_RX_OthAnticoagulant_RC0[[-0.0190843]]',
#  'Co_RX_Insulin_RC0[[0.02031875]]',
#  'Co_RX_Noninsulin_RC0[[-0.03786968]]',
#  'Co_RX_Digoxin_RC0[[-8.69424542e-05]]',
#  'Co_RX_Statin_RC0[[0.01974472]]',
#  'Co_RX_Lipid_RC0[[-0.03148373]]',
#  'Co_RX_Lithium_RC0[[0.0090035]]',
#  'Co_RX_Benzo_RC0[[-0.10256738]]',
#  'Co_RX_ZDrugs_RC0[[-0.12224349]]',
#  'Co_RX_OthAnxiolytic_RC0[[-0.02676343]]',
#  'Co_RX_Barbiturate_RC0[[0.00043365]]',
#  'Co_RX_Dementia_RC0[[-0.06207386]]',
#  'Co_RX_Hormone_RC0[[-0.10024219]]',
#  'Co_RX_Osteoporosis_RC0[[-0.04441606]]',
#  'Co_N_Drugs_RC0[[0.00124172]]',
#  'Co_N_Hosp_RC0[[0.06672334]]',
#  'Co_Total_HospLOS_RC0[[0.00455384]]',
#  'Co_N_MDVisit_RC0[[0.00650124]]',
#  'Co_RX_AnyAspirin_RC0[[0.00151276]]',
#  'Co_RX_AspirinMono_RC0[[0.00423187]]',
#  'Co_RX_ClopidogrelMono_RC0[[-0.0096411]]',
#  'Co_RX_AspirinClopidogrel_RC0[[0.03137396]]',
#  'Co_RX_DM_RC0[[-0.01729596]]',
#  'Co_RX_Antipsychotic_RC0[[0.00698119]]']

# %% [markdown]
# # High Continuity

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_high_sm,out_train_hemorrhage_high_sm = sm.fit_resample(co_train_high, out_train_hemorrhage_high)

best_clf = lr(co_train_high_sm, out_train_hemorrhage_high_sm)

train_scores(co_train_high_sm, out_train_hemorrhage_high_sm)

print()

train_scores(co_train_high, out_train_hemorrhage_high)

print()

test_scores(co_validation_high, out_validation_hemorrhage_high)

comb = [] 
for i in range(len(predictor_variable_claims)):
    comb.append(predictor_variable_claims[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7039958950676672
# 0.6972777959986881
# 0.7038543594365787
# 0.7709506841926195
# 10.223729061845138
#
# 0.722083035075161
# 0.25156626506024093
# 0.5830004223461619
# 0.7635069700244032
# 9.599115527637698
#
# 0.7013990394654417
# 0.25520833333333337
# 0.5729903622395079
# 0.74120345325796
# 10.31352811091942
# ['Co_CAD_RC0[[0.05663671]]',
#  'Co_Embolism_RC0[[0.00669047]]',
#  'Co_DVT_RC0[[0.02995278]]',
#  'Co_PE_RC0[[0.11181079]]',
#  'Co_AFib_RC0[[0.2872084]]',
#  'Co_Hypertension_RC0[[-0.05272071]]',
#  'Co_Hyperlipidemia_RC0[[-0.17246576]]',
#  'Co_Atherosclerosis_RC0[[0.05037822]]',
#  'Co_HF_RC0[[0.14755291]]',
#  'Co_HemoStroke_RC0[[-0.04504842]]',
#  'Co_IscheStroke_RC0[[-0.08884618]]',
#  'Co_OthStroke_RC0[[-0.01995292]]',
#  'Co_TIA_RC0[[-0.01370584]]',
#  'Co_COPD_RC0[[0.18679729]]',
#  'Co_Asthma_RC0[[0.03474679]]',
#  'Co_Pneumonia_RC0[[-0.09432299]]',
#  'Co_Alcoholabuse_RC0[[0.10394367]]',
#  'Co_Drugabuse_RC0[[0.01095578]]',
#  'Co_Epilepsy_RC0[[-0.05414315]]',
#  'Co_Cancer_RC0[[0.06636316]]',
#  'Co_MorbidObesity_RC0[[0.02204272]]',
#  'Co_Dementia_RC0[[0.11847651]]',
#  'Co_Depression_RC0[[-0.0181329]]',
#  'Co_Bipolar_RC0[[-0.0212721]]',
#  'Co_Psychosis_RC0[[0.1534502]]',
#  'Co_Personalitydisorder_RC0[[0.0402543]]',
#  'Co_Adjustmentdisorder_RC0[[-0.10669379]]',
#  'Co_Anxiety_RC0[[0.04151275]]',
#  'Co_Generalizedanxiety_RC0[[-0.02091167]]',
#  'Co_OldMI_RC0[[-0.02249182]]',
#  'Co_AcuteMI_RC0[[0.02821576]]',
#  'Co_PUD_RC0[[0.01638263]]',
#  'Co_UpperGIbleed_RC0[[0.14481459]]',
#  'Co_LowerGIbleed_RC0[[0.27520535]]',
#  'Co_Urogenitalbleed_RC0[[0.15814852]]',
#  'Co_Othbleed_RC0[[-0.04546558]]',
#  'Co_PVD_RC0[[0.28416025]]',
#  'Co_LiverDisease_RC0[[0.07123857]]',
#  'Co_MRI_RC0[[0.05089548]]',
#  'Co_ESRD_RC0[[0.12340892]]',
#  'Co_Obesity_RC0[[-0.10463784]]',
#  'Co_Sepsis_RC0[[-0.00185091]]',
#  'Co_Osteoarthritis_RC0[[0.06320779]]',
#  'Co_RA_RC0[[0.07522926]]',
#  'Co_NeuroPain_RC0[[0.11272955]]',
#  'Co_NeckPain_RC0[[-0.0684169]]',
#  'Co_OthArthritis_RC0[[0.05949275]]',
#  'Co_Osteoporosis_RC0[[0.11567565]]',
#  'Co_Fibromyalgia_RC0[[-0.06937706]]',
#  'Co_Migraine_RC0[[-0.06401351]]',
#  'Co_Headache_RC0[[0.02896865]]',
#  'Co_OthPain_RC0[[0.16511704]]',
#  'Co_GeneralizedPain_RC0[[0.09637448]]',
#  'Co_PainDisorder_RC0[[0.01157769]]',
#  'Co_Falls_RC0[[0.19242572]]',
#  'Co_CoagulationDisorder_RC0[[0.05540174]]',
#  'Co_WhiteBloodCell_RC0[[0.1109045]]',
#  'Co_Parkinson_RC0[[0.11389074]]',
#  'Co_Anemia_RC0[[0.29306813]]',
#  'Co_UrinaryIncontinence_RC0[[0.14823078]]',
#  'Co_DecubitusUlcer_RC0[[0.03343553]]',
#  'Co_Oxygen_RC0[[0.024356]]',
#  'Co_Mammography_RC0[[-0.13178866]]',
#  'Co_PapTest_RC0[[-0.18750615]]',
#  'Co_PSATest_RC0[[-0.11901352]]',
#  'Co_Colonoscopy_RC0[[0.03841568]]',
#  'Co_FecalOccultTest_RC0[[-0.14461682]]',
#  'Co_FluShot_RC0[[0.01021899]]',
#  'Co_PneumococcalVaccine_RC0[[0.22501073]]',
#  'Co_RenalDysfunction_RC0[[0.3532485]]',
#  'Co_Valvular_RC0[[0.16909051]]',
#  'Co_Hosp_Prior30Days_RC0[[0.18689758]]',
#  'Co_RX_Antibiotic_RC0[[0.01624065]]',
#  'Co_RX_Corticosteroid_RC0[[-0.02848035]]',
#  'Co_RX_Aspirin_RC0[[0.0326478]]',
#  'Co_RX_Dipyridamole_RC0[[-0.02955284]]',
#  'Co_RX_Clopidogrel_RC0[[0.03830295]]',
#  'Co_RX_Prasugrel_RC0[[-0.0214602]]',
#  'Co_RX_Cilostazol_RC0[[-0.03987956]]',
#  'Co_RX_Ticlopidine_RC0[[-0.00616656]]',
#  'Co_RX_Ticagrelor_RC0[[0.00692501]]',
#  'Co_RX_OthAntiplatelet_RC0[[-0.04604611]]',
#  'Co_RX_NSAIDs_RC0[[-0.04422228]]',
#  'Co_RX_Opioid_RC0[[-0.04853068]]',
#  'Co_RX_Antidepressant_RC0[[0.15577398]]',
#  'Co_RX_AAntipsychotic_RC0[[-0.10255008]]',
#  'Co_RX_TAntipsychotic_RC0[[0.04263988]]',
#  'Co_RX_Anticonvulsant_RC0[[0.10012046]]',
#  'Co_RX_PPI_RC0[[0.00913351]]',
#  'Co_RX_H2Receptor_RC0[[-0.03506414]]',
#  'Co_RX_OthGastro_RC0[[-0.02881025]]',
#  'Co_RX_ACE_RC0[[-0.09500811]]',
#  'Co_RX_ARB_RC0[[-0.02655765]]',
#  'Co_RX_BBlocker_RC0[[0.12199144]]',
#  'Co_RX_CCB_RC0[[-0.0496122]]',
#  'Co_RX_Thiazide_RC0[[-0.06710166]]',
#  'Co_RX_Loop_RC0[[0.1895051]]',
#  'Co_RX_Potassium_RC0[[0.02848065]]',
#  'Co_RX_Nitrates_RC0[[-0.10737847]]',
#  'Co_RX_Aliskiren_RC0[[-0.01347737]]',
#  'Co_RX_OthAntihypertensive_RC0[[-0.0195675]]',
#  'Co_RX_Antiarrhythmic_RC0[[0.01518731]]',
#  'Co_RX_OthAnticoagulant_RC0[[0.0194281]]',
#  'Co_RX_Insulin_RC0[[-0.03589982]]',
#  'Co_RX_Noninsulin_RC0[[-0.05278774]]',
#  'Co_RX_Digoxin_RC0[[-0.00695012]]',
#  'Co_RX_Statin_RC0[[-0.03455207]]',
#  'Co_RX_Lipid_RC0[[0.03225253]]',
#  'Co_RX_Lithium_RC0[[0.01688852]]',
#  'Co_RX_Benzo_RC0[[-0.14506778]]',
#  'Co_RX_ZDrugs_RC0[[-0.14695489]]',
#  'Co_RX_OthAnxiolytic_RC0[[-0.03065439]]',
#  'Co_RX_Barbiturate_RC0[[-8.44598142e-05]]',
#  'Co_RX_Dementia_RC0[[-0.02979954]]',
#  'Co_RX_Hormone_RC0[[-0.18669896]]',
#  'Co_RX_Osteoporosis_RC0[[0.0188554]]',
#  'Co_N_Drugs_RC0[[0.00481131]]',
#  'Co_N_Hosp_RC0[[0.01026637]]',
#  'Co_Total_HospLOS_RC0[[0.00053675]]',
#  'Co_N_MDVisit_RC0[[0.01702919]]',
#  'Co_RX_AnyAspirin_RC0[[0.02462699]]',
#  'Co_RX_AspirinMono_RC0[[0.07816247]]',
#  'Co_RX_ClopidogrelMono_RC0[[-0.01255086]]',
#  'Co_RX_AspirinClopidogrel_RC0[[0.05931486]]',
#  'Co_RX_DM_RC0[[-0.02461463]]',
#  'Co_RX_Antipsychotic_RC0[[-0.02357192]]']

# %% [markdown]
# # Low Continuity

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_low_sm,out_train_hemorrhage_low_sm = sm.fit_resample(co_train_low,out_train_hemorrhage_low)

best_clf = lr(co_train_low_sm, out_train_hemorrhage_low_sm)

train_scores(co_train_low_sm, out_train_hemorrhage_low_sm)

print()

train_scores(co_train_low, out_train_hemorrhage_low)

print()

test_scores(co_validation_low, out_validation_hemorrhage_low)

comb = [] 
for i in range(len(predictor_variable_claims)):
    comb.append(predictor_variable_claims[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6639402560455192
# 0.6481495271427508
# 0.6633483744343895
# 0.7134898797877012
# 11.607208765426215
#
# 0.700524034418063
# 0.27136785770502125
# 0.5776903995785215
# 0.7095580755754812
# 10.343745195310913
#
# 0.6422981485016225
# 0.26278520849724624
# 0.5432405333682451
# 0.6736245525582635
# 12.354836781448917
# ['Co_CAD_RC0[[0.0878172]]',
#  'Co_Embolism_RC0[[0.01157328]]',
#  'Co_DVT_RC0[[0.00521583]]',
#  'Co_PE_RC0[[0.00347012]]',
#  'Co_AFib_RC0[[0.15263376]]',
#  'Co_Hypertension_RC0[[0.0883232]]',
#  'Co_Hyperlipidemia_RC0[[0.02553041]]',
#  'Co_Atherosclerosis_RC0[[0.08751664]]',
#  'Co_HF_RC0[[0.14992544]]',
#  'Co_HemoStroke_RC0[[-0.03568562]]',
#  'Co_IscheStroke_RC0[[-0.02351662]]',
#  'Co_OthStroke_RC0[[0.00954306]]',
#  'Co_TIA_RC0[[-0.01836817]]',
#  'Co_COPD_RC0[[0.05946831]]',
#  'Co_Asthma_RC0[[0.03811484]]',
#  'Co_Pneumonia_RC0[[-0.02784151]]',
#  'Co_Alcoholabuse_RC0[[0.00345302]]',
#  'Co_Drugabuse_RC0[[0.01861246]]',
#  'Co_Epilepsy_RC0[[-0.00029239]]',
#  'Co_Cancer_RC0[[0.02010883]]',
#  'Co_MorbidObesity_RC0[[0.00395292]]',
#  'Co_Dementia_RC0[[-0.02384338]]',
#  'Co_Depression_RC0[[-0.0157814]]',
#  'Co_Bipolar_RC0[[-0.00327894]]',
#  'Co_Psychosis_RC0[[-0.04640596]]',
#  'Co_Personalitydisorder_RC0[[0.0027137]]',
#  'Co_Adjustmentdisorder_RC0[[-0.00614763]]',
#  'Co_Anxiety_RC0[[0.00643283]]',
#  'Co_Generalizedanxiety_RC0[[0.00990353]]',
#  'Co_OldMI_RC0[[-0.06605589]]',
#  'Co_AcuteMI_RC0[[0.00422483]]',
#  'Co_PUD_RC0[[0.01841482]]',
#  'Co_UpperGIbleed_RC0[[0.05076041]]',
#  'Co_LowerGIbleed_RC0[[0.16344625]]',
#  'Co_Urogenitalbleed_RC0[[0.0541449]]',
#  'Co_Othbleed_RC0[[0.10922914]]',
#  'Co_PVD_RC0[[0.09270859]]',
#  'Co_LiverDisease_RC0[[0.01478479]]',
#  'Co_MRI_RC0[[0.06187698]]',
#  'Co_ESRD_RC0[[0.02994909]]',
#  'Co_Obesity_RC0[[0.0305389]]',
#  'Co_Sepsis_RC0[[-0.00185494]]',
#  'Co_Osteoarthritis_RC0[[0.05476486]]',
#  'Co_RA_RC0[[1.34875873e-05]]',
#  'Co_NeuroPain_RC0[[0.01862712]]',
#  'Co_NeckPain_RC0[[0.05413318]]',
#  'Co_OthArthritis_RC0[[0.03676933]]',
#  'Co_Osteoporosis_RC0[[0.06139757]]',
#  'Co_Fibromyalgia_RC0[[-0.05139144]]',
#  'Co_Migraine_RC0[[0.0048974]]',
#  'Co_Headache_RC0[[-0.02356113]]',
#  'Co_OthPain_RC0[[0.07590588]]',
#  'Co_GeneralizedPain_RC0[[0.0477705]]',
#  'Co_PainDisorder_RC0[[-0.00208379]]',
#  'Co_Falls_RC0[[0.06292778]]',
#  'Co_CoagulationDisorder_RC0[[0.01939851]]',
#  'Co_WhiteBloodCell_RC0[[0.01945565]]',
#  'Co_Parkinson_RC0[[0.02681412]]',
#  'Co_Anemia_RC0[[0.25775922]]',
#  'Co_UrinaryIncontinence_RC0[[0.02309477]]',
#  'Co_DecubitusUlcer_RC0[[-0.0061938]]',
#  'Co_Oxygen_RC0[[0.04645254]]',
#  'Co_Mammography_RC0[[-0.06811254]]',
#  'Co_PapTest_RC0[[-0.05984752]]',
#  'Co_PSATest_RC0[[-0.07079439]]',
#  'Co_Colonoscopy_RC0[[-0.02039101]]',
#  'Co_FecalOccultTest_RC0[[-0.02444325]]',
#  'Co_FluShot_RC0[[0.05623127]]',
#  'Co_PneumococcalVaccine_RC0[[0.16829506]]',
#  'Co_RenalDysfunction_RC0[[0.12437714]]',
#  'Co_Valvular_RC0[[0.06980667]]',
#  'Co_Hosp_Prior30Days_RC0[[0.17918745]]',
#  'Co_RX_Antibiotic_RC0[[0.00681334]]',
#  'Co_RX_Corticosteroid_RC0[[0.08967157]]',
#  'Co_RX_Aspirin_RC0[[-0.00059715]]',
#  'Co_RX_Dipyridamole_RC0[[0.00197259]]',
#  'Co_RX_Clopidogrel_RC0[[0.01717827]]',
#  'Co_RX_Prasugrel_RC0[[0.00115649]]',
#  'Co_RX_Cilostazol_RC0[[-0.00052618]]',
#  'Co_RX_Ticlopidine_RC0[[-0.00283665]]',
#  'Co_RX_Ticagrelor_RC0[[0.00531244]]',
#  'Co_RX_OthAntiplatelet_RC0[[-0.00336283]]',
#  'Co_RX_NSAIDs_RC0[[-0.04813709]]',
#  'Co_RX_Opioid_RC0[[0.01512342]]',
#  'Co_RX_Antidepressant_RC0[[0.04654531]]',
#  'Co_RX_AAntipsychotic_RC0[[-0.01709372]]',
#  'Co_RX_TAntipsychotic_RC0[[0.01821477]]',
#  'Co_RX_Anticonvulsant_RC0[[-0.01393135]]',
#  'Co_RX_PPI_RC0[[0.00065209]]',
#  'Co_RX_H2Receptor_RC0[[-0.03907375]]',
#  'Co_RX_OthGastro_RC0[[-0.0249254]]',
#  'Co_RX_ACE_RC0[[-0.08322453]]',
#  'Co_RX_ARB_RC0[[-0.04600449]]',
#  'Co_RX_BBlocker_RC0[[0.03054418]]',
#  'Co_RX_CCB_RC0[[0.0550964]]',
#  'Co_RX_Thiazide_RC0[[-0.02512221]]',
#  'Co_RX_Loop_RC0[[0.14077977]]',
#  'Co_RX_Potassium_RC0[[0.05594681]]',
#  'Co_RX_Nitrates_RC0[[0.03199475]]',
#  'Co_RX_Aliskiren_RC0[[-0.00501053]]',
#  'Co_RX_OthAntihypertensive_RC0[[-0.03676921]]',
#  'Co_RX_Antiarrhythmic_RC0[[-0.06820051]]',
#  'Co_RX_OthAnticoagulant_RC0[[-0.02358273]]',
#  'Co_RX_Insulin_RC0[[0.04062502]]',
#  'Co_RX_Noninsulin_RC0[[-0.03885312]]',
#  'Co_RX_Digoxin_RC0[[0.00449405]]',
#  'Co_RX_Statin_RC0[[0.05150609]]',
#  'Co_RX_Lipid_RC0[[-0.04033506]]',
#  'Co_RX_Lithium_RC0[[0.00332197]]',
#  'Co_RX_Benzo_RC0[[-0.05516778]]',
#  'Co_RX_ZDrugs_RC0[[-0.04482341]]',
#  'Co_RX_OthAnxiolytic_RC0[[-0.03531684]]',
#  'Co_RX_Barbiturate_RC0[[0.]]',
#  'Co_RX_Dementia_RC0[[-0.05221398]]',
#  'Co_RX_Hormone_RC0[[-0.02437282]]',
#  'Co_RX_Osteoporosis_RC0[[-0.01786189]]',
#  'Co_N_Drugs_RC0[[-0.00318674]]',
#  'Co_N_Hosp_RC0[[0.09916759]]',
#  'Co_Total_HospLOS_RC0[[0.00597321]]',
#  'Co_N_MDVisit_RC0[[0.0046915]]',
#  'Co_RX_AnyAspirin_RC0[[-0.0012765]]',
#  'Co_RX_AspirinMono_RC0[[-0.0344772]]',
#  'Co_RX_ClopidogrelMono_RC0[[-0.01360565]]',
#  'Co_RX_AspirinClopidogrel_RC0[[0.02633829]]',
#  'Co_RX_DM_RC0[[0.0043708]]',
#  'Co_RX_Antipsychotic_RC0[[0.01182526]]']
