# %%
import pandas as pd
medicare = pd.read_csv("/netapp2/home/se197/RPDR/Josh Lin/3_EHR_V2/CMS/Data/final_medicare.csv")

# %%
train_set = medicare[medicare.Hospital != 'BWH'] # MGH
validation_set = medicare[medicare.Hospital == 'BWH'] # BWH and Neither 
import numpy as np

fifty_perc_EHR_cont = np.percentile(medicare['Cal_MPEC_R0'],50)
train_set_high = train_set[train_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
train_set_low= train_set[train_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

validation_set_high = validation_set[validation_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
validation_set_low = validation_set[validation_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

# %%
predictor_variable = [
        'Co_CAD_R0', 'Co_Embolism_R0', 'Co_DVT_R0', 'Co_PE_R0', 'Co_AFib_R0',
        'Co_Hypertension_R0', 'Co_Hyperlipidemia_R0', 'Co_Atherosclerosis_R0',
        'Co_HF_R0', 'Co_HemoStroke_R0', 'Co_IscheStroke_R0', 'Co_OthStroke_R0',
        'Co_TIA_R0', 'Co_COPD_R0', 'Co_Asthma_R0', 'Co_Pneumonia_R0', 'Co_Alcoholabuse_R0',
        'Co_Drugabuse_R0', 'Co_Epilepsy_R0', 'Co_Cancer_R0', 'Co_MorbidObesity_R0',
        'Co_Dementia_R0', 'Co_Depression_R0', 'Co_Bipolar_R0', 'Co_Psychosis_R0',
        'Co_Personalitydisorder_R0', 'Co_Adjustmentdisorder_R0', 'Co_Anxiety_R0',
        'Co_Generalizedanxiety_R0', 'Co_OldMI_R0', 'Co_AcuteMI_R0', 'Co_PUD_R0',
        'Co_UpperGIbleed_R0', 'Co_LowerGIbleed_R0', 'Co_Urogenitalbleed_R0',
        'Co_Othbleed_R0', 'Co_PVD_R0', 'Co_LiverDisease_R0', 'Co_MRI_R0',
        'Co_ESRD_R0', 'Co_Obesity_R0', 'Co_Sepsis_R0', 'Co_Osteoarthritis_R0',
        'Co_RA_R0', 'Co_NeuroPain_R0', 'Co_NeckPain_R0', 'Co_OthArthritis_R0',
        'Co_Osteoporosis_R0', 'Co_Fibromyalgia_R0', 'Co_Migraine_R0', 'Co_Headache_R0',
        'Co_OthPain_R0', 'Co_GeneralizedPain_R0', 'Co_PainDisorder_R0',
        'Co_Falls_R0', 'Co_CoagulationDisorder_R0', 'Co_WhiteBloodCell_R0', 'Co_Parkinson_R0',
        'Co_Anemia_R0', 'Co_UrinaryIncontinence_R0', 'Co_DecubitusUlcer_R0',
        'Co_Oxygen_R0', 'Co_Mammography_R0', 'Co_PapTest_R0', 'Co_PSATest_R0',
        'Co_Colonoscopy_R0', 'Co_FecalOccultTest_R0', 'Co_FluShot_R0', 'Co_PneumococcalVaccine_R0', 'Co_RenalDysfunction_R0', 'Co_Valvular_R0', 'Co_Hosp_Prior30Days_R0',
        'Co_RX_Antibiotic_R0', 'Co_RX_Corticosteroid_R0', 'Co_RX_Aspirin_R0', 'Co_RX_Dipyridamole_R0',
        'Co_RX_Clopidogrel_R0', 'Co_RX_Prasugrel_R0', 'Co_RX_Cilostazol_R0', 'Co_RX_Ticlopidine_R0',
        'Co_RX_Ticagrelor_R0', 'Co_RX_OthAntiplatelet_R0', 'Co_RX_NSAIDs_R0',
        'Co_RX_Opioid_R0', 'Co_RX_Antidepressant_R0', 'Co_RX_AAntipsychotic_R0', 'Co_RX_TAntipsychotic_R0',
        'Co_RX_Anticonvulsant_R0', 'Co_RX_PPI_R0', 'Co_RX_H2Receptor_R0', 'Co_RX_OthGastro_R0',
        'Co_RX_ACE_R0', 'Co_RX_ARB_R0', 'Co_RX_BBlocker_R0', 'Co_RX_CCB_R0', 'Co_RX_Thiazide_R0',
        'Co_RX_Loop_R0', 'Co_RX_Potassium_R0', 'Co_RX_Nitrates_R0', 'Co_RX_Aliskiren_R0',
        'Co_RX_OthAntihypertensive_R0', 'Co_RX_Antiarrhythmic_R0', 'Co_RX_OthAnticoagulant_R0',
        'Co_RX_Insulin_R0', 'Co_RX_Noninsulin_R0', 'Co_RX_Digoxin_R0', 'Co_RX_Statin_R0',
        'Co_RX_Lipid_R0', 'Co_RX_Lithium_R0', 'Co_RX_Benzo_R0', 'Co_RX_ZDrugs_R0',
        'Co_RX_OthAnxiolytic_R0', 'Co_RX_Barbiturate_R0', 'Co_RX_Dementia_R0', 'Co_RX_Hormone_R0',
        'Co_RX_Osteoporosis_R0', 'Co_N_Drugs_R0', 'Co_N_Hosp_R0', 'Co_Total_HospLOS_R0',
        'Co_N_MDVisit_R0', 'Co_RX_AnyAspirin_R0', 'Co_RX_AspirinMono_R0', 'Co_RX_ClopidogrelMono_R0',
        'Co_RX_AspirinClopidogrel_R0', 'Co_RX_DM_R0', 'Co_RX_Antipsychotic_R0'
]

co_train_gpop = train_set[predictor_variable]
co_train_high = train_set_high[predictor_variable]
co_train_low = train_set_low[predictor_variable]

co_validation_gpop = validation_set[predictor_variable]
co_validation_high = validation_set_high[predictor_variable]
co_validation_low = validation_set_low[predictor_variable]

# %%
out_train_death_gpop = train_set['ehr_death']
out_train_death_high = train_set_high['ehr_death']
out_train_death_low = train_set_low['ehr_death']

out_validation_death_gpop = validation_set['ehr_death']
out_validation_death_high = validation_set_high['ehr_death']
out_validation_death_low = validation_set_low['ehr_death']

# %%
def lr(X_train, y_train):
    from sklearn.linear_model import Lasso
    from sklearn.decomposition import PCA
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler 

    model = LogisticRegression(penalty = 'l1', solver = 'liblinear')
    param_grid = [
        {'C' : np.logspace(-4, 4, 20)}
        ]
    clf = GridSearchCV(model, param_grid, cv = 5, verbose = True, n_jobs = -1)
    best_clf = clf.fit(X_train, y_train)
    return best_clf

# %%
def scores(X_train,y_train):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_train)
    actual = y_train
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.decision_function(X_train)))
    print(log_loss(actual,pred))

# %% [markdown]
# # General Population

# %%
best_clf = lr(co_train_gpop, out_train_death_gpop)
scores(co_train_gpop, out_train_death_gpop)
print()
scores(co_validation_gpop, out_validation_death_gpop)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 0.9222246361068868
# 0.0
# 0.4917064356206274
# 0.5006990055433509
# 2.686265902537047
#
# 0.910301156761069
# 0.0
# 0.49033668514460055
# 0.4895123948742101
# 3.0980882895115838
# ['Co_CAD_R0[[0.]]',
#  'Co_Embolism_R0[[0.]]',
#  'Co_DVT_R0[[0.]]',
#  'Co_PE_R0[[0.]]',
#  'Co_AFib_R0[[0.]]',
#  'Co_Hypertension_R0[[0.]]',
#  'Co_Hyperlipidemia_R0[[0.]]',
#  'Co_Atherosclerosis_R0[[0.]]',
#  'Co_HF_R0[[0.]]',
#  'Co_HemoStroke_R0[[0.]]',
#  'Co_IscheStroke_R0[[0.]]',
#  'Co_OthStroke_R0[[0.]]',
#  'Co_TIA_R0[[0.]]',
#  'Co_COPD_R0[[0.]]',
#  'Co_Asthma_R0[[0.]]',
#  'Co_Pneumonia_R0[[0.]]',
#  'Co_Alcoholabuse_R0[[0.]]',
#  'Co_Drugabuse_R0[[0.]]',
#  'Co_Epilepsy_R0[[0.]]',
#  'Co_Cancer_R0[[0.]]',
#  'Co_MorbidObesity_R0[[0.]]',
#  'Co_Dementia_R0[[0.]]',
#  'Co_Depression_R0[[0.]]',
#  'Co_Bipolar_R0[[0.]]',
#  'Co_Psychosis_R0[[0.]]',
#  'Co_Personalitydisorder_R0[[0.]]',
#  'Co_Adjustmentdisorder_R0[[0.]]',
#  'Co_Anxiety_R0[[0.]]',
#  'Co_Generalizedanxiety_R0[[0.]]',
#  'Co_OldMI_R0[[0.]]',
#  'Co_AcuteMI_R0[[0.]]',
#  'Co_PUD_R0[[0.]]',
#  'Co_UpperGIbleed_R0[[0.]]',
#  'Co_LowerGIbleed_R0[[0.]]',
#  'Co_Urogenitalbleed_R0[[0.]]',
#  'Co_Othbleed_R0[[0.]]',
#  'Co_PVD_R0[[0.]]',
#  'Co_LiverDisease_R0[[0.]]',
#  'Co_MRI_R0[[0.]]',
#  'Co_ESRD_R0[[0.]]',
#  'Co_Obesity_R0[[0.]]',
#  'Co_Sepsis_R0[[0.]]',
#  'Co_Osteoarthritis_R0[[0.]]',
#  'Co_RA_R0[[0.]]',
#  'Co_NeuroPain_R0[[0.]]',
#  'Co_NeckPain_R0[[0.]]',
#  'Co_OthArthritis_R0[[0.]]',
#  'Co_Osteoporosis_R0[[0.]]',
#  'Co_Fibromyalgia_R0[[0.]]',
#  'Co_Migraine_R0[[0.]]',
#  'Co_Headache_R0[[0.]]',
#  'Co_OthPain_R0[[0.]]',
#  'Co_GeneralizedPain_R0[[0.]]',
#  'Co_PainDisorder_R0[[0.]]',
#  'Co_Falls_R0[[0.]]',
#  'Co_CoagulationDisorder_R0[[0.]]',
#  'Co_WhiteBloodCell_R0[[0.]]',
#  'Co_Parkinson_R0[[0.]]',
#  'Co_Anemia_R0[[0.]]',
#  'Co_UrinaryIncontinence_R0[[0.]]',
#  'Co_DecubitusUlcer_R0[[0.]]',
#  'Co_Oxygen_R0[[0.]]',
#  'Co_Mammography_R0[[0.]]',
#  'Co_PapTest_R0[[0.]]',
#  'Co_PSATest_R0[[0.]]',
#  'Co_Colonoscopy_R0[[0.]]',
#  'Co_FecalOccultTest_R0[[0.]]',
#  'Co_FluShot_R0[[0.]]',
#  'Co_PneumococcalVaccine_R0[[0.]]',
#  'Co_RenalDysfunction_R0[[0.]]',
#  'Co_Valvular_R0[[0.]]',
#  'Co_Hosp_Prior30Days_R0[[0.]]',
#  'Co_RX_Antibiotic_R0[[0.]]',
#  'Co_RX_Corticosteroid_R0[[0.]]',
#  'Co_RX_Aspirin_R0[[0.]]',
#  'Co_RX_Dipyridamole_R0[[0.]]',
#  'Co_RX_Clopidogrel_R0[[0.]]',
#  'Co_RX_Prasugrel_R0[[0.]]',
#  'Co_RX_Cilostazol_R0[[0.]]',
#  'Co_RX_Ticlopidine_R0[[0.]]',
#  'Co_RX_Ticagrelor_R0[[0.]]',
#  'Co_RX_OthAntiplatelet_R0[[0.]]',
#  'Co_RX_NSAIDs_R0[[0.]]',
#  'Co_RX_Opioid_R0[[0.]]',
#  'Co_RX_Antidepressant_R0[[0.]]',
#  'Co_RX_AAntipsychotic_R0[[0.]]',
#  'Co_RX_TAntipsychotic_R0[[0.]]',
#  'Co_RX_Anticonvulsant_R0[[0.]]',
#  'Co_RX_PPI_R0[[0.]]',
#  'Co_RX_H2Receptor_R0[[0.]]',
#  'Co_RX_OthGastro_R0[[0.]]',
#  'Co_RX_ACE_R0[[0.]]',
#  'Co_RX_ARB_R0[[0.]]',
#  'Co_RX_BBlocker_R0[[0.]]',
#  'Co_RX_CCB_R0[[0.]]',
#  'Co_RX_Thiazide_R0[[0.]]',
#  'Co_RX_Loop_R0[[0.]]',
#  'Co_RX_Potassium_R0[[0.]]',
#  'Co_RX_Nitrates_R0[[0.]]',
#  'Co_RX_Aliskiren_R0[[0.]]',
#  'Co_RX_OthAntihypertensive_R0[[0.]]',
#  'Co_RX_Antiarrhythmic_R0[[0.]]',
#  'Co_RX_OthAnticoagulant_R0[[0.]]',
#  'Co_RX_Insulin_R0[[0.]]',
#  'Co_RX_Noninsulin_R0[[0.]]',
#  'Co_RX_Digoxin_R0[[0.]]',
#  'Co_RX_Statin_R0[[0.]]',
#  'Co_RX_Lipid_R0[[0.]]',
#  'Co_RX_Lithium_R0[[0.]]',
#  'Co_RX_Benzo_R0[[0.]]',
#  'Co_RX_ZDrugs_R0[[0.]]',
#  'Co_RX_OthAnxiolytic_R0[[0.]]',
#  'Co_RX_Barbiturate_R0[[0.]]',
#  'Co_RX_Dementia_R0[[0.]]',
#  'Co_RX_Hormone_R0[[0.]]',
#  'Co_RX_Osteoporosis_R0[[0.]]',
#  'Co_N_Drugs_R0[[-0.03828355]]',
#  'Co_N_Hosp_R0[[0.]]',
#  'Co_Total_HospLOS_R0[[0.]]',
#  'Co_N_MDVisit_R0[[-0.1175117]]',
#  'Co_RX_AnyAspirin_R0[[0.]]',
#  'Co_RX_AspirinMono_R0[[0.]]',
#  'Co_RX_ClopidogrelMono_R0[[0.]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.]]',
#  'Co_RX_DM_R0[[0.]]',
#  'Co_RX_Antipsychotic_R0[[0.]]']

# %% [markdown]
# # Low Continuity

# %%
best_clf = lr(co_train_low, out_train_death_low)
scores(co_train_low, out_train_death_low)
print()
scores(co_validation_low, out_validation_death_low)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 0.9052209354984797
# 0.1690300623936472
# 0.5465806302035516
# 0.8079519611307071
# 3.273557623206981
#
# 0.8838518801297958
# 0.12383009359251261
# 0.5270469671497913
# 0.7701767300263593
# 4.011621037904878
# ['Co_CAD_R0[[0.03348615]]',
#  'Co_Embolism_R0[[0.]]',
#  'Co_DVT_R0[[0.]]',
#  'Co_PE_R0[[0.02652518]]',
#  'Co_AFib_R0[[0.06644471]]',
#  'Co_Hypertension_R0[[-0.09480041]]',
#  'Co_Hyperlipidemia_R0[[-0.32608928]]',
#  'Co_Atherosclerosis_R0[[0.]]',
#  'Co_HF_R0[[0.59309343]]',
#  'Co_HemoStroke_R0[[0.53811768]]',
#  'Co_IscheStroke_R0[[0.2375041]]',
#  'Co_OthStroke_R0[[0.]]',
#  'Co_TIA_R0[[-0.2708096]]',
#  'Co_COPD_R0[[0.54345013]]',
#  'Co_Asthma_R0[[-0.53987167]]',
#  'Co_Pneumonia_R0[[0.39656955]]',
#  'Co_Alcoholabuse_R0[[0.]]',
#  'Co_Drugabuse_R0[[0.]]',
#  'Co_Epilepsy_R0[[0.]]',
#  'Co_Cancer_R0[[0.58207558]]',
#  'Co_MorbidObesity_R0[[0.]]',
#  'Co_Dementia_R0[[0.92363366]]',
#  'Co_Depression_R0[[0.]]',
#  'Co_Bipolar_R0[[0.]]',
#  'Co_Psychosis_R0[[-0.19279987]]',
#  'Co_Personalitydisorder_R0[[0.]]',
#  'Co_Adjustmentdisorder_R0[[0.]]',
#  'Co_Anxiety_R0[[-0.13416513]]',
#  'Co_Generalizedanxiety_R0[[0.]]',
#  'Co_OldMI_R0[[-0.18485204]]',
#  'Co_AcuteMI_R0[[0.]]',
#  'Co_PUD_R0[[-0.26196972]]',
#  'Co_UpperGIbleed_R0[[0.]]',
#  'Co_LowerGIbleed_R0[[0.1785375]]',
#  'Co_Urogenitalbleed_R0[[0.]]',
#  'Co_Othbleed_R0[[0.]]',
#  'Co_PVD_R0[[0.]]',
#  'Co_LiverDisease_R0[[0.03419047]]',
#  'Co_MRI_R0[[0.]]',
#  'Co_ESRD_R0[[0.4069281]]',
#  'Co_Obesity_R0[[-0.32540261]]',
#  'Co_Sepsis_R0[[0.5798947]]',
#  'Co_Osteoarthritis_R0[[0.]]',
#  'Co_RA_R0[[0.]]',
#  'Co_NeuroPain_R0[[0.]]',
#  'Co_NeckPain_R0[[0.]]',
#  'Co_OthArthritis_R0[[0.]]',
#  'Co_Osteoporosis_R0[[0.]]',
#  'Co_Fibromyalgia_R0[[0.]]',
#  'Co_Migraine_R0[[0.]]',
#  'Co_Headache_R0[[-0.01862145]]',
#  'Co_OthPain_R0[[0.]]',
#  'Co_GeneralizedPain_R0[[0.]]',
#  'Co_PainDisorder_R0[[0.]]',
#  'Co_Falls_R0[[0.14655829]]',
#  'Co_CoagulationDisorder_R0[[0.]]',
#  'Co_WhiteBloodCell_R0[[0.]]',
#  'Co_Parkinson_R0[[0.]]',
#  'Co_Anemia_R0[[0.]]',
#  'Co_UrinaryIncontinence_R0[[0.]]',
#  'Co_DecubitusUlcer_R0[[0.02860939]]',
#  'Co_Oxygen_R0[[0.]]',
#  'Co_Mammography_R0[[0.]]',
#  'Co_PapTest_R0[[0.]]',
#  'Co_PSATest_R0[[0.]]',
#  'Co_Colonoscopy_R0[[0.]]',
#  'Co_FecalOccultTest_R0[[0.]]',
#  'Co_FluShot_R0[[0.]]',
#  'Co_PneumococcalVaccine_R0[[0.]]',
#  'Co_RenalDysfunction_R0[[0.35784653]]',
#  'Co_Valvular_R0[[0.0337397]]',
#  'Co_Hosp_Prior30Days_R0[[0.90452223]]',
#  'Co_RX_Antibiotic_R0[[0.]]',
#  'Co_RX_Corticosteroid_R0[[0.11126824]]',
#  'Co_RX_Aspirin_R0[[0.]]',
#  'Co_RX_Dipyridamole_R0[[0.]]',
#  'Co_RX_Clopidogrel_R0[[0.]]',
#  'Co_RX_Prasugrel_R0[[0.]]',
#  'Co_RX_Cilostazol_R0[[0.]]',
#  'Co_RX_Ticlopidine_R0[[0.]]',
#  'Co_RX_Ticagrelor_R0[[0.]]',
#  'Co_RX_OthAntiplatelet_R0[[0.]]',
#  'Co_RX_NSAIDs_R0[[0.]]',
#  'Co_RX_Opioid_R0[[0.21484411]]',
#  'Co_RX_Antidepressant_R0[[0.]]',
#  'Co_RX_AAntipsychotic_R0[[0.]]',
#  'Co_RX_TAntipsychotic_R0[[0.]]',
#  'Co_RX_Anticonvulsant_R0[[0.08973162]]',
#  'Co_RX_PPI_R0[[0.29286713]]',
#  'Co_RX_H2Receptor_R0[[0.16567402]]',
#  'Co_RX_OthGastro_R0[[0.]]',
#  'Co_RX_ACE_R0[[0.]]',
#  'Co_RX_ARB_R0[[-0.14302815]]',
#  'Co_RX_BBlocker_R0[[0.]]',
#  'Co_RX_CCB_R0[[0.]]',
#  'Co_RX_Thiazide_R0[[-0.13082397]]',
#  'Co_RX_Loop_R0[[0.26461987]]',
#  'Co_RX_Potassium_R0[[0.]]',
#  'Co_RX_Nitrates_R0[[0.]]',
#  'Co_RX_Aliskiren_R0[[0.]]',
#  'Co_RX_OthAntihypertensive_R0[[-0.03090534]]',
#  'Co_RX_Antiarrhythmic_R0[[0.]]',
#  'Co_RX_OthAnticoagulant_R0[[0.]]',
#  'Co_RX_Insulin_R0[[0.]]',
#  'Co_RX_Noninsulin_R0[[-0.16877983]]',
#  'Co_RX_Digoxin_R0[[0.1678407]]',
#  'Co_RX_Statin_R0[[-0.36657884]]',
#  'Co_RX_Lipid_R0[[0.]]',
#  'Co_RX_Lithium_R0[[0.]]',
#  'Co_RX_Benzo_R0[[0.]]',
#  'Co_RX_ZDrugs_R0[[0.]]',
#  'Co_RX_OthAnxiolytic_R0[[0.]]',
#  'Co_RX_Barbiturate_R0[[0.]]',
#  'Co_RX_Dementia_R0[[0.]]',
#  'Co_RX_Hormone_R0[[0.]]',
#  'Co_RX_Osteoporosis_R0[[0.]]',
#  'Co_N_Drugs_R0[[-0.00514367]]',
#  'Co_N_Hosp_R0[[-0.02509432]]',
#  'Co_Total_HospLOS_R0[[-0.00385642]]',
#  'Co_N_MDVisit_R0[[-0.30582928]]',
#  'Co_RX_AnyAspirin_R0[[0.]]',
#  'Co_RX_AspirinMono_R0[[-0.07852027]]',
#  'Co_RX_ClopidogrelMono_R0[[0.]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.]]',
#  'Co_RX_DM_R0[[0.]]',
#  'Co_RX_Antipsychotic_R0[[0.03682827]]']

# %% [markdown]
# # High Continuity

# %%
best_clf = lr(co_train_high, out_train_death_high)
scores(co_train_high, out_train_death_high)
print()
scores(co_validation_high, out_validation_death_high)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 0.9413624433309473
# 0.0
# 0.4938476366913679
# 0.3270198275312464
# 2.025269458136316
#
# 0.938504907078722
# 0.0
# 0.4935323055299337
# 0.31018585061802567
# 2.1239652637922735
# ['Co_CAD_R0[[0.]]',
#  'Co_Embolism_R0[[0.]]',
#  'Co_DVT_R0[[0.]]',
#  'Co_PE_R0[[0.]]',
#  'Co_AFib_R0[[0.]]',
#  'Co_Hypertension_R0[[0.]]',
#  'Co_Hyperlipidemia_R0[[0.]]',
#  'Co_Atherosclerosis_R0[[0.]]',
#  'Co_HF_R0[[0.]]',
#  'Co_HemoStroke_R0[[0.]]',
#  'Co_IscheStroke_R0[[0.]]',
#  'Co_OthStroke_R0[[0.]]',
#  'Co_TIA_R0[[0.]]',
#  'Co_COPD_R0[[0.]]',
#  'Co_Asthma_R0[[0.]]',
#  'Co_Pneumonia_R0[[0.]]',
#  'Co_Alcoholabuse_R0[[0.]]',
#  'Co_Drugabuse_R0[[0.]]',
#  'Co_Epilepsy_R0[[0.]]',
#  'Co_Cancer_R0[[0.]]',
#  'Co_MorbidObesity_R0[[0.]]',
#  'Co_Dementia_R0[[0.]]',
#  'Co_Depression_R0[[0.]]',
#  'Co_Bipolar_R0[[0.]]',
#  'Co_Psychosis_R0[[0.]]',
#  'Co_Personalitydisorder_R0[[0.]]',
#  'Co_Adjustmentdisorder_R0[[0.]]',
#  'Co_Anxiety_R0[[0.]]',
#  'Co_Generalizedanxiety_R0[[0.]]',
#  'Co_OldMI_R0[[0.]]',
#  'Co_AcuteMI_R0[[0.]]',
#  'Co_PUD_R0[[0.]]',
#  'Co_UpperGIbleed_R0[[0.]]',
#  'Co_LowerGIbleed_R0[[0.]]',
#  'Co_Urogenitalbleed_R0[[0.]]',
#  'Co_Othbleed_R0[[0.]]',
#  'Co_PVD_R0[[0.]]',
#  'Co_LiverDisease_R0[[0.]]',
#  'Co_MRI_R0[[0.]]',
#  'Co_ESRD_R0[[0.]]',
#  'Co_Obesity_R0[[0.]]',
#  'Co_Sepsis_R0[[0.]]',
#  'Co_Osteoarthritis_R0[[0.]]',
#  'Co_RA_R0[[0.]]',
#  'Co_NeuroPain_R0[[0.]]',
#  'Co_NeckPain_R0[[0.]]',
#  'Co_OthArthritis_R0[[0.]]',
#  'Co_Osteoporosis_R0[[0.]]',
#  'Co_Fibromyalgia_R0[[0.]]',
#  'Co_Migraine_R0[[0.]]',
#  'Co_Headache_R0[[0.]]',
#  'Co_OthPain_R0[[0.]]',
#  'Co_GeneralizedPain_R0[[0.]]',
#  'Co_PainDisorder_R0[[0.]]',
#  'Co_Falls_R0[[0.]]',
#  'Co_CoagulationDisorder_R0[[0.]]',
#  'Co_WhiteBloodCell_R0[[0.]]',
#  'Co_Parkinson_R0[[0.]]',
#  'Co_Anemia_R0[[0.]]',
#  'Co_UrinaryIncontinence_R0[[0.]]',
#  'Co_DecubitusUlcer_R0[[0.]]',
#  'Co_Oxygen_R0[[0.]]',
#  'Co_Mammography_R0[[0.]]',
#  'Co_PapTest_R0[[0.]]',
#  'Co_PSATest_R0[[0.]]',
#  'Co_Colonoscopy_R0[[0.]]',
#  'Co_FecalOccultTest_R0[[0.]]',
#  'Co_FluShot_R0[[0.]]',
#  'Co_PneumococcalVaccine_R0[[0.]]',
#  'Co_RenalDysfunction_R0[[0.]]',
#  'Co_Valvular_R0[[0.]]',
#  'Co_Hosp_Prior30Days_R0[[0.]]',
#  'Co_RX_Antibiotic_R0[[0.]]',
#  'Co_RX_Corticosteroid_R0[[0.]]',
#  'Co_RX_Aspirin_R0[[0.]]',
#  'Co_RX_Dipyridamole_R0[[0.]]',
#  'Co_RX_Clopidogrel_R0[[0.]]',
#  'Co_RX_Prasugrel_R0[[0.]]',
#  'Co_RX_Cilostazol_R0[[0.]]',
#  'Co_RX_Ticlopidine_R0[[0.]]',
#  'Co_RX_Ticagrelor_R0[[0.]]',
#  'Co_RX_OthAntiplatelet_R0[[0.]]',
#  'Co_RX_NSAIDs_R0[[0.]]',
#  'Co_RX_Opioid_R0[[0.]]',
#  'Co_RX_Antidepressant_R0[[0.]]',
#  'Co_RX_AAntipsychotic_R0[[0.]]',
#  'Co_RX_TAntipsychotic_R0[[0.]]',
#  'Co_RX_Anticonvulsant_R0[[0.]]',
#  'Co_RX_PPI_R0[[0.]]',
#  'Co_RX_H2Receptor_R0[[0.]]',
#  'Co_RX_OthGastro_R0[[0.]]',
#  'Co_RX_ACE_R0[[0.]]',
#  'Co_RX_ARB_R0[[0.]]',
#  'Co_RX_BBlocker_R0[[0.]]',
#  'Co_RX_CCB_R0[[0.]]',
#  'Co_RX_Thiazide_R0[[0.]]',
#  'Co_RX_Loop_R0[[0.]]',
#  'Co_RX_Potassium_R0[[0.]]',
#  'Co_RX_Nitrates_R0[[0.]]',
#  'Co_RX_Aliskiren_R0[[0.]]',
#  'Co_RX_OthAntihypertensive_R0[[0.]]',
#  'Co_RX_Antiarrhythmic_R0[[0.]]',
#  'Co_RX_OthAnticoagulant_R0[[0.]]',
#  'Co_RX_Insulin_R0[[0.]]',
#  'Co_RX_Noninsulin_R0[[0.]]',
#  'Co_RX_Digoxin_R0[[0.]]',
#  'Co_RX_Statin_R0[[0.]]',
#  'Co_RX_Lipid_R0[[0.]]',
#  'Co_RX_Lithium_R0[[0.]]',
#  'Co_RX_Benzo_R0[[0.]]',
#  'Co_RX_ZDrugs_R0[[0.]]',
#  'Co_RX_OthAnxiolytic_R0[[0.]]',
#  'Co_RX_Barbiturate_R0[[0.]]',
#  'Co_RX_Dementia_R0[[0.]]',
#  'Co_RX_Hormone_R0[[0.]]',
#  'Co_RX_Osteoporosis_R0[[0.]]',
#  'Co_N_Drugs_R0[[-0.02731747]]',
#  'Co_N_Hosp_R0[[0.]]',
#  'Co_Total_HospLOS_R0[[0.]]',
#  'Co_N_MDVisit_R0[[-0.09754095]]',
#  'Co_RX_AnyAspirin_R0[[0.]]',
#  'Co_RX_AspirinMono_R0[[0.]]',
#  'Co_RX_ClopidogrelMono_R0[[0.]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.]]',
#  'Co_RX_DM_R0[[0.]]',
#  'Co_RX_Antipsychotic_R0[[0.]]']
