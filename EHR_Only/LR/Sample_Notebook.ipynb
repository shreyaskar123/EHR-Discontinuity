# %%
#!/usr/bin/env python
# coding: utf-8

# In[13]:


import pandas as pd
medicare = pd.read_csv("/netapp2/home/se197/RPDR/Josh Lin/3_EHR_V2/CMS/Data/final_medicare.csv")


# In[14]:


medicare = medicare[(medicare.Co_CAD_R0 == 1) | (medicare.Co_Diabetes_R0 == 1) | (medicare.Co_CAD_R0 == 1) | 
                    (medicare.Co_Embolism_R0 == 1) | (medicare.Co_DVT_R0 == 1) | (medicare.Co_PE_R0 == 1) | 
                    (medicare.Co_AFib_R0 == 1) | (medicare.Co_HF_R0 == 1) | (medicare.Co_HemoStroke_R0 == 1) | 
                    (medicare.Co_IscheStroke_R0 == 1) | (medicare.Co_OthStroke_R0 == 1) |(medicare.Co_TIA_R0 == 1)
                    | (medicare.Co_OldMI_R0 == 1) | (medicare.Co_AcuteMI_R0 == 1) | (medicare.Co_PVD_R0 == 1)]
medicare.shape


# In[15]:


train_set = medicare[medicare.Hospital != 'BWH'] # MGH; n = 204014
validation_set = medicare[medicare.Hospital == 'BWH'] # BWH and Neither; n = 115726
import numpy as np

fifty_perc_EHR_cont = np.percentile(medicare['Cal_MPEC_R0'],50)
train_set_high = train_set[train_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
train_set_low= train_set[train_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

validation_set_high = validation_set[validation_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
validation_set_low = validation_set[validation_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]


# In[16]:


medicare.head()


# In[17]:


predictor_variable = [
'Co_CAD_RC0', 'Co_Embolism_RC0', 'Co_DVT_RC0', 'Co_PE_RC0', 'Co_AFib_RC0',
        'Co_Hypertension_RC0', 'Co_Hyperlipidemia_RC0', 'Co_Atherosclerosis_RC0',
        'Co_HF_RC0', 'Co_HemoStroke_RC0', 'Co_IscheStroke_RC0', 'Co_OthStroke_RC0',
        'Co_TIA_RC0', 'Co_COPD_RC0', 'Co_Asthma_RC0', 'Co_Pneumonia_RC0', 'Co_Alcoholabuse_RC0',
        'Co_Drugabuse_RC0', 'Co_Epilepsy_RC0', 'Co_Cancer_RC0', 'Co_MorbidObesity_RC0',
        'Co_Dementia_RC0', 'Co_Depression_RC0', 'Co_Bipolar_RC0', 'Co_Psychosis_RC0',
        'Co_Personalitydisorder_RC0', 'Co_Adjustmentdisorder_RC0', 'Co_Anxiety_RC0',
        'Co_Generalizedanxiety_RC0', 'Co_OldMI_RC0', 'Co_AcuteMI_RC0', 'Co_PUD_RC0',
        'Co_UpperGIbleed_RC0', 'Co_LowerGIbleed_RC0', 'Co_Urogenitalbleed_RC0',
        'Co_Othbleed_RC0', 'Co_PVD_RC0', 'Co_LiverDisease_RC0', 'Co_MRI_RC0',
        'Co_ESRD_RC0', 'Co_Obesity_RC0', 'Co_Sepsis_RC0', 'Co_Osteoarthritis_RC0',
        'Co_RA_RC0', 'Co_NeuroPain_RC0', 'Co_NeckPain_RC0', 'Co_OthArthritis_RC0',
        'Co_Osteoporosis_RC0', 'Co_Fibromyalgia_RC0', 'Co_Migraine_RC0', 'Co_Headache_RC0',
        'Co_OthPain_RC0', 'Co_GeneralizedPain_RC0', 'Co_PainDisorder_RC0',
        'Co_Falls_RC0', 'Co_CoagulationDisorder_RC0', 'Co_WhiteBloodCell_RC0', 'Co_Parkinson_RC0',
        'Co_Anemia_RC0', 'Co_UrinaryIncontinence_RC0', 'Co_DecubitusUlcer_RC0',
        'Co_Oxygen_RC0', 'Co_Mammography_RC0', 'Co_PapTest_RC0', 'Co_PSATest_RC0',
        'Co_Colonoscopy_RC0', 'Co_FecalOccultTest_RC0', 'Co_FluShot_RC0', 'Co_PneumococcalVaccine_RC0' , 'Co_RenalDysfunction_RC0', 'Co_Valvular_RC0', 'Co_Hosp_Prior30Days_RC0',
        'Co_RX_Antibiotic_RC0', 'Co_RX_Corticosteroid_RC0', 'Co_RX_Aspirin_RC0', 'Co_RX_Dipyridamole_RC0',
        'Co_RX_Clopidogrel_RC0', 'Co_RX_Prasugrel_RC0', 'Co_RX_Cilostazol_RC0', 'Co_RX_Ticlopidine_RC0',
        'Co_RX_Ticagrelor_RC0', 'Co_RX_OthAntiplatelet_RC0', 'Co_RX_NSAIDs_RC0',
        'Co_RX_Opioid_RC0', 'Co_RX_Antidepressant_RC0', 'Co_RX_AAntipsychotic_RC0', 'Co_RX_TAntipsychotic_RC0',
        'Co_RX_Anticonvulsant_RC0', 'Co_RX_PPI_RC0', 'Co_RX_H2Receptor_RC0', 'Co_RX_OthGastro_RC0',
        'Co_RX_ACE_RC0', 'Co_RX_ARB_RC0', 'Co_RX_BBlocker_RC0', 'Co_RX_CCB_RC0', 'Co_RX_Thiazide_RC0',
        'Co_RX_Loop_RC0', 'Co_RX_Potassium_RC0', 'Co_RX_Nitrates_RC0', 'Co_RX_Aliskiren_RC0',
        'Co_RX_OthAntihypertensive_RC0', 'Co_RX_Antiarrhythmic_RC0', 'Co_RX_OthAnticoagulant_RC0',
        'Co_RX_Insulin_RC0', 'Co_RX_Noninsulin_RC0', 'Co_RX_Digoxin_RC0', 'Co_RX_Statin_RC0',
        'Co_RX_Lipid_RC0', 'Co_RX_Lithium_RC0', 'Co_RX_Benzo_RC0', 'Co_RX_ZDrugs_RC0',
        'Co_RX_OthAnxiolytic_RC0', 'Co_RX_Dementia_RC0', 'Co_RX_Hormone_RC0',
        'Co_RX_Osteoporosis_RC0', 'Co_N_Drugs_RC0', 'Co_N_Hosp_RC0', 'Co_Total_HospLOS_RC0',
        'Co_N_MDVisit_RC0', 'Co_RX_AnyAspirin_RC0', 'Co_RX_AspirinMono_RC0', 'Co_RX_ClopidogrelMono_RC0',
        'Co_RX_AspirinClopidogrel_RC0', 'Co_RX_DM_RC0', 'Co_RX_Antipsychotic_RC0'
]

co_train_gpop = train_set[predictor_variable]
co_train_high = train_set_high[predictor_variable]
co_train_low = train_set_low[predictor_variable]

co_validation_gpop = validation_set[predictor_variable]
co_validation_high = validation_set_high[predictor_variable]
co_validation_low = validation_set_low[predictor_variable]


# In[18]:


out_train_death_gpop = train_set['Out_Hemorrhage_RC1']
out_train_death_high = train_set_high['Out_Hemorrhage_RC1']
out_train_death_low = train_set_low['Out_Hemorrhage_RC1']

out_validation_death_gpop = validation_set['Out_Hemorrhage_RC1']
out_validation_death_high = validation_set_high['Out_Hemorrhage_RC1']
out_validation_death_low = validation_set_low['Out_Hemorrhage_RC1']


# In[19]:


"""
def a(b):
    count = 0
    tval = 0
    for val in b:
        tval = tval + 1
        if (val == 1):
            count = count + 1
    print(count, tval)
a(out_train_hemorrhage_gpop)
a(out_train_hemorrhage_high)
a(out_train_hemorrhage_low)
a(out_validation_hemorrhage_gpop)
a(out_validation_hemorrhage_high)
a(out_validation_hemorrhage_low)
"""


# # Template LR 

# In[20]:


def lr(X_train, y_train):
    from sklearn.linear_model import Lasso
    from sklearn.decomposition import PCA
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler 

    model = LogisticRegression()
    param_grid = [
        {'C' : np.logspace(-4, 4, 20)}
        ]
    clf = GridSearchCV(model, param_grid, cv = 5, verbose = True, n_jobs = 10)
    best_clf = clf.fit(X_train, y_train)
    return best_clf


# In[21]:


import pandas as pd
import numpy as np
import scipy.stats

# AUC comparison adapted from
# https://github.com/Netflix/vmaf/
def compute_midrank(x):
    """Computes midranks.
    Args:
       x - a 1D numpy array
    Returns:
       array of midranks
    """
    J = np.argsort(x)
    Z = x[J]
    N = len(x)
    T = np.zeros(N, dtype=np.float)
    i = 0
    while i < N:
        j = i
        while j < N and Z[j] == Z[i]:
            j += 1
        T[i:j] = 0.5*(i + j - 1)
        i = j
    T2 = np.empty(N, dtype=np.float)
    # Note(kazeevn) +1 is due to Python using 0-based indexing
    # instead of 1-based in the AUC formula in the paper
    T2[J] = T + 1
    return T2


def fastDeLong(predictions_sorted_transposed, label_1_count):
    """
    The fast version of DeLong's method for computing the covariance of
    unadjusted AUC.
    Args:
       predictions_sorted_transposed: a 2D numpy.array[n_classifiers, n_examples]
          sorted such as the examples with label "1" are first
    Returns:
       (AUC value, DeLong covariance)
    Reference:
     @article{sun2014fast,
       title={Fast Implementation of DeLong's Algorithm for
              Comparing the Areas Under Correlated Receiver Operating Characteristic Curves},
       author={Xu Sun and Weichao Xu},
       journal={IEEE Signal Processing Letters},
       volume={21},
       number={11},
       pages={1389--1393},
       year={2014},
       publisher={IEEE}
     }
    """
    # Short variables are named as they are in the paper
    m = label_1_count
    n = predictions_sorted_transposed.shape[1] - m
    positive_examples = predictions_sorted_transposed[:, :m]
    negative_examples = predictions_sorted_transposed[:, m:]
    k = predictions_sorted_transposed.shape[0]

    tx = np.empty([k, m], dtype=np.float)
    ty = np.empty([k, n], dtype=np.float)
    tz = np.empty([k, m + n], dtype=np.float)
    for r in range(k):
        tx[r, :] = compute_midrank(positive_examples[r, :])
        ty[r, :] = compute_midrank(negative_examples[r, :])
        tz[r, :] = compute_midrank(predictions_sorted_transposed[r, :])
    aucs = tz[:, :m].sum(axis=1) / m / n - float(m + 1.0) / 2.0 / n
    v01 = (tz[:, :m] - tx[:, :]) / n
    v10 = 1.0 - (tz[:, m:] - ty[:, :]) / m
    sx = np.cov(v01)
    sy = np.cov(v10)
    delongcov = sx / m + sy / n
    return aucs, delongcov


def calc_pvalue(aucs, sigma):
    """Computes log(10) of p-values.
    Args:
       aucs: 1D array of AUCs
       sigma: AUC DeLong covariances
    Returns:
       log10(pvalue)
    """
    l = np.array([[1, -1]])
    z = np.abs(np.diff(aucs)) / np.sqrt(np.dot(np.dot(l, sigma), l.T))
    return np.log10(2) + scipy.stats.norm.logsf(z, loc=0, scale=1) / np.log(10)


def compute_ground_truth_statistics(ground_truth):
    assert np.array_equal(np.unique(ground_truth), [0, 1])
    order = (-ground_truth).argsort()
    label_1_count = int(ground_truth.sum())
    return order, label_1_count


def delong_roc_variance(ground_truth, predictions):
    """
    Computes ROC AUC variance for a single set of predictions
    Args:
       ground_truth: np.array of 0 and 1
       predictions: np.array of floats of the probability of being class 1
    """
    order, label_1_count = compute_ground_truth_statistics(ground_truth)
    predictions_sorted_transposed = predictions[np.newaxis, order]
    aucs, delongcov = fastDeLong(predictions_sorted_transposed, label_1_count)
    assert len(aucs) == 1, "There is a bug in the code, please forward this to the developers"
    return aucs[0], delongcov


def delong_roc_test(ground_truth, predictions_one, predictions_two):
    """
    Computes log(p-value) for hypothesis that two ROC AUCs are different
    Args:
       ground_truth: np.array of 0 and 1
       predictions_one: predictions of the first model,
          np.array of floats of the probability of being class 1
       predictions_two: predictions of the second model,
          np.array of floats of the probability of being class 1
    """
    order, label_1_count = compute_ground_truth_statistics(ground_truth)
    predictions_sorted_transposed = np.vstack((predictions_one, predictions_two))[:, order]
    aucs, delongcov = fastDeLong(predictions_sorted_transposed, label_1_count)
    return calc_pvalue(aucs, delongcov)


# In[39]:


def train_scores(X_train,y_train):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_train)
    actual = y_train
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.predict_proba(X_train)[:,1]))
    print(log_loss(actual,best_clf.predict_proba(X_train)[:,1]))
    
def test_scores(X_test,y_test):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_test)
    actual = y_test
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.predict_proba(X_test)[:,1]))
    print(log_loss(actual,best_clf.predict_proba(X_test)[:,1]))
    


# In[37]:


def cross_val(X,y):
    from sklearn.model_selection import KFold
    from sklearn.model_selection import cross_validate
    from sklearn.metrics import log_loss
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import fbeta_score
    import sklearn
    import numpy as np
    cv = KFold(n_splits=5, random_state=1, shuffle=True)
    log_loss = [] 
    auc = [] 
    accuracy = [] 
    f1 = [] 
    f2 = [] 
    for train_index, test_index in cv.split(X):
        X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        model = lr(X_train, y_train)
        prob = model.predict_proba(X_test)[:,1] # prob is a vector of probabilities 
        #print(prob)
        pred = np.round(prob) # pred is the rounded predictions 
        
        log_loss.append(sklearn.metrics.log_loss(y_test, prob))
        auc.append(sklearn.metrics.roc_auc_score(y_test, prob))
        accuracy.append(sklearn.metrics.accuracy_score(y_test, pred))
        f1.append(sklearn.metrics.f1_score(y_test, pred, average = 'macro'))
        f2.append(fbeta_score(y_test,pred, average = 'macro', beta = 2))
    print(np.mean(accuracy))
    print(np.mean(f1))
    print(np.mean(f2))
    print(np.mean(auc))
    print(np.mean(log_loss))


# # General Population

# In[40]:


print("gpop")
best_clf = lr(co_train_gpop, out_train_death_gpop)
cross_val(co_train_gpop, out_train_death_gpop)
print("")
test_scores(co_validation_gpop, out_validation_death_gpop)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb


# # High Continuity 

# In[41]:

print("High")

best_clf = lr(co_train_high, out_train_death_high)
cross_val(co_train_high, out_train_death_high)
print()
print("")
test_scores(co_validation_high, out_validation_death_high)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb


# # Low Continuity

# In[42]:

print("Low")

best_clf = lr(co_train_low, out_train_death_low)
cross_val(co_train_low, out_train_death_low)
print()
print("")
test_scores(co_validation_low, out_validation_death_low)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# gpop
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 0.9198657792455766
# 0.48219917859182154
# 0.4931807323946072
# 0.7166109399789525
# 0.25793210437532554
#
# 0.9071599521340248
# 0.01585623678646934
# 0.4947954459090549
# 0.68802611707904
# 0.29251529678356725
# High
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 0.9296113906472101
# 0.4932805440411097
# 0.49952003564635394
# 0.7208391491953873
# 0.23553946395895992
#
#
# 0.919816245562748
# 0.0327455919395466
# 0.5012787822453043
# 0.7130999798166044
# 0.25729629344052624
# Low
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 0.909167373625302
# 0.4783421589364794
# 0.4913464888598349
# 0.6685456884257261
# 0.29250474292278356
#
#
# 0.8941591906852453
# 0.007162041181736795
# 0.49050193256949304
# 0.6555690801456799
# 0.32581812820565315
# ['Co_CAD_RC0[[0.01595943]]',
#  'Co_Embolism_RC0[[0.00175893]]',
#  'Co_DVT_RC0[[0.00372142]]',
#  'Co_PE_RC0[[0.00216679]]',
#  'Co_AFib_RC0[[0.02246256]]',
#  'Co_Hypertension_RC0[[0.00607081]]',
#  'Co_Hyperlipidemia_RC0[[0.00135291]]',
#  'Co_Atherosclerosis_RC0[[0.01516285]]',
#  'Co_HF_RC0[[0.0334103]]',
#  'Co_HemoStroke_RC0[[-0.00303813]]',
#  'Co_IscheStroke_RC0[[0.00468433]]',
#  'Co_OthStroke_RC0[[0.00449172]]',
#  'Co_TIA_RC0[[-0.00020202]]',
#  'Co_COPD_RC0[[0.01599201]]',
#  'Co_Asthma_RC0[[0.01133005]]',
#  'Co_Pneumonia_RC0[[0.00750253]]',
#  'Co_Alcoholabuse_RC0[[0.00216731]]',
#  'Co_Drugabuse_RC0[[0.00316329]]',
#  'Co_Epilepsy_RC0[[0.00099566]]',
#  'Co_Cancer_RC0[[0.00356363]]',
#  'Co_MorbidObesity_RC0[[0.00297695]]',
#  'Co_Dementia_RC0[[0.00442988]]',
#  'Co_Depression_RC0[[0.00764366]]',
#  'Co_Bipolar_RC0[[0.0011279]]',
#  'Co_Psychosis_RC0[[-0.0003781]]',
#  'Co_Personalitydisorder_RC0[[0.0004768]]',
#  'Co_Adjustmentdisorder_RC0[[0.00064077]]',
#  'Co_Anxiety_RC0[[0.00654709]]',
#  'Co_Generalizedanxiety_RC0[[0.00247692]]',
#  'Co_OldMI_RC0[[0.00259313]]',
#  'Co_AcuteMI_RC0[[0.00791413]]',
#  'Co_PUD_RC0[[0.01435813]]',
#  'Co_UpperGIbleed_RC0[[0.00715948]]',
#  'Co_LowerGIbleed_RC0[[0.02426271]]',
#  'Co_Urogenitalbleed_RC0[[0.00677169]]',
#  'Co_Othbleed_RC0[[0.020617]]',
#  'Co_PVD_RC0[[0.01832271]]',
#  'Co_LiverDisease_RC0[[0.0059261]]',
#  'Co_MRI_RC0[[0.01742018]]',
#  'Co_ESRD_RC0[[0.00529142]]',
#  'Co_Obesity_RC0[[0.00783974]]',
#  'Co_Sepsis_RC0[[0.00232097]]',
#  'Co_Osteoarthritis_RC0[[0.00949806]]',
#  'Co_RA_RC0[[0.0010754]]',
#  'Co_NeuroPain_RC0[[0.00799756]]',
#  'Co_NeckPain_RC0[[0.01231223]]',
#  'Co_OthArthritis_RC0[[0.01497473]]',
#  'Co_Osteoporosis_RC0[[0.00646523]]',
#  'Co_Fibromyalgia_RC0[[-0.00270288]]',
#  'Co_Migraine_RC0[[-0.00034932]]',
#  'Co_Headache_RC0[[0.00132532]]',
#  'Co_OthPain_RC0[[0.01532054]]',
#  'Co_GeneralizedPain_RC0[[0.0069846]]',
#  'Co_PainDisorder_RC0[[-0.0001279]]',
#  'Co_Falls_RC0[[0.0137438]]',
#  'Co_CoagulationDisorder_RC0[[0.00758874]]',
#  'Co_WhiteBloodCell_RC0[[0.00778246]]',
#  'Co_Parkinson_RC0[[0.00209189]]',
#  'Co_Anemia_RC0[[0.04734344]]',
#  'Co_UrinaryIncontinence_RC0[[0.00536579]]',
#  'Co_DecubitusUlcer_RC0[[0.00183231]]',
#  'Co_Oxygen_RC0[[0.00786507]]',
#  'Co_Mammography_RC0[[-0.00707569]]',
#  'Co_PapTest_RC0[[-0.00524047]]',
#  'Co_PSATest_RC0[[-0.00889902]]',
#  'Co_Colonoscopy_RC0[[0.00247472]]',
#  'Co_FecalOccultTest_RC0[[-0.00247383]]',
#  'Co_FluShot_RC0[[0.00823357]]',
#  'Co_PneumococcalVaccine_RC0[[0.02394167]]',
#  'Co_RenalDysfunction_RC0[[0.03256538]]',
#  'Co_Valvular_RC0[[0.01259907]]',
#  'Co_Hosp_Prior30Days_RC0[[0.03234344]]',
#  'Co_RX_Antibiotic_RC0[[0.00456458]]',
#  'Co_RX_Corticosteroid_RC0[[0.01325881]]',
#  'Co_RX_Aspirin_RC0[[0.00030226]]',
#  'Co_RX_Dipyridamole_RC0[[0.00037265]]',
#  'Co_RX_Clopidogrel_RC0[[0.00675987]]',
#  'Co_RX_Prasugrel_RC0[[0.00017435]]',
#  'Co_RX_Cilostazol_RC0[[0.00011119]]',
#  'Co_RX_Ticlopidine_RC0[[-0.00023017]]',
#  'Co_RX_Ticagrelor_RC0[[0.00049859]]',
#  'Co_RX_OthAntiplatelet_RC0[[-0.00011898]]',
#  'Co_RX_NSAIDs_RC0[[-0.00695043]]',
#  'Co_RX_Opioid_RC0[[0.00613084]]',
#  'Co_RX_Antidepressant_RC0[[0.01285665]]',
#  'Co_RX_AAntipsychotic_RC0[[0.00053055]]',
#  'Co_RX_TAntipsychotic_RC0[[0.00118609]]',
#  'Co_RX_Anticonvulsant_RC0[[0.00365176]]',
#  'Co_RX_PPI_RC0[[0.00936206]]',
#  'Co_RX_H2Receptor_RC0[[-0.00209082]]',
#  'Co_RX_OthGastro_RC0[[-0.00129362]]',
#  'Co_RX_ACE_RC0[[-0.00967612]]',
#  'Co_RX_ARB_RC0[[-0.00414852]]',
#  'Co_RX_BBlocker_RC0[[0.00321888]]',
#  'Co_RX_CCB_RC0[[0.00823071]]',
#  'Co_RX_Thiazide_RC0[[-0.00740847]]',
#  'Co_RX_Loop_RC0[[0.02759659]]',
#  'Co_RX_Potassium_RC0[[0.00770473]]',
#  'Co_RX_Nitrates_RC0[[0.00812572]]',
#  'Co_RX_Aliskiren_RC0[[-0.00039539]]',
#  'Co_RX_OthAntihypertensive_RC0[[-0.00118315]]',
#  'Co_RX_Antiarrhythmic_RC0[[-0.00387429]]',
#  'Co_RX_OthAnticoagulant_RC0[[-0.00173623]]',
#  'Co_RX_Insulin_RC0[[0.00757254]]',
#  'Co_RX_Noninsulin_RC0[[-0.00173764]]',
#  'Co_RX_Digoxin_RC0[[0.00030973]]',
#  'Co_RX_Statin_RC0[[0.00037812]]',
#  'Co_RX_Lipid_RC0[[-0.00537283]]',
#  'Co_RX_Lithium_RC0[[0.00011783]]',
#  'Co_RX_Benzo_RC0[[-0.00401228]]',
#  'Co_RX_ZDrugs_RC0[[-0.00488274]]',
#  'Co_RX_OthAnxiolytic_RC0[[-0.00138446]]',
#  'Co_RX_Dementia_RC0[[-0.00276523]]',
#  'Co_RX_Hormone_RC0[[-0.00194162]]',
#  'Co_RX_Osteoporosis_RC0[[-0.0014933]]',
#  'Co_N_Drugs_RC0[[0.00046996]]',
#  'Co_N_Hosp_RC0[[0.06264297]]',
#  'Co_Total_HospLOS_RC0[[0.00963294]]',
#  'Co_N_MDVisit_RC0[[0.01399558]]',
#  'Co_RX_AnyAspirin_RC0[[0.0002854]]',
#  'Co_RX_AspirinMono_RC0[[-0.00358638]]',
#  'Co_RX_ClopidogrelMono_RC0[[0.00355536]]',
#  'Co_RX_AspirinClopidogrel_RC0[[0.00329082]]',
#  'Co_RX_DM_RC0[[0.00295794]]',
#  'Co_RX_Antipsychotic_RC0[[0.00257483]]']

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import pandas as pd
#medicare = pd.read_csv("/netapp2/home/se197/RPDR/Josh Lin/3_EHR_V2/CMS/Data/final_medicare.csv")
medicare = pd.read_csv("/netapp2/home/se197/data/CMS/Data/medicare.csv")

# In[2]:


train_set = medicare[medicare.Hospital != 'BWH'] # MGH
validation_set = medicare[medicare.Hospital == 'BWH'] # BWH and Neither 
import numpy as np

fifty_perc_EHR_cont = np.percentile(medicare['Cal_MPEC_R0'],50)
train_set_high = train_set[train_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
train_set_low= train_set[train_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

validation_set_high = validation_set[validation_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
validation_set_low = validation_set[validation_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]


# In[3]:


predictor_variable = [
'Co_CAD_RC0', 'Co_Embolism_RC0', 'Co_DVT_RC0', 'Co_PE_RC0', 'Co_AFib_RC0',
        'Co_Hypertension_RC0', 'Co_Hyperlipidemia_RC0', 'Co_Atherosclerosis_RC0',
        'Co_HF_RC0', 'Co_HemoStroke_RC0', 'Co_IscheStroke_RC0', 'Co_OthStroke_RC0',
        'Co_TIA_RC0', 'Co_COPD_RC0', 'Co_Asthma_RC0', 'Co_Pneumonia_RC0', 'Co_Alcoholabuse_RC0',
        'Co_Drugabuse_RC0', 'Co_Epilepsy_RC0', 'Co_Cancer_RC0', 'Co_MorbidObesity_RC0',
        'Co_Dementia_RC0', 'Co_Depression_RC0', 'Co_Bipolar_RC0', 'Co_Psychosis_RC0',
        'Co_Personalitydisorder_RC0', 'Co_Adjustmentdisorder_RC0', 'Co_Anxiety_RC0',
        'Co_Generalizedanxiety_RC0', 'Co_OldMI_RC0', 'Co_AcuteMI_RC0', 'Co_PUD_RC0',
        'Co_UpperGIbleed_RC0', 'Co_LowerGIbleed_RC0', 'Co_Urogenitalbleed_RC0',
        'Co_Othbleed_RC0', 'Co_PVD_RC0', 'Co_LiverDisease_RC0', 'Co_MRI_RC0',
        'Co_ESRD_RC0', 'Co_Obesity_RC0', 'Co_Sepsis_RC0', 'Co_Osteoarthritis_RC0',
        'Co_RA_RC0', 'Co_NeuroPain_RC0', 'Co_NeckPain_RC0', 'Co_OthArthritis_RC0',
        'Co_Osteoporosis_RC0', 'Co_Fibromyalgia_RC0', 'Co_Migraine_RC0', 'Co_Headache_RC0',
        'Co_OthPain_RC0', 'Co_GeneralizedPain_RC0', 'Co_PainDisorder_RC0',
        'Co_Falls_RC0', 'Co_CoagulationDisorder_RC0', 'Co_WhiteBloodCell_RC0', 'Co_Parkinson_RC0',
        'Co_Anemia_RC0', 'Co_UrinaryIncontinence_RC0', 'Co_DecubitusUlcer_RC0',
        'Co_Oxygen_RC0', 'Co_Mammography_RC0', 'Co_PapTest_RC0', 'Co_PSATest_RC0',
        'Co_Colonoscopy_RC0', 'Co_FecalOccultTest_RC0', 'Co_FluShot_RC0', 'Co_PneumococcalVaccine_RC0' , 'Co_RenalDysfunction_RC0', 'Co_Valvular_RC0', 'Co_Hosp_Prior30Days_RC0',
        'Co_RX_Antibiotic_RC0', 'Co_RX_Corticosteroid_RC0', 'Co_RX_Aspirin_RC0', 'Co_RX_Dipyridamole_RC0',
        'Co_RX_Clopidogrel_RC0', 'Co_RX_Prasugrel_RC0', 'Co_RX_Cilostazol_RC0', 'Co_RX_Ticlopidine_RC0',
        'Co_RX_Ticagrelor_RC0', 'Co_RX_OthAntiplatelet_RC0', 'Co_RX_NSAIDs_RC0',
        'Co_RX_Opioid_RC0', 'Co_RX_Antidepressant_RC0', 'Co_RX_AAntipsychotic_RC0', 'Co_RX_TAntipsychotic_RC0',
        'Co_RX_Anticonvulsant_RC0', 'Co_RX_PPI_RC0', 'Co_RX_H2Receptor_RC0', 'Co_RX_OthGastro_RC0',
        'Co_RX_ACE_RC0', 'Co_RX_ARB_RC0', 'Co_RX_BBlocker_RC0', 'Co_RX_CCB_RC0', 'Co_RX_Thiazide_RC0',
        'Co_RX_Loop_RC0', 'Co_RX_Potassium_RC0', 'Co_RX_Nitrates_RC0', 'Co_RX_Aliskiren_RC0',
        'Co_RX_OthAntihypertensive_RC0', 'Co_RX_Antiarrhythmic_RC0', 'Co_RX_OthAnticoagulant_RC0',
        'Co_RX_Insulin_RC0', 'Co_RX_Noninsulin_RC0', 'Co_RX_Digoxin_RC0', 'Co_RX_Statin_RC0',
        'Co_RX_Lipid_RC0', 'Co_RX_Lithium_RC0', 'Co_RX_Benzo_RC0', 'Co_RX_ZDrugs_RC0',
        'Co_RX_OthAnxiolytic_RC0', 'Co_RX_Dementia_RC0', 'Co_RX_Hormone_RC0',
        'Co_RX_Osteoporosis_RC0', 'Co_N_Drugs_RC0', 'Co_N_Hosp_RC0', 'Co_Total_HospLOS_RC0',
        'Co_N_MDVisit_RC0', 'Co_RX_AnyAspirin_RC0', 'Co_RX_AspirinMono_RC0', 'Co_RX_ClopidogrelMono_RC0',
        'Co_RX_AspirinClopidogrel_RC0', 'Co_RX_DM_RC0', 'Co_RX_Antipsychotic_RC0'
]

co_train_gpop = train_set[predictor_variable]
co_train_high = train_set_high[predictor_variable]
co_train_low = train_set_low[predictor_variable]

co_validation_gpop = validation_set[predictor_variable]
co_validation_high = validation_set_high[predictor_variable]
co_validation_low = validation_set_low[predictor_variable]


# In[4]:


out_train_cardio_gpop = train_set['Out_comp_cardiovascular_nd_RC1']
out_train_cardio_high = train_set_high['Out_comp_cardiovascular_nd_RC1']
out_train_cardio_low = train_set_low['Out_comp_cardiovascular_nd_RC1']

out_validation_cardio_gpop = validation_set['Out_comp_cardiovascular_nd_RC1']
out_validation_cardio_high = validation_set_high['Out_comp_cardiovascular_nd_RC1']
out_validation_cardio_low = validation_set_low['Out_comp_cardiovascular_nd_RC1']


# In[5]:


def lr(X_train, y_train):
    from sklearn.linear_model import Lasso
    from sklearn.decomposition import PCA
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler 

    model = LogisticRegression()
    param_grid = [
        {'C' : np.logspace(-4, 4, 20)}
        ]
    clf = GridSearchCV(model, param_grid, cv = 5, verbose = True, n_jobs = -1)
    best_clf = clf.fit(X_train, y_train)
    return best_clf


# In[6]:


def scores(X_train,y_train):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_train)
    actual = y_train
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.predict_proba(X_train)[:,1]))
    print(log_loss(actual,best_clf.predict_proba(X_train)[:,1]))
    
    


# In[7]:


def cross_val(X,y):
    from sklearn.model_selection import KFold
    from sklearn.model_selection import cross_validate
    from sklearn.metrics import log_loss
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import fbeta_score
    import sklearn
    import numpy as np
    cv = KFold(n_splits=5, random_state=1, shuffle=True)
    log_loss = [] 
    auc = [] 
    accuracy = [] 
    f1 = [] 
    f2 = [] 
    for train_index, test_index in cv.split(X):
        X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        model = lr(X_train, y_train)
        prob = model.predict_proba(X_test)[:,1] # prob is a vector of probabilities 
        print(prob)
        pred = np.round(prob) # pred is the rounded predictions 
        
        log_loss.append(sklearn.metrics.log_loss(y_test, prob))
        auc.append(sklearn.metrics.roc_auc_score(y_test, prob))
        accuracy.append(sklearn.metrics.accuracy_score(y_test, pred))
        f1.append(sklearn.metrics.f1_score(y_test, pred, average = 'macro'))
        f2.append(fbeta_score(y_test,pred, average = 'macro', beta = 2))
    print(np.mean(accuracy))
    print(np.mean(f1))
    print(np.mean(f2))
    print(np.mean(auc))
    print(np.mean(log_loss))


# In[8]:


print("Gpop")
best_clf = lr(co_train_gpop, out_train_cardio_gpop)
cross_val(co_train_gpop, out_train_cardio_gpop)
print()
print("")
scores(co_validation_gpop, out_validation_cardio_gpop)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb


# In[14]:


print("Low")
best_clf = lr(co_train_low, out_train_cardio_low)
cross_val(co_train_low, out_train_cardio_low)
print("")
scores(co_validation_low, out_validation_cardio_low)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb


# In[15]:


print("High")
best_clf = lr(co_train_high, out_train_cardio_high)
cross_val(co_train_high, out_train_cardio_high)
print()
print("")
scores(co_validation_high, out_validation_cardio_high)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Gpop
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0.02984775 0.00817397 0.01941577 ... 0.02245512 0.05886388 0.04428573]
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0.05079487 0.0231489  0.01044024 ... 0.0451368  0.01797975 0.01354689]
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0.01531839 0.10512474 0.03259263 ... 0.0412826  0.07970276 0.02198591]
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0.0251974  0.01169921 0.06414759 ... 0.12622688 0.03286992 0.07396396]
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0.04135877 0.0242435  0.01801797 ... 0.03020374 0.02382572 0.03295174]
# 0.9595605705345186
# 0.4904808991025308
# 0.4963140184969895
# 0.6772379012770545
# 0.161355218983036
#
#
# 0.9589150378938971
# 0.0
# 0.49572120837199707
# 0.6762868850198617
# 0.16368235547309895
# Low
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0.03921819 0.01470503 0.0282611  ... 0.02697028 0.05325217 0.03378853]
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0.05833232 0.02846711 0.03646082 ... 0.07857199 0.04995885 0.03911219]
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0.04139564 0.08325957 0.03225174 ... 0.08143863 0.04881407 0.04589214]
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [0.04205404 0.06071385 0.05490762 ... 0.03799862 0.04277965 0.04598757]
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0.04927931 0.01013577 0.042549   ... 0.02273158 0.02757316 0.02485167]
# 0.9503138938193469
# 0.48726172816057833
# 0.49482551970341404
# 0.6662234900140447
# 0.1900701138829342
#
# 0.9500858942546287
# 0.0
# 0.49477147571618857
# 0.6425413582213848
# 0.19230725742132398
# High
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [0.02540733 0.02995008 0.02874385 ... 0.02801042 0.04546081 0.02437964]
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [0.02333646 0.02341687 0.02593967 ... 0.02900902 0.02259332 0.02302456]
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [0.02282695 0.02916987 0.02456776 ... 0.04166688 0.02660193 0.03072817]
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [0.02371751 0.0884523  0.05666815 ... 0.02823491 0.02712398 0.08062515]
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0.0224036  0.02216372 0.01382979 ... 0.09247987 0.01953922 0.02209069]
# 0.9680863395228295
# 0.4918921492934782
# 0.4967249805195159
# 0.6173859393996094
# 0.13839133596313052
#
#
# 0.9686782209229484
# 0.006622516556291392
# 0.4988349217205959
# 0.5856355536394338
# 0.13926203570091972
# ['Co_CAD_RC0[[0.00462267]]',
#  'Co_Embolism_RC0[[0.0002786]]',
#  'Co_DVT_RC0[[-0.00149713]]',
#  'Co_PE_RC0[[-0.0004464]]',
#  'Co_AFib_RC0[[0.00251072]]',
#  'Co_Hypertension_RC0[[0.00147458]]',
#  'Co_Hyperlipidemia_RC0[[-0.00026649]]',
#  'Co_Atherosclerosis_RC0[[0.0043618]]',
#  'Co_HF_RC0[[0.00595655]]',
#  'Co_HemoStroke_RC0[[0.00061629]]',
#  'Co_IscheStroke_RC0[[0.00600151]]',
#  'Co_OthStroke_RC0[[0.00087856]]',
#  'Co_TIA_RC0[[0.00304029]]',
#  'Co_COPD_RC0[[0.00296236]]',
#  'Co_Asthma_RC0[[0.00181215]]',
#  'Co_Pneumonia_RC0[[0.00096648]]',
#  'Co_Alcoholabuse_RC0[[0.00058351]]',
#  'Co_Drugabuse_RC0[[0.00037764]]',
#  'Co_Epilepsy_RC0[[0.00043488]]',
#  'Co_Cancer_RC0[[0.00038176]]',
#  'Co_MorbidObesity_RC0[[-0.00018071]]',
#  'Co_Dementia_RC0[[0.00255792]]',
#  'Co_Depression_RC0[[0.00028079]]',
#  'Co_Bipolar_RC0[[-0.00039111]]',
#  'Co_Psychosis_RC0[[0.00067684]]',
#  'Co_Personalitydisorder_RC0[[-0.00029398]]',
#  'Co_Adjustmentdisorder_RC0[[-0.00052328]]',
#  'Co_Anxiety_RC0[[0.0009759]]',
#  'Co_Generalizedanxiety_RC0[[0.00030832]]',
#  'Co_OldMI_RC0[[0.00530197]]',
#  'Co_AcuteMI_RC0[[0.00398163]]',
#  'Co_PUD_RC0[[0.00067364]]',
#  'Co_UpperGIbleed_RC0[[0.0003912]]',
#  'Co_LowerGIbleed_RC0[[0.00246423]]',
#  'Co_Urogenitalbleed_RC0[[8.94229555e-05]]',
#  'Co_Othbleed_RC0[[-0.0002076]]',
#  'Co_PVD_RC0[[0.005817]]',
#  'Co_LiverDisease_RC0[[0.00065611]]',
#  'Co_MRI_RC0[[0.00205815]]',
#  'Co_ESRD_RC0[[0.0012897]]',
#  'Co_Obesity_RC0[[-0.00097451]]',
#  'Co_Sepsis_RC0[[0.00044535]]',
#  'Co_Osteoarthritis_RC0[[-0.00032494]]',
#  'Co_RA_RC0[[0.00036148]]',
#  'Co_NeuroPain_RC0[[0.00189127]]',
#  'Co_NeckPain_RC0[[0.00214587]]',
#  'Co_OthArthritis_RC0[[0.00310016]]',
#  'Co_Osteoporosis_RC0[[0.00063887]]',
#  'Co_Fibromyalgia_RC0[[-0.00106718]]',
#  'Co_Migraine_RC0[[0.00043531]]',
#  'Co_Headache_RC0[[0.00161503]]',
#  'Co_OthPain_RC0[[0.00035753]]',
#  'Co_GeneralizedPain_RC0[[-9.02978932e-05]]',
#  'Co_PainDisorder_RC0[[-4.87825077e-06]]',
#  'Co_Falls_RC0[[0.00247884]]',
#  'Co_CoagulationDisorder_RC0[[0.00102444]]',
#  'Co_WhiteBloodCell_RC0[[0.00149313]]',
#  'Co_Parkinson_RC0[[0.00084835]]',
#  'Co_Anemia_RC0[[0.00378549]]',
#  'Co_UrinaryIncontinence_RC0[[0.00145253]]',
#  'Co_DecubitusUlcer_RC0[[0.00036352]]',
#  'Co_Oxygen_RC0[[-0.00024275]]',
#  'Co_Mammography_RC0[[-0.00455609]]',
#  'Co_PapTest_RC0[[-0.00157984]]',
#  'Co_PSATest_RC0[[-0.00249429]]',
#  'Co_Colonoscopy_RC0[[-0.00015455]]',
#  'Co_FecalOccultTest_RC0[[-0.00058762]]',
#  'Co_FluShot_RC0[[-0.00188512]]',
#  'Co_PneumococcalVaccine_RC0[[-0.00035308]]',
#  'Co_RenalDysfunction_RC0[[0.00565719]]',
#  'Co_Valvular_RC0[[0.00167841]]',
#  'Co_Hosp_Prior30Days_RC0[[0.00291196]]',
#  'Co_RX_Antibiotic_RC0[[-0.000489]]',
#  'Co_RX_Corticosteroid_RC0[[-0.00024811]]',
#  'Co_RX_Aspirin_RC0[[0.00225427]]',
#  'Co_RX_Dipyridamole_RC0[[0.00050611]]',
#  'Co_RX_Clopidogrel_RC0[[0.00565905]]',
#  'Co_RX_Prasugrel_RC0[[-1.5201642e-05]]',
#  'Co_RX_Cilostazol_RC0[[0.00011746]]',
#  'Co_RX_Ticlopidine_RC0[[-1.95467857e-05]]',
#  'Co_RX_Ticagrelor_RC0[[0.00022131]]',
#  'Co_RX_OthAntiplatelet_RC0[[9.79100431e-05]]',
#  'Co_RX_NSAIDs_RC0[[-0.00352273]]',
#  'Co_RX_Opioid_RC0[[-0.00252377]]',
#  'Co_RX_Antidepressant_RC0[[-0.00022524]]',
#  'Co_RX_AAntipsychotic_RC0[[-0.00054065]]',
#  'Co_RX_TAntipsychotic_RC0[[-0.00037419]]',
#  'Co_RX_Anticonvulsant_RC0[[0.00078355]]',
#  'Co_RX_PPI_RC0[[0.00188191]]',
#  'Co_RX_H2Receptor_RC0[[0.00063993]]',
#  'Co_RX_OthGastro_RC0[[-0.00021852]]',
#  'Co_RX_ACE_RC0[[0.00155677]]',
#  'Co_RX_ARB_RC0[[-0.00018981]]',
#  'Co_RX_BBlocker_RC0[[0.0028089]]',
#  'Co_RX_CCB_RC0[[0.00151166]]',
#  'Co_RX_Thiazide_RC0[[-0.00114365]]',
#  'Co_RX_Loop_RC0[[0.00371041]]',
#  'Co_RX_Potassium_RC0[[8.22615386e-05]]',
#  'Co_RX_Nitrates_RC0[[0.00583122]]',
#  'Co_RX_Aliskiren_RC0[[0.00015241]]',
#  'Co_RX_OthAntihypertensive_RC0[[0.00106354]]',
#  'Co_RX_Antiarrhythmic_RC0[[-0.00092986]]',
#  'Co_RX_OthAnticoagulant_RC0[[-0.00017383]]',
#  'Co_RX_Insulin_RC0[[0.00217872]]',
#  'Co_RX_Noninsulin_RC0[[-0.00022506]]',
#  'Co_RX_Digoxin_RC0[[-0.00038594]]',
#  'Co_RX_Statin_RC0[[0.00073854]]',
#  'Co_RX_Lipid_RC0[[0.0015044]]',
#  'Co_RX_Lithium_RC0[[7.64479509e-06]]',
#  'Co_RX_Benzo_RC0[[-0.00177196]]',
#  'Co_RX_ZDrugs_RC0[[5.69363012e-05]]',
#  'Co_RX_OthAnxiolytic_RC0[[-0.00020828]]',
#  'Co_RX_Dementia_RC0[[0.0011343]]',
#  'Co_RX_Hormone_RC0[[-0.00029056]]',
#  'Co_RX_Osteoporosis_RC0[[-0.00062222]]',
#  'Co_N_Drugs_RC0[[0.00915944]]',
#  'Co_N_Hosp_RC0[[0.01176321]]',
#  'Co_Total_HospLOS_RC0[[-0.00021858]]',
#  'Co_N_MDVisit_RC0[[-0.0047918]]',
#  'Co_RX_AnyAspirin_RC0[[0.00222695]]',
#  'Co_RX_AspirinMono_RC0[[-0.00239731]]',
#  'Co_RX_ClopidogrelMono_RC0[[0.00467662]]',
#  'Co_RX_AspirinClopidogrel_RC0[[0.00429562]]',
#  'Co_RX_DM_RC0[[0.00039265]]',
#  'Co_RX_Antipsychotic_RC0[[-0.00095848]]']
