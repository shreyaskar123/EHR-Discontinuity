# %%
import pandas as pd
medicare = pd.read_csv("/netapp2/home/se197/RPDR/Josh Lin/3_EHR_V2/CMS/Data/final_medicare.csv")
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 125

# %%
medicare = medicare[(medicare.Co_CAD_R0 == 1) | (medicare.Co_Diabetes_R0 == 1) | (medicare.Co_CAD_R0 == 1) | 
                    (medicare.Co_Embolism_R0 == 1) | (medicare.Co_DVT_R0 == 1) | (medicare.Co_PE_R0 == 1) | 
                    (medicare.Co_AFib_R0 == 1) | (medicare.Co_HF_R0 == 1) | (medicare.Co_HemoStroke_R0 == 1) | 
                    (medicare.Co_IscheStroke_R0 == 1) | (medicare.Co_OthStroke_R0 == 1) |(medicare.Co_TIA_R0 == 1)
                    | (medicare.Co_OldMI_R0 == 1) | (medicare.Co_AcuteMI_R0 == 1) | (medicare.Co_PVD_R0 == 1)]
medicare.shape
# Out:
# (52277, 276)

# %%
train_set = medicare[medicare.Hospital != 'BWH'] # MGH; n = 204014
validation_set = medicare[medicare.Hospital == 'BWH'] # BWH and Neither; n = 115726
import numpy as np

fifty_perc_EHR_cont = np.percentile(medicare['Cal_MPEC_R0'],50)
train_set_high = train_set[train_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
train_set_low= train_set[train_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

validation_set_high = validation_set[validation_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
validation_set_low = validation_set[validation_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

# %%
predictor_variable = [
        'Co_CAD_R0', 'Co_Embolism_R0', 'Co_DVT_R0', 'Co_PE_R0', 'Co_AFib_R0',
        'Co_Hypertension_R0', 'Co_Hyperlipidemia_R0', 'Co_Atherosclerosis_R0',
        'Co_HF_R0', 'Co_HemoStroke_R0', 'Co_IscheStroke_R0', 'Co_OthStroke_R0',
        'Co_TIA_R0', 'Co_COPD_R0', 'Co_Asthma_R0', 'Co_Pneumonia_R0', 'Co_Alcoholabuse_R0',
        'Co_Drugabuse_R0', 'Co_Epilepsy_R0', 'Co_Cancer_R0', 'Co_MorbidObesity_R0',
        'Co_Dementia_R0', 'Co_Depression_R0', 'Co_Bipolar_R0', 'Co_Psychosis_R0',
        'Co_Personalitydisorder_R0', 'Co_Adjustmentdisorder_R0', 'Co_Anxiety_R0',
        'Co_Generalizedanxiety_R0', 'Co_OldMI_R0', 'Co_AcuteMI_R0', 'Co_PUD_R0',
        'Co_UpperGIbleed_R0', 'Co_LowerGIbleed_R0', 'Co_Urogenitalbleed_R0',
        'Co_Othbleed_R0', 'Co_PVD_R0', 'Co_LiverDisease_R0', 'Co_MRI_R0',
        'Co_ESRD_R0', 'Co_Obesity_R0', 'Co_Sepsis_R0', 'Co_Osteoarthritis_R0',
        'Co_RA_R0', 'Co_NeuroPain_R0', 'Co_NeckPain_R0', 'Co_OthArthritis_R0',
        'Co_Osteoporosis_R0', 'Co_Fibromyalgia_R0', 'Co_Migraine_R0', 'Co_Headache_R0',
        'Co_OthPain_R0', 'Co_GeneralizedPain_R0', 'Co_PainDisorder_R0',
        'Co_Falls_R0', 'Co_CoagulationDisorder_R0', 'Co_WhiteBloodCell_R0', 'Co_Parkinson_R0',
        'Co_Anemia_R0', 'Co_UrinaryIncontinence_R0', 'Co_DecubitusUlcer_R0',
        'Co_Oxygen_R0', 'Co_Mammography_R0', 'Co_PapTest_R0', 'Co_PSATest_R0',
        'Co_Colonoscopy_R0', 'Co_FecalOccultTest_R0', 'Co_FluShot_R0', 'Co_PneumococcalVaccine_R0', 'Co_RenalDysfunction_R0', 'Co_Valvular_R0', 'Co_Hosp_Prior30Days_R0',
        'Co_RX_Antibiotic_R0', 'Co_RX_Corticosteroid_R0', 'Co_RX_Aspirin_R0', 'Co_RX_Dipyridamole_R0',
        'Co_RX_Clopidogrel_R0', 'Co_RX_Prasugrel_R0', 'Co_RX_Cilostazol_R0', 'Co_RX_Ticlopidine_R0',
        'Co_RX_Ticagrelor_R0', 'Co_RX_OthAntiplatelet_R0', 'Co_RX_NSAIDs_R0',
        'Co_RX_Opioid_R0', 'Co_RX_Antidepressant_R0', 'Co_RX_AAntipsychotic_R0', 'Co_RX_TAntipsychotic_R0',
        'Co_RX_Anticonvulsant_R0', 'Co_RX_PPI_R0', 'Co_RX_H2Receptor_R0', 'Co_RX_OthGastro_R0',
        'Co_RX_ACE_R0', 'Co_RX_ARB_R0', 'Co_RX_BBlocker_R0', 'Co_RX_CCB_R0', 'Co_RX_Thiazide_R0',
        'Co_RX_Loop_R0', 'Co_RX_Potassium_R0', 'Co_RX_Nitrates_R0', 'Co_RX_Aliskiren_R0',
        'Co_RX_OthAntihypertensive_R0', 'Co_RX_Antiarrhythmic_R0', 'Co_RX_OthAnticoagulant_R0',
        'Co_RX_Insulin_R0', 'Co_RX_Noninsulin_R0', 'Co_RX_Digoxin_R0', 'Co_RX_Statin_R0',
        'Co_RX_Lipid_R0', 'Co_RX_Lithium_R0', 'Co_RX_Benzo_R0', 'Co_RX_ZDrugs_R0',
        'Co_RX_OthAnxiolytic_R0', 'Co_RX_Dementia_R0', 'Co_RX_Hormone_R0',
        'Co_RX_Osteoporosis_R0', 'Co_N_Drugs_R0', 'Co_N_Hosp_R0', 'Co_Total_HospLOS_R0',
        'Co_N_MDVisit_R0', 'Co_RX_AnyAspirin_R0', 'Co_RX_AspirinMono_R0', 'Co_RX_ClopidogrelMono_R0',
        'Co_RX_AspirinClopidogrel_R0', 'Co_RX_DM_R0', 'Co_RX_Antipsychotic_R0'
]

co_train_gpop = train_set[predictor_variable]
co_train_high = train_set_high[predictor_variable]
co_train_low = train_set_low[predictor_variable]

co_validation_gpop = validation_set[predictor_variable]
co_validation_high = validation_set_high[predictor_variable]
co_validation_low = validation_set_low[predictor_variable]

# %%
out_train_hemorrhage_gpop = train_set['Out_Hemorrhage_R1']
out_train_hemorrhage_high = train_set_high['Out_Hemorrhage_R1']
out_train_hemorrhage_low = train_set_low['Out_Hemorrhage_R1']

out_validation_hemorrhage_gpop = validation_set['Out_Hemorrhage_R1']
out_validation_hemorrhage_high = validation_set_high['Out_Hemorrhage_R1']
out_validation_hemorrhage_low = validation_set_low['Out_Hemorrhage_R1']

# %% [markdown]
# # Template LR

# %%
def lr(X_train, y_train):
    from sklearn.linear_model import Lasso
    from sklearn.decomposition import PCA
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler 

    model = LogisticRegression()
    param_grid = [
        {'C' : np.logspace(-4, 4, 20)}
        ]
    clf = GridSearchCV(model, param_grid, cv = 5, verbose = True, n_jobs = -1)
    best_clf = clf.fit(X_train, y_train)
    return best_clf

# %%
def scores(X_train,y_train):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_train)
    actual = y_train
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.decision_function(X_train)))
    print(log_loss(actual,pred))

# %% [markdown]
# # General Population

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_gpop_sm,out_train_hemorrhage_gpop_sm = sm.fit_resample(co_train_gpop,out_train_hemorrhage_gpop)

best_clf = lr(co_train_gpop_sm, out_train_hemorrhage_gpop_sm)

scores(co_train_gpop_sm, out_train_hemorrhage_gpop_sm)

print()

scores(co_train_gpop, out_train_hemorrhage_gpop)

print()

scores(co_validation_gpop, out_validation_hemorrhage_gpop)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6673557692307692
# 0.6466713193865219
# 0.6663503052478017
# 0.7386961235412558
# 11.489234291448462
#
# 0.7217342726793086
# 0.11925343811394892
# 0.497513458288254
# 0.7196202660790076
# 9.611169961018968
#
# 0.6932090147586757
# 0.11886008878705427
# 0.4825572900887237
# 0.6683867645519719
# 10.59641691356962
# ['Co_CAD_R0[[0.62905905]]',
#  'Co_Embolism_R0[[0.20526356]]',
#  'Co_DVT_R0[[0.10761253]]',
#  'Co_PE_R0[[0.07328852]]',
#  'Co_AFib_R0[[0.26040031]]',
#  'Co_Hypertension_R0[[-0.42397285]]',
#  'Co_Hyperlipidemia_R0[[-0.27396418]]',
#  'Co_Atherosclerosis_R0[[-0.02143867]]',
#  'Co_HF_R0[[0.14985013]]',
#  'Co_HemoStroke_R0[[-0.27762115]]',
#  'Co_IscheStroke_R0[[-0.14053194]]',
#  'Co_OthStroke_R0[[-0.0726268]]',
#  'Co_TIA_R0[[-0.16450293]]',
#  'Co_COPD_R0[[-0.096389]]',
#  'Co_Asthma_R0[[0.23563278]]',
#  'Co_Pneumonia_R0[[-0.18581863]]',
#  'Co_Alcoholabuse_R0[[0.29097604]]',
#  'Co_Drugabuse_R0[[-0.06395197]]',
#  'Co_Epilepsy_R0[[-0.05793415]]',
#  'Co_Cancer_R0[[0.08853264]]',
#  'Co_MorbidObesity_R0[[0.04652651]]',
#  'Co_Dementia_R0[[-0.06392455]]',
#  'Co_Depression_R0[[-0.06104646]]',
#  'Co_Bipolar_R0[[-0.12889799]]',
#  'Co_Psychosis_R0[[0.07929378]]',
#  'Co_Personalitydisorder_R0[[-0.06812866]]',
#  'Co_Adjustmentdisorder_R0[[-0.06499961]]',
#  'Co_Anxiety_R0[[0.08064317]]',
#  'Co_Generalizedanxiety_R0[[-0.08873405]]',
#  'Co_OldMI_R0[[-0.1773371]]',
#  'Co_AcuteMI_R0[[-0.12844454]]',
#  'Co_PUD_R0[[-0.28534706]]',
#  'Co_UpperGIbleed_R0[[-0.10349701]]',
#  'Co_LowerGIbleed_R0[[0.61911968]]',
#  'Co_Urogenitalbleed_R0[[0.37492163]]',
#  'Co_Othbleed_R0[[-0.4113217]]',
#  'Co_PVD_R0[[0.75048723]]',
#  'Co_LiverDisease_R0[[0.04868486]]',
#  'Co_MRI_R0[[0.32966545]]',
#  'Co_ESRD_R0[[0.17538426]]',
#  'Co_Obesity_R0[[-0.1249403]]',
#  'Co_Sepsis_R0[[-0.30715476]]',
#  'Co_Osteoarthritis_R0[[0.11046418]]',
#  'Co_RA_R0[[0.263076]]',
#  'Co_NeuroPain_R0[[0.09877851]]',
#  'Co_NeckPain_R0[[-0.09202943]]',
#  'Co_OthArthritis_R0[[-0.20723906]]',
#  'Co_Osteoporosis_R0[[0.49332756]]',
#  'Co_Fibromyalgia_R0[[0.05066872]]',
#  'Co_Migraine_R0[[-0.09255892]]',
#  'Co_Headache_R0[[0.12463363]]',
#  'Co_OthPain_R0[[-0.18045082]]',
#  'Co_GeneralizedPain_R0[[-0.0799839]]',
#  'Co_PainDisorder_R0[[0.00580611]]',
#  'Co_Falls_R0[[0.23188528]]',
#  'Co_CoagulationDisorder_R0[[-0.4151238]]',
#  'Co_WhiteBloodCell_R0[[0.20253364]]',
#  'Co_Parkinson_R0[[0.00349268]]',
#  'Co_Anemia_R0[[0.56430108]]',
#  'Co_UrinaryIncontinence_R0[[0.28069809]]',
#  'Co_DecubitusUlcer_R0[[0.14540539]]',
#  'Co_Oxygen_R0[[0.04295497]]',
#  'Co_Mammography_R0[[-0.0713367]]',
#  'Co_PapTest_R0[[-0.50356625]]',
#  'Co_PSATest_R0[[-0.27480442]]',
#  'Co_Colonoscopy_R0[[0.25507039]]',
#  'Co_FecalOccultTest_R0[[-0.08242318]]',
#  'Co_FluShot_R0[[0.02741932]]',
#  'Co_PneumococcalVaccine_R0[[0.01437813]]',
#  'Co_RenalDysfunction_R0[[0.11359006]]',
#  'Co_Valvular_R0[[0.19440572]]',
#  'Co_Hosp_Prior30Days_R0[[0.53147348]]',
#  'Co_RX_Antibiotic_R0[[-0.03178572]]',
#  'Co_RX_Corticosteroid_R0[[0.03671663]]',
#  'Co_RX_Aspirin_R0[[0.12913676]]',
#  'Co_RX_Dipyridamole_R0[[-0.03456845]]',
#  'Co_RX_Clopidogrel_R0[[-0.09983565]]',
#  'Co_RX_Prasugrel_R0[[0.04786686]]',
#  'Co_RX_Cilostazol_R0[[-0.15335071]]',
#  'Co_RX_Ticlopidine_R0[[-0.02290125]]',
#  'Co_RX_Ticagrelor_R0[[0.19940748]]',
#  'Co_RX_OthAntiplatelet_R0[[-0.17625196]]',
#  'Co_RX_NSAIDs_R0[[-0.15866413]]',
#  'Co_RX_Opioid_R0[[-0.08887696]]',
#  'Co_RX_Antidepressant_R0[[0.08055766]]',
#  'Co_RX_AAntipsychotic_R0[[-0.37555795]]',
#  'Co_RX_TAntipsychotic_R0[[0.05854047]]',
#  'Co_RX_Anticonvulsant_R0[[0.09593794]]',
#  'Co_RX_PPI_R0[[0.17926349]]',
#  'Co_RX_H2Receptor_R0[[-0.1834953]]',
#  'Co_RX_OthGastro_R0[[-0.49778016]]',
#  'Co_RX_ACE_R0[[-0.18667302]]',
#  'Co_RX_ARB_R0[[-0.09259515]]',
#  'Co_RX_BBlocker_R0[[0.06801251]]',
#  'Co_RX_CCB_R0[[-0.01341715]]',
#  'Co_RX_Thiazide_R0[[-0.16152524]]',
#  'Co_RX_Loop_R0[[0.16140989]]',
#  'Co_RX_Potassium_R0[[0.06573734]]',
#  'Co_RX_Nitrates_R0[[-0.16035267]]',
#  'Co_RX_Aliskiren_R0[[-0.03145226]]',
#  'Co_RX_OthAntihypertensive_R0[[0.0430089]]',
#  'Co_RX_Antiarrhythmic_R0[[-0.39482634]]',
#  'Co_RX_OthAnticoagulant_R0[[-0.16583096]]',
#  'Co_RX_Insulin_R0[[0.11657569]]',
#  'Co_RX_Noninsulin_R0[[-0.07318072]]',
#  'Co_RX_Digoxin_R0[[-0.45750146]]',
#  'Co_RX_Statin_R0[[-0.10673132]]',
#  'Co_RX_Lipid_R0[[0.01135038]]',
#  'Co_RX_Lithium_R0[[-0.07862541]]',
#  'Co_RX_Benzo_R0[[-0.22208175]]',
#  'Co_RX_ZDrugs_R0[[-0.14847583]]',
#  'Co_RX_OthAnxiolytic_R0[[-0.29252002]]',
#  'Co_RX_Dementia_R0[[-0.26846485]]',
#  'Co_RX_Hormone_R0[[-0.21382361]]',
#  'Co_RX_Osteoporosis_R0[[-0.00359464]]',
#  'Co_N_Drugs_R0[[0.01289387]]',
#  'Co_N_Hosp_R0[[0.01077532]]',
#  'Co_Total_HospLOS_R0[[0.00180612]]',
#  'Co_N_MDVisit_R0[[0.02929588]]',
#  'Co_RX_AnyAspirin_R0[[0.10826616]]',
#  'Co_RX_AspirinMono_R0[[0.13593159]]',
#  'Co_RX_ClopidogrelMono_R0[[-0.09144561]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.0032728]]',
#  'Co_RX_DM_R0[[-0.14388286]]',
#  'Co_RX_Antipsychotic_R0[[-0.14241795]]']

# %% [markdown]
# # High Continuity

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_high_sm,out_train_hemorrhage_high_sm = sm.fit_resample(co_train_high,out_train_hemorrhage_high)

best_clf = lr(co_train_high_sm, out_train_hemorrhage_high_sm)

scores(co_train_high_sm, out_train_hemorrhage_high_sm)

print()

scores(co_train_high, out_train_hemorrhage_high)

print()

scores(co_validation_high, out_validation_hemorrhage_high)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7179161765616294
# 0.7081131289836968
# 0.717594499868748
# 0.7899299166356765
# 9.742929451832659
#
# 0.748329754235266
# 0.16139932419002187
# 0.5422216791213361
# 0.7735650388171296
# 8.692573800656943
#
# 0.7414909166840676
# 0.16856950973807924
# 0.5396588178918171
# 0.7255178409818894
# 8.928779184495303
# ['Co_CAD_R0[[0.11318737]]',
#  'Co_Embolism_R0[[0.06040545]]',
#  'Co_DVT_R0[[0.08629677]]',
#  'Co_PE_R0[[0.05120827]]',
#  'Co_AFib_R0[[0.31881484]]',
#  'Co_Hypertension_R0[[0.26299544]]',
#  'Co_Hyperlipidemia_R0[[-0.09626166]]',
#  'Co_Atherosclerosis_R0[[0.18481922]]',
#  'Co_HF_R0[[0.26066173]]',
#  'Co_HemoStroke_R0[[-0.07762363]]',
#  'Co_IscheStroke_R0[[-0.01819831]]',
#  'Co_OthStroke_R0[[0.14530809]]',
#  'Co_TIA_R0[[-0.17471411]]',
#  'Co_COPD_R0[[0.25860179]]',
#  'Co_Asthma_R0[[0.06752889]]',
#  'Co_Pneumonia_R0[[-0.23300145]]',
#  'Co_Alcoholabuse_R0[[0.70978629]]',
#  'Co_Drugabuse_R0[[-0.1016591]]',
#  'Co_Epilepsy_R0[[-0.17160849]]',
#  'Co_Cancer_R0[[0.34795084]]',
#  'Co_MorbidObesity_R0[[-0.09773823]]',
#  'Co_Dementia_R0[[0.36164556]]',
#  'Co_Depression_R0[[-0.13601625]]',
#  'Co_Bipolar_R0[[-0.14220744]]',
#  'Co_Psychosis_R0[[0.28630564]]',
#  'Co_Personalitydisorder_R0[[-0.21388931]]',
#  'Co_Adjustmentdisorder_R0[[-0.15453595]]',
#  'Co_Anxiety_R0[[-0.04405648]]',
#  'Co_Generalizedanxiety_R0[[-0.12270381]]',
#  'Co_OldMI_R0[[0.16129531]]',
#  'Co_AcuteMI_R0[[0.2808574]]',
#  'Co_PUD_R0[[-0.16079109]]',
#  'Co_UpperGIbleed_R0[[0.1119697]]',
#  'Co_LowerGIbleed_R0[[0.39621074]]',
#  'Co_Urogenitalbleed_R0[[0.56883435]]',
#  'Co_Othbleed_R0[[-0.53310712]]',
#  'Co_PVD_R0[[0.79155837]]',
#  'Co_LiverDisease_R0[[0.04122525]]',
#  'Co_MRI_R0[[0.21535095]]',
#  'Co_ESRD_R0[[0.38316639]]',
#  'Co_Obesity_R0[[-0.08601655]]',
#  'Co_Sepsis_R0[[-0.33060138]]',
#  'Co_Osteoarthritis_R0[[0.0141794]]',
#  'Co_RA_R0[[0.30261906]]',
#  'Co_NeuroPain_R0[[0.11903678]]',
#  'Co_NeckPain_R0[[-0.04504658]]',
#  'Co_OthArthritis_R0[[-0.01615071]]',
#  'Co_Osteoporosis_R0[[0.62384244]]',
#  'Co_Fibromyalgia_R0[[0.23164551]]',
#  'Co_Migraine_R0[[-0.08754459]]',
#  'Co_Headache_R0[[0.29782844]]',
#  'Co_OthPain_R0[[-0.02078783]]',
#  'Co_GeneralizedPain_R0[[0.0116856]]',
#  'Co_PainDisorder_R0[[0.00783192]]',
#  'Co_Falls_R0[[0.36821007]]',
#  'Co_CoagulationDisorder_R0[[-0.1244545]]',
#  'Co_WhiteBloodCell_R0[[0.11064012]]',
#  'Co_Parkinson_R0[[0.33100042]]',
#  'Co_Anemia_R0[[0.52094292]]',
#  'Co_UrinaryIncontinence_R0[[0.39714245]]',
#  'Co_DecubitusUlcer_R0[[0.23520714]]',
#  'Co_Oxygen_R0[[-0.13157636]]',
#  'Co_Mammography_R0[[-0.01594422]]',
#  'Co_PapTest_R0[[-0.5075296]]',
#  'Co_PSATest_R0[[-0.13550994]]',
#  'Co_Colonoscopy_R0[[0.37782379]]',
#  'Co_FecalOccultTest_R0[[-0.0103606]]',
#  'Co_FluShot_R0[[0.07756033]]',
#  'Co_PneumococcalVaccine_R0[[0.08681365]]',
#  'Co_RenalDysfunction_R0[[0.23534997]]',
#  'Co_Valvular_R0[[0.26675784]]',
#  'Co_Hosp_Prior30Days_R0[[0.30793621]]',
#  'Co_RX_Antibiotic_R0[[0.05093295]]',
#  'Co_RX_Corticosteroid_R0[[0.02909037]]',
#  'Co_RX_Aspirin_R0[[0.08958848]]',
#  'Co_RX_Dipyridamole_R0[[0.03474528]]',
#  'Co_RX_Clopidogrel_R0[[-0.10984654]]',
#  'Co_RX_Prasugrel_R0[[-0.12423308]]',
#  'Co_RX_Cilostazol_R0[[-0.29817994]]',
#  'Co_RX_Ticlopidine_R0[[-0.03253818]]',
#  'Co_RX_Ticagrelor_R0[[0.24609085]]',
#  'Co_RX_OthAntiplatelet_R0[[-0.33071811]]',
#  'Co_RX_NSAIDs_R0[[-0.06124809]]',
#  'Co_RX_Opioid_R0[[-0.24127002]]',
#  'Co_RX_Antidepressant_R0[[0.11163744]]',
#  'Co_RX_AAntipsychotic_R0[[-0.70604201]]',
#  'Co_RX_TAntipsychotic_R0[[0.09075065]]',
#  'Co_RX_Anticonvulsant_R0[[0.20346173]]',
#  'Co_RX_PPI_R0[[0.1166513]]',
#  'Co_RX_H2Receptor_R0[[-0.14411106]]',
#  'Co_RX_OthGastro_R0[[-0.34622931]]',
#  'Co_RX_ACE_R0[[-0.06560297]]',
#  'Co_RX_ARB_R0[[-0.03308889]]',
#  'Co_RX_BBlocker_R0[[0.14473578]]',
#  'Co_RX_CCB_R0[[-0.13447166]]',
#  'Co_RX_Thiazide_R0[[-0.04774891]]',
#  'Co_RX_Loop_R0[[0.21674103]]',
#  'Co_RX_Potassium_R0[[0.10461212]]',
#  'Co_RX_Nitrates_R0[[-0.29112994]]',
#  'Co_RX_Aliskiren_R0[[-0.05055724]]',
#  'Co_RX_OthAntihypertensive_R0[[0.02135441]]',
#  'Co_RX_Antiarrhythmic_R0[[-0.26623588]]',
#  'Co_RX_OthAnticoagulant_R0[[0.15655709]]',
#  'Co_RX_Insulin_R0[[-0.02219285]]',
#  'Co_RX_Noninsulin_R0[[0.13232901]]',
#  'Co_RX_Digoxin_R0[[-0.35571926]]',
#  'Co_RX_Statin_R0[[-0.18707545]]',
#  'Co_RX_Lipid_R0[[0.10708421]]',
#  'Co_RX_Lithium_R0[[-0.05618701]]',
#  'Co_RX_Benzo_R0[[-0.14817981]]',
#  'Co_RX_ZDrugs_R0[[-0.036783]]',
#  'Co_RX_OthAnxiolytic_R0[[-0.21486244]]',
#  'Co_RX_Dementia_R0[[-0.29209288]]',
#  'Co_RX_Hormone_R0[[-0.55082932]]',
#  'Co_RX_Osteoporosis_R0[[0.05263087]]',
#  'Co_N_Drugs_R0[[0.01003459]]',
#  'Co_N_Hosp_R0[[0.09526275]]',
#  'Co_Total_HospLOS_R0[[-0.00323698]]',
#  'Co_N_MDVisit_R0[[0.02163259]]',
#  'Co_RX_AnyAspirin_R0[[0.0481778]]',
#  'Co_RX_AspirinMono_R0[[0.31817316]]',
#  'Co_RX_ClopidogrelMono_R0[[-0.12705831]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.02653585]]',
#  'Co_RX_DM_R0[[-0.2159722]]',
#  'Co_RX_Antipsychotic_R0[[-0.3568824]]']

# %% [markdown]
# # Low Continuity

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
co_train_low_sm,out_train_hemorrhage_low_sm = sm.fit_resample(co_train_low,out_train_hemorrhage_low)

best_clf = lr(co_train_low_sm, out_train_hemorrhage_low_sm)

scores(co_train_low_sm, out_train_hemorrhage_low_sm)

print()

scores(co_train_low, out_train_hemorrhage_low)

print()

scores(co_validation_low, out_validation_hemorrhage_low)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7027978999136041
# 0.7117628101836933
# 0.7025196878298077
# 0.7597667425257972
# 10.265128134757303
#
# 0.6716050980138448
# 0.09743954480796585
# 0.4586970175219079
# 0.7254630612698099
# 11.342613637308132
#
# 0.6102309601068906
# 0.08018018018018018
# 0.4129446980004618
# 0.6034480265423301
# 13.46244600235761
# ['Co_CAD_R0[[0.91170943]]',
#  'Co_Embolism_R0[[0.53646294]]',
#  'Co_DVT_R0[[-0.27417061]]',
#  'Co_PE_R0[[0.19371936]]',
#  'Co_AFib_R0[[0.17589377]]',
#  'Co_Hypertension_R0[[-0.49694316]]',
#  'Co_Hyperlipidemia_R0[[-0.19094799]]',
#  'Co_Atherosclerosis_R0[[-0.0592164]]',
#  'Co_HF_R0[[-0.00170261]]',
#  'Co_HemoStroke_R0[[-0.76095477]]',
#  'Co_IscheStroke_R0[[-0.27744701]]',
#  'Co_OthStroke_R0[[-1.05925714]]',
#  'Co_TIA_R0[[-0.77647378]]',
#  'Co_COPD_R0[[-0.70928357]]',
#  'Co_Asthma_R0[[0.6814092]]',
#  'Co_Pneumonia_R0[[-0.36122051]]',
#  'Co_Alcoholabuse_R0[[-0.35253011]]',
#  'Co_Drugabuse_R0[[-0.69440928]]',
#  'Co_Epilepsy_R0[[0.23214441]]',
#  'Co_Cancer_R0[[-0.11624962]]',
#  'Co_MorbidObesity_R0[[0.84023785]]',
#  'Co_Dementia_R0[[-0.58098402]]',
#  'Co_Depression_R0[[-0.46104493]]',
#  'Co_Bipolar_R0[[-0.45019216]]',
#  'Co_Psychosis_R0[[-0.38467433]]',
#  'Co_Personalitydisorder_R0[[0.62417602]]',
#  'Co_Adjustmentdisorder_R0[[0.28044317]]',
#  'Co_Anxiety_R0[[0.66836103]]',
#  'Co_Generalizedanxiety_R0[[-0.01882774]]',
#  'Co_OldMI_R0[[-0.7955181]]',
#  'Co_AcuteMI_R0[[-0.70986538]]',
#  'Co_PUD_R0[[-0.52503907]]',
#  'Co_UpperGIbleed_R0[[-1.15778647]]',
#  'Co_LowerGIbleed_R0[[1.14981143]]',
#  'Co_Urogenitalbleed_R0[[0.0333948]]',
#  'Co_Othbleed_R0[[-0.45270935]]',
#  'Co_PVD_R0[[0.61368771]]',
#  'Co_LiverDisease_R0[[0.40383782]]',
#  'Co_MRI_R0[[0.55448122]]',
#  'Co_ESRD_R0[[-0.20609664]]',
#  'Co_Obesity_R0[[-0.23278346]]',
#  'Co_Sepsis_R0[[-0.8688027]]',
#  'Co_Osteoarthritis_R0[[0.59383665]]',
#  'Co_RA_R0[[0.50970058]]',
#  'Co_NeuroPain_R0[[0.0516573]]',
#  'Co_NeckPain_R0[[-0.175575]]',
#  'Co_OthArthritis_R0[[-0.23781424]]',
#  'Co_Osteoporosis_R0[[0.3888973]]',
#  'Co_Fibromyalgia_R0[[-0.48284044]]',
#  'Co_Migraine_R0[[-0.32326224]]',
#  'Co_Headache_R0[[-0.67187522]]',
#  'Co_OthPain_R0[[-0.58887817]]',
#  'Co_GeneralizedPain_R0[[-0.645564]]',
#  'Co_PainDisorder_R0[[-0.01419676]]',
#  'Co_Falls_R0[[-0.56804026]]',
#  'Co_CoagulationDisorder_R0[[-1.51285728]]',
#  'Co_WhiteBloodCell_R0[[0.76528077]]',
#  'Co_Parkinson_R0[[-1.14973697]]',
#  'Co_Anemia_R0[[0.85673567]]',
#  'Co_UrinaryIncontinence_R0[[-0.30243657]]',
#  'Co_DecubitusUlcer_R0[[0.0663775]]',
#  'Co_Oxygen_R0[[0.64808838]]',
#  'Co_Mammography_R0[[-1.13800722]]',
#  'Co_PapTest_R0[[-0.44339007]]',
#  'Co_PSATest_R0[[-0.70184856]]',
#  'Co_Colonoscopy_R0[[-0.71197891]]',
#  'Co_FecalOccultTest_R0[[0.04568146]]',
#  'Co_FluShot_R0[[-0.04376732]]',
#  'Co_PneumococcalVaccine_R0[[-0.73715074]]',
#  'Co_RenalDysfunction_R0[[-0.16699898]]',
#  'Co_Valvular_R0[[0.24597748]]',
#  'Co_Hosp_Prior30Days_R0[[2.51076539]]',
#  'Co_RX_Antibiotic_R0[[-0.11452979]]',
#  'Co_RX_Corticosteroid_R0[[0.04100422]]',
#  'Co_RX_Aspirin_R0[[0.26704129]]',
#  'Co_RX_Dipyridamole_R0[[-0.28162282]]',
#  'Co_RX_Clopidogrel_R0[[0.09996914]]',
#  'Co_RX_Prasugrel_R0[[0.66803037]]',
#  'Co_RX_Cilostazol_R0[[-0.02408944]]',
#  'Co_RX_Ticlopidine_R0[[-0.01793824]]',
#  'Co_RX_Ticagrelor_R0[[0.20641547]]',
#  'Co_RX_OthAntiplatelet_R0[[-0.04202769]]',
#  'Co_RX_NSAIDs_R0[[-0.50825429]]',
#  'Co_RX_Opioid_R0[[0.1983725]]',
#  'Co_RX_Antidepressant_R0[[-0.0705039]]',
#  'Co_RX_AAntipsychotic_R0[[0.33731799]]',
#  'Co_RX_TAntipsychotic_R0[[-0.11011003]]',
#  'Co_RX_Anticonvulsant_R0[[0.15964767]]',
#  'Co_RX_PPI_R0[[0.37744821]]',
#  'Co_RX_H2Receptor_R0[[-0.27650711]]',
#  'Co_RX_OthGastro_R0[[-0.85616939]]',
#  'Co_RX_ACE_R0[[-0.18521542]]',
#  'Co_RX_ARB_R0[[-0.31858275]]',
#  'Co_RX_BBlocker_R0[[-0.0106674]]',
#  'Co_RX_CCB_R0[[0.10710663]]',
#  'Co_RX_Thiazide_R0[[-0.39771044]]',
#  'Co_RX_Loop_R0[[0.11490154]]',
#  'Co_RX_Potassium_R0[[0.17797434]]',
#  'Co_RX_Nitrates_R0[[-0.08235688]]',
#  'Co_RX_Aliskiren_R0[[-0.04149343]]',
#  'Co_RX_OthAntihypertensive_R0[[0.28579896]]',
#  'Co_RX_Antiarrhythmic_R0[[-0.62607786]]',
#  'Co_RX_OthAnticoagulant_R0[[-1.22178343]]',
#  'Co_RX_Insulin_R0[[0.29220129]]',
#  'Co_RX_Noninsulin_R0[[-0.59838568]]',
#  'Co_RX_Digoxin_R0[[-1.08583893]]',
#  'Co_RX_Statin_R0[[-0.23336116]]',
#  'Co_RX_Lipid_R0[[-0.54493414]]',
#  'Co_RX_Lithium_R0[[-0.20074625]]',
#  'Co_RX_Benzo_R0[[-0.36112746]]',
#  'Co_RX_ZDrugs_R0[[-0.06261394]]',
#  'Co_RX_OthAnxiolytic_R0[[-0.58111614]]',
#  'Co_RX_Dementia_R0[[-0.91392786]]',
#  'Co_RX_Hormone_R0[[0.72477201]]',
#  'Co_RX_Osteoporosis_R0[[-0.58948099]]',
#  'Co_N_Drugs_R0[[0.03019649]]',
#  'Co_N_Hosp_R0[[-2.03384873]]',
#  'Co_Total_HospLOS_R0[[0.01746667]]',
#  'Co_N_MDVisit_R0[[-0.27198617]]',
#  'Co_RX_AnyAspirin_R0[[0.26704129]]',
#  'Co_RX_AspirinMono_R0[[-0.33922767]]',
#  'Co_RX_ClopidogrelMono_R0[[0.04644014]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.12034213]]',
#  'Co_RX_DM_R0[[0.13842192]]',
#  'Co_RX_Antipsychotic_R0[[0.51397774]]']
