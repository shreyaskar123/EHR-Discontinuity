# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import pandas as pd
#medicare = pd.read_csv("/netapp2/home/se197/RPDR/Josh Lin/3_EHR_V2/CMS/Data/final_medicare.csv")
medicare = pd.read_csv("/netapp2/home/se197/data/CMS/Data/medicare.csv")

# In[2]:


train_set = medicare[medicare.Hospital != 'BWH'] # MGH
validation_set = medicare[medicare.Hospital == 'BWH'] # BWH and Neither 
import numpy as np

fifty_perc_EHR_cont = np.percentile(medicare['Cal_MPEC_R0'],50)
train_set_high = train_set[train_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
train_set_low= train_set[train_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

validation_set_high = validation_set[validation_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
validation_set_low = validation_set[validation_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]


# In[3]:

print("", file = open('cardio_nd_no_lr_ehr.out', 'a'))
predictor_variable = [
        'Co_CAD_R0', 'Co_Embolism_R0', 'Co_DVT_R0', 'Co_PE_R0', 'Co_AFib_R0',
        'Co_Hypertension_R0', 'Co_Hyperlipidemia_R0', 'Co_Atherosclerosis_R0',
        'Co_HF_R0', 'Co_HemoStroke_R0', 'Co_IscheStroke_R0', 'Co_OthStroke_R0',
        'Co_TIA_R0', 'Co_COPD_R0', 'Co_Asthma_R0', 'Co_Pneumonia_R0', 'Co_Alcoholabuse_R0',
        'Co_Drugabuse_R0', 'Co_Epilepsy_R0', 'Co_Cancer_R0', 'Co_MorbidObesity_R0',
        'Co_Dementia_R0', 'Co_Depression_R0', 'Co_Bipolar_R0', 'Co_Psychosis_R0',
        'Co_Personalitydisorder_R0', 'Co_Adjustmentdisorder_R0', 'Co_Anxiety_R0',
        'Co_Generalizedanxiety_R0', 'Co_OldMI_R0', 'Co_AcuteMI_R0', 'Co_PUD_R0',
        'Co_UpperGIbleed_R0', 'Co_LowerGIbleed_R0', 'Co_Urogenitalbleed_R0',
        'Co_Othbleed_R0', 'Co_PVD_R0', 'Co_LiverDisease_R0', 'Co_MRI_R0',
        'Co_ESRD_R0', 'Co_Obesity_R0', 'Co_Sepsis_R0', 'Co_Osteoarthritis_R0',
        'Co_RA_R0', 'Co_NeuroPain_R0', 'Co_NeckPain_R0', 'Co_OthArthritis_R0',
        'Co_Osteoporosis_R0', 'Co_Fibromyalgia_R0', 'Co_Migraine_R0', 'Co_Headache_R0',
        'Co_OthPain_R0', 'Co_GeneralizedPain_R0', 'Co_PainDisorder_R0',
        'Co_Falls_R0', 'Co_CoagulationDisorder_R0', 'Co_WhiteBloodCell_R0', 'Co_Parkinson_R0',
        'Co_Anemia_R0', 'Co_UrinaryIncontinence_R0', 'Co_DecubitusUlcer_R0',
        'Co_Oxygen_R0', 'Co_Mammography_R0', 'Co_PapTest_R0', 'Co_PSATest_R0',
        'Co_Colonoscopy_R0', 'Co_FecalOccultTest_R0', 'Co_FluShot_R0', 'Co_PneumococcalVaccine_R0', 'Co_RenalDysfunction_R0', 'Co_Valvular_R0', 'Co_Hosp_Prior30Days_R0',
        'Co_RX_Antibiotic_R0', 'Co_RX_Corticosteroid_R0', 'Co_RX_Aspirin_R0', 'Co_RX_Dipyridamole_R0',
        'Co_RX_Clopidogrel_R0', 'Co_RX_Prasugrel_R0', 'Co_RX_Cilostazol_R0', 'Co_RX_Ticlopidine_R0',
        'Co_RX_Ticagrelor_R0', 'Co_RX_OthAntiplatelet_R0', 'Co_RX_NSAIDs_R0',
        'Co_RX_Opioid_R0', 'Co_RX_Antidepressant_R0', 'Co_RX_AAntipsychotic_R0', 'Co_RX_TAntipsychotic_R0',
        'Co_RX_Anticonvulsant_R0', 'Co_RX_PPI_R0', 'Co_RX_H2Receptor_R0', 'Co_RX_OthGastro_R0',
        'Co_RX_ACE_R0', 'Co_RX_ARB_R0', 'Co_RX_BBlocker_R0', 'Co_RX_CCB_R0', 'Co_RX_Thiazide_R0',
        'Co_RX_Loop_R0', 'Co_RX_Potassium_R0', 'Co_RX_Nitrates_R0', 'Co_RX_Aliskiren_R0',
        'Co_RX_OthAntihypertensive_R0', 'Co_RX_Antiarrhythmic_R0', 'Co_RX_OthAnticoagulant_R0',
        'Co_RX_Insulin_R0', 'Co_RX_Noninsulin_R0', 'Co_RX_Digoxin_R0', 'Co_RX_Statin_R0',
        'Co_RX_Lipid_R0', 'Co_RX_Lithium_R0', 'Co_RX_Benzo_R0', 'Co_RX_ZDrugs_R0',
        'Co_RX_OthAnxiolytic_R0', 'Co_RX_Barbiturate_R0', 'Co_RX_Dementia_R0', 'Co_RX_Hormone_R0',
        'Co_RX_Osteoporosis_R0', 'Co_N_Drugs_R0', 'Co_N_Hosp_R0', 'Co_Total_HospLOS_R0',
        'Co_N_MDVisit_R0', 'Co_RX_AnyAspirin_R0', 'Co_RX_AspirinMono_R0', 'Co_RX_ClopidogrelMono_R0',
        'Co_RX_AspirinClopidogrel_R0', 'Co_RX_DM_R0', 'Co_RX_Antipsychotic_R0'
]

co_train_gpop = train_set[predictor_variable]
co_train_high = train_set_high[predictor_variable]
co_train_low = train_set_low[predictor_variable]

co_validation_gpop = validation_set[predictor_variable]
co_validation_high = validation_set_high[predictor_variable]
co_validation_low = validation_set_low[predictor_variable]


# In[4]:


out_train_cardio_gpop = train_set['Out_comp_cardiovascular_nd_RC1']
out_train_cardio_high = train_set_high['Out_comp_cardiovascular_nd_RC1']
out_train_cardio_low = train_set_low['Out_comp_cardiovascular_nd_RC1']

out_validation_cardio_gpop = validation_set['Out_comp_cardiovascular_nd_RC1']
out_validation_cardio_high = validation_set_high['Out_comp_cardiovascular_nd_RC1']
out_validation_cardio_low = validation_set_low['Out_comp_cardiovascular_nd_RC1']


# In[5]:


def lr(X_train, y_train):
    from sklearn.linear_model import Lasso
    from sklearn.decomposition import PCA
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler 

    model = LogisticRegression()
    param_grid = [
        {'C' : np.logspace(-4, 4, 20)}
        ]
    clf = GridSearchCV(model, param_grid, cv = 5, verbose = True, n_jobs = -1)
    best_clf = clf.fit(X_train, y_train)
    return best_clf


# In[6]:


def scores(X_train,y_train):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_train)
    actual = y_train
    print(accuracy_score(actual,pred),file = open('cardio_nd_no_lr_ehr.out', 'a'))
    print(f1_score(actual,pred),file = open('cardio_nd_no_lr_ehr.out', 'a'))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2),file = open('cardio_nd_no_lr_ehr.out', 'a'))
    print(roc_auc_score(actual, best_clf.predict_proba(X_train)[:,1]),file = open('cardio_nd_no_lr_ehr.out', 'a'))
    print(log_loss(actual,best_clf.predict_proba(X_train)[:,1]),file = open('cardio_nd_no_lr_ehr.out', 'a'))
    
    


# In[7]:


def cross_val(X,y):
    from sklearn.model_selection import KFold
    from sklearn.model_selection import cross_validate
    from sklearn.metrics import log_loss
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import fbeta_score
    import sklearn
    import numpy as np
    cv = KFold(n_splits=5, random_state=1, shuffle=True)
    log_loss = [] 
    auc = [] 
    accuracy = [] 
    f1 = [] 
    f2 = [] 
    for train_index, test_index in cv.split(X):
        X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        model = lr(X_train, y_train)
        prob = model.predict_proba(X_test)[:,1] # prob is a vector of probabilities 
        print(prob)
        pred = np.round(prob) # pred is the rounded predictions 
        
        log_loss.append(sklearn.metrics.log_loss(y_test, prob))
        auc.append(sklearn.metrics.roc_auc_score(y_test, prob))
        accuracy.append(sklearn.metrics.accuracy_score(y_test, pred))
        f1.append(sklearn.metrics.f1_score(y_test, pred, average = 'macro'))
        f2.append(fbeta_score(y_test,pred, average = 'macro', beta = 2))
    print(np.mean(accuracy),file = open('cardio_nd_no_lr_ehr.out', 'a'))
    print(np.mean(f1),file = open('cardio_nd_no_lr_ehr.out', 'a'))
    print(np.mean(f2),file = open('cardio_nd_no_lr_ehr.out', 'a'))
    print(np.mean(auc),file = open('cardio_nd_no_lr_ehr.out', 'a'))
    print(np.mean(log_loss),file = open('cardio_nd_no_lr_ehr.out', 'a'))


# In[8]:


print("Gpop",file = open('cardio_nd_no_lr_ehr.out', 'a'))
best_clf = lr(co_train_gpop, out_train_cardio_gpop)
prediction_gpop_onlow = best_clf.predict_proba(co_train_low)
cross_val(co_train_gpop, out_train_cardio_gpop)
print()
print("",file = open('cardio_nd_no_lr_ehr.out', 'a'))
scores(co_validation_gpop, out_validation_cardio_gpop)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb


# In[14]:


print("Low",file = open('cardio_nd_no_lr_ehr.out', 'a'))
best_clf = lr(co_train_low, out_train_cardio_low)
prediction_low_onlow = best_clf.predict_proba(co_train_low)

scores(co_train_low, out_train_cardio_low)
print("",file = open('cardio_nd_no_lr_ehr.out', 'a'))
scores(co_validation_low, out_validation_cardio_low)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb


# In[15]:


#print("High",file = open('cardio_nd_no_lr_ehr.out', 'a'))
#best_clf = lr(co_train_high, out_train_cardio_high)
#scores(co_train_high, out_train_cardio_high)
#print()
#print("",file = open('cardio_nd_no_lr_ehr.out', 'a'))
#scores(co_validation_high, out_validation_cardio_high)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ['Co_CAD_R0[[0.45466166]]',
#  'Co_Embolism_R0[[-0.12724507]]',
#  'Co_DVT_R0[[-0.29125666]]',
#  'Co_PE_R0[[-0.05904544]]',
#  'Co_AFib_R0[[0.12450372]]',
#  'Co_Hypertension_R0[[-0.01313947]]',
#  'Co_Hyperlipidemia_R0[[-0.1872545]]',
#  'Co_Atherosclerosis_R0[[-0.01304006]]',
#  'Co_HF_R0[[-0.10581835]]',
#  'Co_HemoStroke_R0[[-0.09740789]]',
#  'Co_IscheStroke_R0[[0.82319444]]',
#  'Co_OthStroke_R0[[0.22434768]]',
#  'Co_TIA_R0[[0.379493]]',
#  'Co_COPD_R0[[-0.04774405]]',
#  'Co_Asthma_R0[[0.234545]]',
#  'Co_Pneumonia_R0[[-0.17374129]]',
#  'Co_Alcoholabuse_R0[[-0.02391326]]',
#  'Co_Drugabuse_R0[[-0.07792156]]',
#  'Co_Epilepsy_R0[[-0.02839162]]',
#  'Co_Cancer_R0[[-0.06098362]]',
#  'Co_MorbidObesity_R0[[-0.00793067]]',
#  'Co_Dementia_R0[[-0.12726477]]',
#  'Co_Depression_R0[[-0.02649737]]',
#  'Co_Bipolar_R0[[-0.13347586]]',
#  'Co_Psychosis_R0[[-0.12745666]]',
#  'Co_Personalitydisorder_R0[[-0.03683842]]',
#  'Co_Adjustmentdisorder_R0[[-0.07949953]]',
#  'Co_Anxiety_R0[[-0.17006408]]',
#  'Co_Generalizedanxiety_R0[[0.00791051]]',
#  'Co_OldMI_R0[[-0.20646322]]',
#  'Co_AcuteMI_R0[[0.51815052]]',
#  'Co_PUD_R0[[-0.06043992]]',
#  'Co_UpperGIbleed_R0[[0.16910419]]',
#  'Co_LowerGIbleed_R0[[0.27672868]]',
#  'Co_Urogenitalbleed_R0[[0.17773317]]',
#  'Co_Othbleed_R0[[-0.12002788]]',
#  'Co_PVD_R0[[0.25625484]]',
#  'Co_LiverDisease_R0[[-0.19346271]]',
#  'Co_MRI_R0[[0.22322705]]',
#  'Co_ESRD_R0[[0.36417039]]',
#  'Co_Obesity_R0[[-0.20515914]]',
#  'Co_Sepsis_R0[[-0.32946578]]',
#  'Co_Osteoarthritis_R0[[-0.13036038]]',
#  'Co_RA_R0[[0.15078555]]',
#  'Co_NeuroPain_R0[[0.08270423]]',
#  'Co_NeckPain_R0[[0.01842339]]',
#  'Co_OthArthritis_R0[[0.08211214]]',
#  'Co_Osteoporosis_R0[[-0.09535965]]',
#  'Co_Fibromyalgia_R0[[0.03633622]]',
#  'Co_Migraine_R0[[-0.07209415]]',
#  'Co_Headache_R0[[0.10608307]]',
#  'Co_OthPain_R0[[-0.13966823]]',
#  'Co_GeneralizedPain_R0[[0.15558425]]',
#  'Co_PainDisorder_R0[[-0.00486432]]',
#  'Co_Falls_R0[[0.18707207]]',
#  'Co_CoagulationDisorder_R0[[-0.01530754]]',
#  'Co_WhiteBloodCell_R0[[-0.02788353]]',
#  'Co_Parkinson_R0[[0.01882575]]',
#  'Co_Anemia_R0[[0.04503373]]',
#  'Co_UrinaryIncontinence_R0[[-0.0414095]]',
#  'Co_DecubitusUlcer_R0[[0.11567283]]',
#  'Co_Oxygen_R0[[0.00924347]]',
#  'Co_Mammography_R0[[-0.2122534]]',
#  'Co_PapTest_R0[[-0.01128204]]',
#  'Co_PSATest_R0[[-0.04783466]]',
#  'Co_Colonoscopy_R0[[-0.10042732]]',
#  'Co_FecalOccultTest_R0[[-0.06677018]]',
#  'Co_FluShot_R0[[0.01556513]]',
#  'Co_PneumococcalVaccine_R0[[-0.20423047]]',
#  'Co_RenalDysfunction_R0[[0.19306708]]',
#  'Co_Valvular_R0[[-0.01331301]]',
#  'Co_Hosp_Prior30Days_R0[[0.26282322]]',
#  'Co_RX_Antibiotic_R0[[-0.16039988]]',
#  'Co_RX_Corticosteroid_R0[[0.08806363]]',
#  'Co_RX_Aspirin_R0[[0.0372631]]',
#  'Co_RX_Dipyridamole_R0[[-0.04768344]]',
#  'Co_RX_Clopidogrel_R0[[0.16558781]]',
#  'Co_RX_Prasugrel_R0[[-0.04432913]]',
#  'Co_RX_Cilostazol_R0[[-0.12631724]]',
#  'Co_RX_Ticlopidine_R0[[-0.00763044]]',
#  'Co_RX_Ticagrelor_R0[[-0.02012922]]',
#  'Co_RX_OthAntiplatelet_R0[[-0.13394769]]',
#  'Co_RX_NSAIDs_R0[[0.04870528]]',
#  'Co_RX_Opioid_R0[[-0.0865565]]',
#  'Co_RX_Antidepressant_R0[[-0.18017586]]',
#  'Co_RX_AAntipsychotic_R0[[-0.14479858]]',
#  'Co_RX_TAntipsychotic_R0[[0.26774064]]',
#  'Co_RX_Anticonvulsant_R0[[0.01621049]]',
#  'Co_RX_PPI_R0[[-0.01414227]]',
#  'Co_RX_H2Receptor_R0[[-0.10761753]]',
#  'Co_RX_OthGastro_R0[[-0.25940987]]',
#  'Co_RX_ACE_R0[[-0.15385498]]',
#  'Co_RX_ARB_R0[[-0.12167426]]',
#  'Co_RX_BBlocker_R0[[0.05411398]]',
#  'Co_RX_CCB_R0[[0.20655312]]',
#  'Co_RX_Thiazide_R0[[0.03756812]]',
#  'Co_RX_Loop_R0[[0.16687009]]',
#  'Co_RX_Potassium_R0[[-0.03337782]]',
#  'Co_RX_Nitrates_R0[[0.25802256]]',
#  'Co_RX_Aliskiren_R0[[-0.02144439]]',
#  'Co_RX_OthAntihypertensive_R0[[0.12335716]]',
#  'Co_RX_Antiarrhythmic_R0[[-0.3672177]]',
#  'Co_RX_OthAnticoagulant_R0[[0.03328756]]',
#  'Co_RX_Insulin_R0[[0.26241983]]',
#  'Co_RX_Noninsulin_R0[[-0.23896836]]',
#  'Co_RX_Digoxin_R0[[0.00754915]]',
#  'Co_RX_Statin_R0[[-0.12844986]]',
#  'Co_RX_Lipid_R0[[-0.13364369]]',
#  'Co_RX_Lithium_R0[[0.08802157]]',
#  'Co_RX_Benzo_R0[[0.0322651]]',
#  'Co_RX_ZDrugs_R0[[-0.08106154]]',
#  'Co_RX_OthAnxiolytic_R0[[-0.08577806]]',
#  'Co_RX_Barbiturate_R0[[0.]]',
#  'Co_RX_Dementia_R0[[0.04563391]]',
#  'Co_RX_Hormone_R0[[0.01053321]]',
#  'Co_RX_Osteoporosis_R0[[-0.13505019]]',
#  'Co_N_Drugs_R0[[-5.01208315e-05]]',
#  'Co_N_Hosp_R0[[-0.21111089]]',
#  'Co_Total_HospLOS_R0[[-0.0042409]]',
#  'Co_N_MDVisit_R0[[-0.23338828]]',
#  'Co_RX_AnyAspirin_R0[[0.0372631]]',
#  'Co_RX_AspirinMono_R0[[-0.06379061]]',
#  'Co_RX_ClopidogrelMono_R0[[-0.07197093]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.25167625]]',
#  'Co_RX_DM_R0[[0.25303964]]',
#  'Co_RX_Antipsychotic_R0[[0.05681835]]']
