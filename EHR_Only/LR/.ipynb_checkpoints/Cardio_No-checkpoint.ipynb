# %%
import pandas as pd
medicare = pd.read_csv("/netapp2/home/se197/RPDR/Josh Lin/3_EHR_V2/CMS/Data/final_medicare.csv")

# %%
train_set = medicare[medicare.Hospital != 'BWH'] # MGH
validation_set = medicare[medicare.Hospital == 'BWH'] # BWH and Neither 
import numpy as np

fifty_perc_EHR_cont = np.percentile(medicare['Cal_MPEC_R0'],50)
train_set_high = train_set[train_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
train_set_low= train_set[train_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

validation_set_high = validation_set[validation_set.Cal_MPEC_R0 >= fifty_perc_EHR_cont]
validation_set_low = validation_set[validation_set.Cal_MPEC_R0 < fifty_perc_EHR_cont]

# %%
predictor_variable = [
        'Co_CAD_R0', 'Co_Embolism_R0', 'Co_DVT_R0', 'Co_PE_R0', 'Co_AFib_R0',
        'Co_Hypertension_R0', 'Co_Hyperlipidemia_R0', 'Co_Atherosclerosis_R0',
        'Co_HF_R0', 'Co_HemoStroke_R0', 'Co_IscheStroke_R0', 'Co_OthStroke_R0',
        'Co_TIA_R0', 'Co_COPD_R0', 'Co_Asthma_R0', 'Co_Pneumonia_R0', 'Co_Alcoholabuse_R0',
        'Co_Drugabuse_R0', 'Co_Epilepsy_R0', 'Co_Cancer_R0', 'Co_MorbidObesity_R0',
        'Co_Dementia_R0', 'Co_Depression_R0', 'Co_Bipolar_R0', 'Co_Psychosis_R0',
        'Co_Personalitydisorder_R0', 'Co_Adjustmentdisorder_R0', 'Co_Anxiety_R0',
        'Co_Generalizedanxiety_R0', 'Co_OldMI_R0', 'Co_AcuteMI_R0', 'Co_PUD_R0',
        'Co_UpperGIbleed_R0', 'Co_LowerGIbleed_R0', 'Co_Urogenitalbleed_R0',
        'Co_Othbleed_R0', 'Co_PVD_R0', 'Co_LiverDisease_R0', 'Co_MRI_R0',
        'Co_ESRD_R0', 'Co_Obesity_R0', 'Co_Sepsis_R0', 'Co_Osteoarthritis_R0',
        'Co_RA_R0', 'Co_NeuroPain_R0', 'Co_NeckPain_R0', 'Co_OthArthritis_R0',
        'Co_Osteoporosis_R0', 'Co_Fibromyalgia_R0', 'Co_Migraine_R0', 'Co_Headache_R0',
        'Co_OthPain_R0', 'Co_GeneralizedPain_R0', 'Co_PainDisorder_R0',
        'Co_Falls_R0', 'Co_CoagulationDisorder_R0', 'Co_WhiteBloodCell_R0', 'Co_Parkinson_R0',
        'Co_Anemia_R0', 'Co_UrinaryIncontinence_R0', 'Co_DecubitusUlcer_R0',
        'Co_Oxygen_R0', 'Co_Mammography_R0', 'Co_PapTest_R0', 'Co_PSATest_R0',
        'Co_Colonoscopy_R0', 'Co_FecalOccultTest_R0', 'Co_FluShot_R0', 'Co_PneumococcalVaccine_R0', 'Co_RenalDysfunction_R0', 'Co_Valvular_R0', 'Co_Hosp_Prior30Days_R0',
        'Co_RX_Antibiotic_R0', 'Co_RX_Corticosteroid_R0', 'Co_RX_Aspirin_R0', 'Co_RX_Dipyridamole_R0',
        'Co_RX_Clopidogrel_R0', 'Co_RX_Prasugrel_R0', 'Co_RX_Cilostazol_R0', 'Co_RX_Ticlopidine_R0',
        'Co_RX_Ticagrelor_R0', 'Co_RX_OthAntiplatelet_R0', 'Co_RX_NSAIDs_R0',
        'Co_RX_Opioid_R0', 'Co_RX_Antidepressant_R0', 'Co_RX_AAntipsychotic_R0', 'Co_RX_TAntipsychotic_R0',
        'Co_RX_Anticonvulsant_R0', 'Co_RX_PPI_R0', 'Co_RX_H2Receptor_R0', 'Co_RX_OthGastro_R0',
        'Co_RX_ACE_R0', 'Co_RX_ARB_R0', 'Co_RX_BBlocker_R0', 'Co_RX_CCB_R0', 'Co_RX_Thiazide_R0',
        'Co_RX_Loop_R0', 'Co_RX_Potassium_R0', 'Co_RX_Nitrates_R0', 'Co_RX_Aliskiren_R0',
        'Co_RX_OthAntihypertensive_R0', 'Co_RX_Antiarrhythmic_R0', 'Co_RX_OthAnticoagulant_R0',
        'Co_RX_Insulin_R0', 'Co_RX_Noninsulin_R0', 'Co_RX_Digoxin_R0', 'Co_RX_Statin_R0',
        'Co_RX_Lipid_R0', 'Co_RX_Lithium_R0', 'Co_RX_Benzo_R0', 'Co_RX_ZDrugs_R0',
        'Co_RX_OthAnxiolytic_R0', 'Co_RX_Barbiturate_R0', 'Co_RX_Dementia_R0', 'Co_RX_Hormone_R0',
        'Co_RX_Osteoporosis_R0', 'Co_N_Drugs_R0', 'Co_N_Hosp_R0', 'Co_Total_HospLOS_R0',
        'Co_N_MDVisit_R0', 'Co_RX_AnyAspirin_R0', 'Co_RX_AspirinMono_R0', 'Co_RX_ClopidogrelMono_R0',
        'Co_RX_AspirinClopidogrel_R0', 'Co_RX_DM_R0', 'Co_RX_Antipsychotic_R0'
]

co_train_gpop = train_set[predictor_variable]
co_train_high = train_set_high[predictor_variable]
co_train_low = train_set_low[predictor_variable]

co_validation_gpop = validation_set[predictor_variable]
co_validation_high = validation_set_high[predictor_variable]
co_validation_low = validation_set_low[predictor_variable]

# %%
out_train_cardio_gpop = train_set['Out_comp_cardiovascular_RC1']
out_train_cardio_high = train_set_high['Out_comp_cardiovascular_RC1']
out_train_cardio_low = train_set_low['Out_comp_cardiovascular_RC1']

out_validation_cardio_gpop = validation_set['Out_comp_cardiovascular_RC1']
out_validation_cardio_high = validation_set_high['Out_comp_cardiovascular_RC1']
out_validation_cardio_low = validation_set_low['Out_comp_cardiovascular_RC1']

# %%
def lr(X_train, y_train):
    from sklearn.linear_model import Lasso
    from sklearn.decomposition import PCA
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    from imblearn.over_sampling import SMOTE
    from sklearn.preprocessing import StandardScaler 

    model = LogisticRegression()
    param_grid = [
        {'C' : np.logspace(-4, 4, 20)}
        ]
    clf = GridSearchCV(model, param_grid, cv = 5, verbose = True, n_jobs = -1)
    best_clf = clf.fit(X_train, y_train)
    return best_clf

# %%
def scores(X_train,y_train):
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import fbeta_score
    from sklearn.metrics import roc_auc_score 
    from sklearn.metrics import log_loss

    pred = best_clf.predict(X_train)
    actual = y_train
    print(accuracy_score(actual,pred))
    print(f1_score(actual,pred))
    print(fbeta_score(actual,pred, average = 'macro', beta = 2))
    print(roc_auc_score(actual, best_clf.predict_proba(X_train)[:,1]))
    print(log_loss(actual,best_clf.predict_proba(X_train)[:,1]))

# %%
def cross_val(X,y):
    from sklearn.model_selection import KFold
    from sklearn.model_selection import cross_validate
    from sklearn.metrics import log_loss
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import fbeta_score
    import sklearn
    import numpy as np
    cv = KFold(n_splits=5, random_state=1, shuffle=True)
    log_loss = [] 
    auc = [] 
    accuracy = [] 
    f1 = [] 
    f2 = [] 
    for train_index, test_index in cv.split(X):
        X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
        model = lr(X_train, y_train)
        prob = model.predict_proba(X_test)[:,1] # prob is a vector of probabilities 
        print(prob)
        pred = np.round(prob) # pred is the rounded predictions 
        
        log_loss.append(sklearn.metrics.log_loss(y_test, prob))
        auc.append(sklearn.metrics.roc_auc_score(y_test, prob))
        accuracy.append(sklearn.metrics.accuracy_score(y_test, pred))
        f1.append(sklearn.metrics.f1_score(y_test, pred, average = 'macro'))
        f2.append(fbeta_score(y_test,pred, average = 'macro', beta = 2))
    print(np.mean(accuracy))
    print(np.mean(f1))
    print(np.mean(f2))
    print(np.mean(auc))
    print(np.mean(log_loss))

# %%
best_clf = lr(co_train_gpop, out_train_cardio_gpop)
scores(co_train_gpop, out_train_cardio_gpop)
print()
scores(co_validation_gpop, out_validation_cardio_gpop)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 0.9093758728779368
# 0.022757697456492636
# 0.4970866156423905
# 0.7803274311677314
# 0.26626009297325265
#
# 0.8970382927802154
# 0.011488750598372427
# 0.49198337046159235
# 0.7684584948648554
# 0.2912727156539781
# ['Co_CAD_R0[[0.05282888]]',
#  'Co_Embolism_R0[[0.00179406]]',
#  'Co_DVT_R0[[-0.0119486]]',
#  'Co_PE_R0[[0.03765208]]',
#  'Co_AFib_R0[[0.11792563]]',
#  'Co_Hypertension_R0[[-0.04029284]]',
#  'Co_Hyperlipidemia_R0[[-0.26019592]]',
#  'Co_Atherosclerosis_R0[[0.01015357]]',
#  'Co_HF_R0[[0.28668932]]',
#  'Co_HemoStroke_R0[[0.09426557]]',
#  'Co_IscheStroke_R0[[0.10591247]]',
#  'Co_OthStroke_R0[[0.00319633]]',
#  'Co_TIA_R0[[-0.01351648]]',
#  'Co_COPD_R0[[0.19947739]]',
#  'Co_Asthma_R0[[-0.08727061]]',
#  'Co_Pneumonia_R0[[0.20397979]]',
#  'Co_Alcoholabuse_R0[[-0.00992874]]',
#  'Co_Drugabuse_R0[[-0.02820993]]',
#  'Co_Epilepsy_R0[[0.0171888]]',
#  'Co_Cancer_R0[[0.2156092]]',
#  'Co_MorbidObesity_R0[[-0.03765327]]',
#  'Co_Dementia_R0[[0.31212453]]',
#  'Co_Depression_R0[[-0.01418698]]',
#  'Co_Bipolar_R0[[-0.01320924]]',
#  'Co_Psychosis_R0[[-0.00119967]]',
#  'Co_Personalitydisorder_R0[[0.00060425]]',
#  'Co_Adjustmentdisorder_R0[[-0.00192473]]',
#  'Co_Anxiety_R0[[-0.04586488]]',
#  'Co_Generalizedanxiety_R0[[-0.01945656]]',
#  'Co_OldMI_R0[[-0.00430177]]',
#  'Co_AcuteMI_R0[[0.07253143]]',
#  'Co_PUD_R0[[-0.08558911]]',
#  'Co_UpperGIbleed_R0[[0.0042885]]',
#  'Co_LowerGIbleed_R0[[0.04272505]]',
#  'Co_Urogenitalbleed_R0[[-0.01925109]]',
#  'Co_Othbleed_R0[[-0.00751631]]',
#  'Co_PVD_R0[[0.0482509]]',
#  'Co_LiverDisease_R0[[0.05131884]]',
#  'Co_MRI_R0[[-0.00773924]]',
#  'Co_ESRD_R0[[0.07966054]]',
#  'Co_Obesity_R0[[-0.13617084]]',
#  'Co_Sepsis_R0[[0.06130856]]',
#  'Co_Osteoarthritis_R0[[-0.10000652]]',
#  'Co_RA_R0[[-0.01058583]]',
#  'Co_NeuroPain_R0[[-0.04036818]]',
#  'Co_NeckPain_R0[[-0.02091269]]',
#  'Co_OthArthritis_R0[[-0.06531927]]',
#  'Co_Osteoporosis_R0[[-0.01206998]]',
#  'Co_Fibromyalgia_R0[[-0.05022687]]',
#  'Co_Migraine_R0[[-0.01793183]]',
#  'Co_Headache_R0[[-0.02381651]]',
#  'Co_OthPain_R0[[0.00322973]]',
#  'Co_GeneralizedPain_R0[[0.01983642]]',
#  'Co_PainDisorder_R0[[-0.00159332]]',
#  'Co_Falls_R0[[0.12725907]]',
#  'Co_CoagulationDisorder_R0[[0.00545354]]',
#  'Co_WhiteBloodCell_R0[[0.04811526]]',
#  'Co_Parkinson_R0[[0.02115132]]',
#  'Co_Anemia_R0[[0.14024565]]',
#  'Co_UrinaryIncontinence_R0[[-0.01638944]]',
#  'Co_DecubitusUlcer_R0[[0.06202196]]',
#  'Co_Oxygen_R0[[0.02477834]]',
#  'Co_Mammography_R0[[-0.14331793]]',
#  'Co_PapTest_R0[[-0.04279334]]',
#  'Co_PSATest_R0[[-0.09542039]]',
#  'Co_Colonoscopy_R0[[-0.07413933]]',
#  'Co_FecalOccultTest_R0[[-0.00479339]]',
#  'Co_FluShot_R0[[-0.13884304]]',
#  'Co_PneumococcalVaccine_R0[[-0.08977335]]',
#  'Co_RenalDysfunction_R0[[0.21844046]]',
#  'Co_Valvular_R0[[0.01197737]]',
#  'Co_Hosp_Prior30Days_R0[[0.46956791]]',
#  'Co_RX_Antibiotic_R0[[-0.00644862]]',
#  'Co_RX_Corticosteroid_R0[[0.07377314]]',
#  'Co_RX_Aspirin_R0[[-0.0278525]]',
#  'Co_RX_Dipyridamole_R0[[-0.00101489]]',
#  'Co_RX_Clopidogrel_R0[[0.01419942]]',
#  'Co_RX_Prasugrel_R0[[-0.00440274]]',
#  'Co_RX_Cilostazol_R0[[0.0085771]]',
#  'Co_RX_Ticlopidine_R0[[-0.00107593]]',
#  'Co_RX_Ticagrelor_R0[[0.00310661]]',
#  'Co_RX_OthAntiplatelet_R0[[0.00750117]]',
#  'Co_RX_NSAIDs_R0[[-0.06192786]]',
#  'Co_RX_Opioid_R0[[0.05312862]]',
#  'Co_RX_Antidepressant_R0[[0.07296758]]',
#  'Co_RX_AAntipsychotic_R0[[0.06417692]]',
#  'Co_RX_TAntipsychotic_R0[[0.00519201]]',
#  'Co_RX_Anticonvulsant_R0[[0.07654114]]',
#  'Co_RX_PPI_R0[[0.0900378]]',
#  'Co_RX_H2Receptor_R0[[0.03822967]]',
#  'Co_RX_OthGastro_R0[[-0.04112717]]',
#  'Co_RX_ACE_R0[[-0.08173953]]',
#  'Co_RX_ARB_R0[[-0.09245892]]',
#  'Co_RX_BBlocker_R0[[-0.00613105]]',
#  'Co_RX_CCB_R0[[-0.01373512]]',
#  'Co_RX_Thiazide_R0[[-0.05883009]]',
#  'Co_RX_Loop_R0[[0.17989218]]',
#  'Co_RX_Potassium_R0[[0.01578765]]',
#  'Co_RX_Nitrates_R0[[0.07064901]]',
#  'Co_RX_Aliskiren_R0[[5.56636555e-05]]',
#  'Co_RX_OthAntihypertensive_R0[[-0.01432054]]',
#  'Co_RX_Antiarrhythmic_R0[[-0.01701063]]',
#  'Co_RX_OthAnticoagulant_R0[[0.01106699]]',
#  'Co_RX_Insulin_R0[[0.03928225]]',
#  'Co_RX_Noninsulin_R0[[-0.08150528]]',
#  'Co_RX_Digoxin_R0[[0.06700708]]',
#  'Co_RX_Statin_R0[[-0.15337933]]',
#  'Co_RX_Lipid_R0[[-0.05226669]]',
#  'Co_RX_Lithium_R0[[-0.00288238]]',
#  'Co_RX_Benzo_R0[[0.03169369]]',
#  'Co_RX_ZDrugs_R0[[-0.01297791]]',
#  'Co_RX_OthAnxiolytic_R0[[0.00563921]]',
#  'Co_RX_Barbiturate_R0[[0.00070147]]',
#  'Co_RX_Dementia_R0[[0.08411689]]',
#  'Co_RX_Hormone_R0[[-0.02779006]]',
#  'Co_RX_Osteoporosis_R0[[0.02917292]]',
#  'Co_N_Drugs_R0[[-0.00265093]]',
#  'Co_N_Hosp_R0[[0.1310391]]',
#  'Co_Total_HospLOS_R0[[0.0146758]]',
#  'Co_N_MDVisit_R0[[0.00020965]]',
#  'Co_RX_AnyAspirin_R0[[-0.02730436]]',
#  'Co_RX_AspirinMono_R0[[-0.04936087]]',
#  'Co_RX_ClopidogrelMono_R0[[-0.00501174]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.01995682]]',
#  'Co_RX_DM_R0[[-0.04354447]]',
#  'Co_RX_Antipsychotic_R0[[0.06969679]]']

# %%
best_clf = lr(co_train_low, out_train_cardio_low)
scores(co_train_low, out_train_cardio_low)
print()
scores(co_validation_low, out_validation_cardio_low)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8924759008863298
# 0.14943705220061412
# 0.5375845202541459
# 0.7887683203940171
# 3.7137554203605387
#
# 0.8731628173315519
# 0.1181154611811546
# 0.5235625276862101
# 0.7508179113801913
# 4.380807195708219
# ['Co_CAD_R0[[0.20779113]]',
#  'Co_Embolism_R0[[0.04734595]]',
#  'Co_DVT_R0[[0.00995306]]',
#  'Co_PE_R0[[0.20926545]]',
#  'Co_AFib_R0[[0.13208882]]',
#  'Co_Hypertension_R0[[-0.03836182]]',
#  'Co_Hyperlipidemia_R0[[-0.26650398]]',
#  'Co_Atherosclerosis_R0[[-0.01776418]]',
#  'Co_HF_R0[[0.48138627]]',
#  'Co_HemoStroke_R0[[0.464881]]',
#  'Co_IscheStroke_R0[[0.31239119]]',
#  'Co_OthStroke_R0[[-0.00423008]]',
#  'Co_TIA_R0[[-0.19725377]]',
#  'Co_COPD_R0[[0.48058742]]',
#  'Co_Asthma_R0[[-0.44064987]]',
#  'Co_Pneumonia_R0[[0.35800708]]',
#  'Co_Alcoholabuse_R0[[-0.25168658]]',
#  'Co_Drugabuse_R0[[-0.10736422]]',
#  'Co_Epilepsy_R0[[0.1264857]]',
#  'Co_Cancer_R0[[0.50832431]]',
#  'Co_MorbidObesity_R0[[-0.05700147]]',
#  'Co_Dementia_R0[[0.71076463]]',
#  'Co_Depression_R0[[-0.07969722]]',
#  'Co_Bipolar_R0[[-0.12069789]]',
#  'Co_Psychosis_R0[[-0.25482685]]',
#  'Co_Personalitydisorder_R0[[0.0275733]]',
#  'Co_Adjustmentdisorder_R0[[-0.00459671]]',
#  'Co_Anxiety_R0[[-0.2325627]]',
#  'Co_Generalizedanxiety_R0[[-0.10572661]]',
#  'Co_OldMI_R0[[-0.27441058]]',
#  'Co_AcuteMI_R0[[0.16047163]]',
#  'Co_PUD_R0[[-0.2857936]]',
#  'Co_UpperGIbleed_R0[[0.02443806]]',
#  'Co_LowerGIbleed_R0[[0.20705412]]',
#  'Co_Urogenitalbleed_R0[[-0.14559494]]',
#  'Co_Othbleed_R0[[-0.08007918]]',
#  'Co_PVD_R0[[0.19126836]]',
#  'Co_LiverDisease_R0[[0.1706456]]',
#  'Co_MRI_R0[[0.01135684]]',
#  'Co_ESRD_R0[[0.38388951]]',
#  'Co_Obesity_R0[[-0.30306637]]',
#  'Co_Sepsis_R0[[0.45148459]]',
#  'Co_Osteoarthritis_R0[[-0.02002695]]',
#  'Co_RA_R0[[0.03819317]]',
#  'Co_NeuroPain_R0[[-0.00989444]]',
#  'Co_NeckPain_R0[[-0.10529032]]',
#  'Co_OthArthritis_R0[[0.02846643]]',
#  'Co_Osteoporosis_R0[[-0.1003606]]',
#  'Co_Fibromyalgia_R0[[-0.05799707]]',
#  'Co_Migraine_R0[[-0.09312461]]',
#  'Co_Headache_R0[[-0.14772079]]',
#  'Co_OthPain_R0[[-0.17689586]]',
#  'Co_GeneralizedPain_R0[[0.02636046]]',
#  'Co_PainDisorder_R0[[-0.00388211]]',
#  'Co_Falls_R0[[0.20521604]]',
#  'Co_CoagulationDisorder_R0[[0.05221942]]',
#  'Co_WhiteBloodCell_R0[[0.06771142]]',
#  'Co_Parkinson_R0[[-0.0060073]]',
#  'Co_Anemia_R0[[0.0373059]]',
#  'Co_UrinaryIncontinence_R0[[-0.13072677]]',
#  'Co_DecubitusUlcer_R0[[0.25472321]]',
#  'Co_Oxygen_R0[[0.01141287]]',
#  'Co_Mammography_R0[[-0.12228789]]',
#  'Co_PapTest_R0[[-0.0328545]]',
#  'Co_PSATest_R0[[-0.07817587]]',
#  'Co_Colonoscopy_R0[[-0.0840066]]',
#  'Co_FecalOccultTest_R0[[0.0298584]]',
#  'Co_FluShot_R0[[-0.13680887]]',
#  'Co_PneumococcalVaccine_R0[[-0.06113839]]',
#  'Co_RenalDysfunction_R0[[0.34064808]]',
#  'Co_Valvular_R0[[0.11063381]]',
#  'Co_Hosp_Prior30Days_R0[[0.75240632]]',
#  'Co_RX_Antibiotic_R0[[-0.0344285]]',
#  'Co_RX_Corticosteroid_R0[[0.17313597]]',
#  'Co_RX_Aspirin_R0[[-0.00895952]]',
#  'Co_RX_Dipyridamole_R0[[0.02562719]]',
#  'Co_RX_Clopidogrel_R0[[-0.04416736]]',
#  'Co_RX_Prasugrel_R0[[-0.02285589]]',
#  'Co_RX_Cilostazol_R0[[0.02148657]]',
#  'Co_RX_Ticlopidine_R0[[-0.00545715]]',
#  'Co_RX_Ticagrelor_R0[[0.04294966]]',
#  'Co_RX_OthAntiplatelet_R0[[0.01602942]]',
#  'Co_RX_NSAIDs_R0[[-0.05478795]]',
#  'Co_RX_Opioid_R0[[0.28177879]]',
#  'Co_RX_Antidepressant_R0[[0.02680302]]',
#  'Co_RX_AAntipsychotic_R0[[0.11391982]]',
#  'Co_RX_TAntipsychotic_R0[[-0.04908801]]',
#  'Co_RX_Anticonvulsant_R0[[0.17244647]]',
#  'Co_RX_PPI_R0[[0.27293576]]',
#  'Co_RX_H2Receptor_R0[[0.20035042]]',
#  'Co_RX_OthGastro_R0[[-0.04940038]]',
#  'Co_RX_ACE_R0[[-0.06376916]]',
#  'Co_RX_ARB_R0[[-0.18375795]]',
#  'Co_RX_BBlocker_R0[[-0.0025415]]',
#  'Co_RX_CCB_R0[[-0.01165928]]',
#  'Co_RX_Thiazide_R0[[-0.1242079]]',
#  'Co_RX_Loop_R0[[0.25339051]]',
#  'Co_RX_Potassium_R0[[-0.04158721]]',
#  'Co_RX_Nitrates_R0[[0.06863462]]',
#  'Co_RX_Aliskiren_R0[[-0.00842228]]',
#  'Co_RX_OthAntihypertensive_R0[[-0.15203673]]',
#  'Co_RX_Antiarrhythmic_R0[[-0.07376082]]',
#  'Co_RX_OthAnticoagulant_R0[[0.08350395]]',
#  'Co_RX_Insulin_R0[[0.17879397]]',
#  'Co_RX_Noninsulin_R0[[-0.18281943]]',
#  'Co_RX_Digoxin_R0[[0.20018863]]',
#  'Co_RX_Statin_R0[[-0.33319411]]',
#  'Co_RX_Lipid_R0[[-0.14050796]]',
#  'Co_RX_Lithium_R0[[0.02276413]]',
#  'Co_RX_Benzo_R0[[0.07467941]]',
#  'Co_RX_ZDrugs_R0[[-0.01371681]]',
#  'Co_RX_OthAnxiolytic_R0[[-0.12091491]]',
#  'Co_RX_Barbiturate_R0[[0.]]',
#  'Co_RX_Dementia_R0[[0.15929171]]',
#  'Co_RX_Hormone_R0[[-0.02138176]]',
#  'Co_RX_Osteoporosis_R0[[-0.00442452]]',
#  'Co_N_Drugs_R0[[-0.00787558]]',
#  'Co_N_Hosp_R0[[-0.00535736]]',
#  'Co_Total_HospLOS_R0[[-0.00513988]]',
#  'Co_N_MDVisit_R0[[-0.30685596]]',
#  'Co_RX_AnyAspirin_R0[[-0.00895952]]',
#  'Co_RX_AspirinMono_R0[[-0.11253648]]',
#  'Co_RX_ClopidogrelMono_R0[[-0.10864141]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.06981604]]',
#  'Co_RX_DM_R0[[-0.08085116]]',
#  'Co_RX_Antipsychotic_R0[[0.14510016]]']

# %%
best_clf = lr(co_train_high, out_train_cardio_high)
scores(co_train_high, out_train_cardio_high)
print()
scores(co_validation_high, out_validation_cardio_high)

comb = [] 
for i in range(len(predictor_variable)):
    comb.append(predictor_variable[i] + str(best_clf.best_estimator_.coef_[:,i:i+1]))
comb
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /PHShome/se197/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9282390837508948
# 0.025910931174089064
# 0.5002561820151564
# 0.7954917593119863
# 2.478535289562218
#
# 0.9246189183545626
# 0.024324324324324322
# 0.49917050223225246
# 0.7710335152343126
# 2.603571909529828
# ['Co_CAD_R0[[-0.02593684]]',
#  'Co_Embolism_R0[[-0.01065262]]',
#  'Co_DVT_R0[[-0.01379738]]',
#  'Co_PE_R0[[0.03869755]]',
#  'Co_AFib_R0[[0.12812447]]',
#  'Co_Hypertension_R0[[-0.03918049]]',
#  'Co_Hyperlipidemia_R0[[-0.25569458]]',
#  'Co_Atherosclerosis_R0[[0.03084575]]',
#  'Co_HF_R0[[0.27161124]]',
#  'Co_HemoStroke_R0[[0.01964557]]',
#  'Co_IscheStroke_R0[[0.07712306]]',
#  'Co_OthStroke_R0[[0.00021617]]',
#  'Co_TIA_R0[[0.03612268]]',
#  'Co_COPD_R0[[0.17349651]]',
#  'Co_Asthma_R0[[-0.11741841]]',
#  'Co_Pneumonia_R0[[0.16759299]]',
#  'Co_Alcoholabuse_R0[[0.015803]]',
#  'Co_Drugabuse_R0[[-0.04597738]]',
#  'Co_Epilepsy_R0[[-0.01688021]]',
#  'Co_Cancer_R0[[0.26617689]]',
#  'Co_MorbidObesity_R0[[-0.05987371]]',
#  'Co_Dementia_R0[[0.29042927]]',
#  'Co_Depression_R0[[-0.00425201]]',
#  'Co_Bipolar_R0[[-0.01532914]]',
#  'Co_Psychosis_R0[[0.01738713]]',
#  'Co_Personalitydisorder_R0[[-0.00275624]]',
#  'Co_Adjustmentdisorder_R0[[-0.00543387]]',
#  'Co_Anxiety_R0[[-0.05053258]]',
#  'Co_Generalizedanxiety_R0[[-0.02601927]]',
#  'Co_OldMI_R0[[0.07432946]]',
#  'Co_AcuteMI_R0[[0.00450924]]',
#  'Co_PUD_R0[[-0.08245748]]',
#  'Co_UpperGIbleed_R0[[-0.00497061]]',
#  'Co_LowerGIbleed_R0[[0.03600799]]',
#  'Co_Urogenitalbleed_R0[[-0.01432858]]',
#  'Co_Othbleed_R0[[-0.01453413]]',
#  'Co_PVD_R0[[0.07601924]]',
#  'Co_LiverDisease_R0[[0.05384621]]',
#  'Co_MRI_R0[[-0.01314748]]',
#  'Co_ESRD_R0[[0.08156724]]',
#  'Co_Obesity_R0[[-0.19143424]]',
#  'Co_Sepsis_R0[[0.0068136]]',
#  'Co_Osteoarthritis_R0[[-0.15490947]]',
#  'Co_RA_R0[[-0.03811587]]',
#  'Co_NeuroPain_R0[[-0.04996784]]',
#  'Co_NeckPain_R0[[0.01534902]]',
#  'Co_OthArthritis_R0[[-0.06426196]]',
#  'Co_Osteoporosis_R0[[-0.02036735]]',
#  'Co_Fibromyalgia_R0[[-0.10345702]]',
#  'Co_Migraine_R0[[-0.02583105]]',
#  'Co_Headache_R0[[-0.02843802]]',
#  'Co_OthPain_R0[[0.03418373]]',
#  'Co_GeneralizedPain_R0[[0.04150579]]',
#  'Co_PainDisorder_R0[[-0.00334589]]',
#  'Co_Falls_R0[[0.15361132]]',
#  'Co_CoagulationDisorder_R0[[-0.03837792]]',
#  'Co_WhiteBloodCell_R0[[0.07974257]]',
#  'Co_Parkinson_R0[[0.05855104]]',
#  'Co_Anemia_R0[[0.21907013]]',
#  'Co_UrinaryIncontinence_R0[[-0.00699182]]',
#  'Co_DecubitusUlcer_R0[[0.09309969]]',
#  'Co_Oxygen_R0[[0.03109607]]',
#  'Co_Mammography_R0[[-0.23336]]',
#  'Co_PapTest_R0[[-0.07790841]]',
#  'Co_PSATest_R0[[-0.11770227]]',
#  'Co_Colonoscopy_R0[[-0.10794691]]',
#  'Co_FecalOccultTest_R0[[0.0040704]]',
#  'Co_FluShot_R0[[-0.14324957]]',
#  'Co_PneumococcalVaccine_R0[[-0.13854743]]',
#  'Co_RenalDysfunction_R0[[0.19703849]]',
#  'Co_Valvular_R0[[0.04062464]]',
#  'Co_Hosp_Prior30Days_R0[[0.18580593]]',
#  'Co_RX_Antibiotic_R0[[0.01865958]]',
#  'Co_RX_Corticosteroid_R0[[0.10360253]]',
#  'Co_RX_Aspirin_R0[[-0.00784097]]',
#  'Co_RX_Dipyridamole_R0[[-0.00326966]]',
#  'Co_RX_Clopidogrel_R0[[0.04601151]]',
#  'Co_RX_Prasugrel_R0[[-0.00527942]]',
#  'Co_RX_Cilostazol_R0[[0.0163961]]',
#  'Co_RX_Ticlopidine_R0[[-0.00179693]]',
#  'Co_RX_Ticagrelor_R0[[-0.00045407]]',
#  'Co_RX_OthAntiplatelet_R0[[0.01459917]]',
#  'Co_RX_NSAIDs_R0[[-0.0576086]]',
#  'Co_RX_Opioid_R0[[-0.02918601]]',
#  'Co_RX_Antidepressant_R0[[0.13083112]]',
#  'Co_RX_AAntipsychotic_R0[[0.10462743]]',
#  'Co_RX_TAntipsychotic_R0[[-0.00366353]]',
#  'Co_RX_Anticonvulsant_R0[[0.03086302]]',
#  'Co_RX_PPI_R0[[0.10541237]]',
#  'Co_RX_H2Receptor_R0[[0.00849433]]',
#  'Co_RX_OthGastro_R0[[-0.07611889]]',
#  'Co_RX_ACE_R0[[-0.07538673]]',
#  'Co_RX_ARB_R0[[-0.09915427]]',
#  'Co_RX_BBlocker_R0[[0.03981239]]',
#  'Co_RX_CCB_R0[[-0.04666643]]',
#  'Co_RX_Thiazide_R0[[-0.01992414]]',
#  'Co_RX_Loop_R0[[0.22013075]]',
#  'Co_RX_Potassium_R0[[0.05255637]]',
#  'Co_RX_Nitrates_R0[[0.11825279]]',
#  'Co_RX_Aliskiren_R0[[0.00155504]]',
#  'Co_RX_OthAntihypertensive_R0[[0.00515808]]',
#  'Co_RX_Antiarrhythmic_R0[[-0.01018226]]',
#  'Co_RX_OthAnticoagulant_R0[[0.01457435]]',
#  'Co_RX_Insulin_R0[[0.00589197]]',
#  'Co_RX_Noninsulin_R0[[-0.05496981]]',
#  'Co_RX_Digoxin_R0[[0.10036249]]',
#  'Co_RX_Statin_R0[[-0.11828271]]',
#  'Co_RX_Lipid_R0[[-0.06177514]]',
#  'Co_RX_Lithium_R0[[-0.01264797]]',
#  'Co_RX_Benzo_R0[[0.02846789]]',
#  'Co_RX_ZDrugs_R0[[-0.00389126]]',
#  'Co_RX_OthAnxiolytic_R0[[0.03074999]]',
#  'Co_RX_Barbiturate_R0[[0.0018675]]',
#  'Co_RX_Dementia_R0[[0.13435306]]',
#  'Co_RX_Hormone_R0[[-0.04940422]]',
#  'Co_RX_Osteoporosis_R0[[0.07043354]]',
#  'Co_N_Drugs_R0[[0.00324697]]',
#  'Co_N_Hosp_R0[[0.04354274]]',
#  'Co_Total_HospLOS_R0[[0.00576923]]',
#  'Co_N_MDVisit_R0[[0.02423766]]',
#  'Co_RX_AnyAspirin_R0[[-0.00614002]]',
#  'Co_RX_AspirinMono_R0[[-0.04440868]]',
#  'Co_RX_ClopidogrelMono_R0[[0.00740621]]',
#  'Co_RX_AspirinClopidogrel_R0[[0.03944705]]',
#  'Co_RX_DM_R0[[-0.03969067]]',
#  'Co_RX_Antipsychotic_R0[[0.08816775]]']
